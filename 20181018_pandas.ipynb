# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library: 
##from (library) import (specific library function)
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# Enable inline plotting
# %matplotlib inline

# %%
# The inital set of baby names and birth rates
names = ['Bob','Jessica','Mary','John','Mel']
births = [968, 155, 77, 578, 973]

# %%
zip(names,births)

# %%
BabyDataSet = list(zip(names,births))
BabyDataSet
# Out:
# [('Bob', 968), ('Jessica', 155), ('Mary', 77), ('John', 578), ('Mel', 973)]

# %%
df = pd.DataFrame(data = BabyDataSet, columns=['Names', 'Births'])
df
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973

# %%
df.to_csv('births1880.csv',index=False,header=False)

# %%
read_csv?

# %%
Location = r'C:\Users\Administrator\births1880.csv'
df = pd.read_csv(Location)

# %%
df
# Out:
#        Bob  968
# 0  Jessica  155
# 1     Mary   77
# 2     John  578
# 3      Mel  973

# %%
Location = r'births1880.csv'
df = pd.read_csv(Location)
df
# Out:
#        Bob  968
# 0  Jessica  155
# 1     Mary   77
# 2     John  578
# 3      Mel  973

# %%
pd.read_csv?

# %%
df = pd.read_csv(Location, header=None)
df
# Out:
#          0    1
# 0      Bob  968
# 1  Jessica  155
# 2     Mary   77
# 3     John  578
# 4      Mel  973

# %%
df = pd.read_csv(Location, names=['Names','Births'])
df
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973

# %%
df = pd.read_csv(Location, header=[1,3])
df
# Out:
#   Jessica  155
#      John  578
# 0     Mel  973

# %% [markdown]
# import os
# os.remove('births1880 - 副本.csv')

# %%
df = pd.read_csv(Location, header=None)
df
# Out:
#          0    1
# 0      Bob  968
# 1  Jessica  155
# 2     Mary   77
# 3     John  578
# 4      Mel  973

# %%
# Check data type of the columns
df.dtypes
# Out:
# 0    object
# 1     int64
# dtype: object

# %%
# Check data type of Births column
help(df)
# Out:
# Help on DataFrame in module pandas.core.frame object:
#
# class DataFrame(pandas.core.generic.NDFrame)
#  |  Two-dimensional size-mutable, potentially heterogeneous tabular data
#  |  structure with labeled axes (rows and columns). Arithmetic operations
#  |  align on both row and column labels. Can be thought of as a dict-like
#  |  container for Series objects. The primary pandas data structure
#  |
#  |  Parameters
#  |  ----------
#  |  data : numpy ndarray (structured or homogeneous), dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, or list-like objects
#  |  index : Index or array-like
#  |      Index to use for resulting frame. Will default to np.arange(n) if
#  |      no indexing information part of input data and no index provided
#  |  columns : Index or array-like
#  |      Column labels to use for resulting frame. Will default to
#  |      np.arange(n) if no column labels are provided
#  |  dtype : dtype, default None
# ...

# %%
type(df[0])
# Out:
# pandas.core.series.Series

# %%
df[1].dtype
# Out:
# dtype('int64')

# %%
df[1][2]
# Out:
# 77

# %%
df = pd.read_csv(Location, names=['Names','Births'])
df
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973

# %%
df['Names'][0]
# Out:
# 'Bob'

# %%
#df.loc(0)[0]
# Out:
# Names     Bob
# Births    968
# Name: 0, dtype: object

# %%
# Method 1:
Sorted = df.sort_values(['Births'], ascending=False)

# %%
Sorted
# Out:
#      Names  Births
# 4      Mel     973
# 0      Bob     968
# 3     John     578
# 1  Jessica     155
# 2     Mary      77

# %%
Sorted.head(2)
# Out:
#   Names  Births
# 4   Mel     973
# 0   Bob     968

# %%
Sorted.tail(2)
# Out:
#      Names  Births
# 1  Jessica     155
# 2     Mary      77

# %%
# Method 2:
df['Births'].max()
# Out:
# 973

# %%
# df.iloc(0)[0]

# %%
# df.loc(0)[0]['Names']

# %%
df['Births'] == df['Births'].max()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Births, dtype: bool

# %%
[df['Births'] == df['Births'].max()]
# Out:
# [0    False
#  1    False
#  2    False
#  3    False
#  4     True
#  Name: Births, dtype: bool]

# %%
type([df['Births'] == df['Births'].max()][0])
# Out:
# pandas.core.series.Series

# %%
df['Births'] == df['Births'].max()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Births, dtype: bool

# %%
type(df['Births'] == df['Births'].max())
# Out:
# pandas.core.series.Series

# %%
df['Names'][df['Births'] == df['Births'].max()]
# Out:
# 4    Mel
# Name: Names, dtype: object

# %%
obj = pd.Series(data = [True,False,True,False,False],name='Births')
type(obj)
# Out:
# pandas.core.series.Series

# %%
obj
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# Name: Births, dtype: bool

# %%
df['Names'][obj]
# Out:
# 0     Bob
# 2    Mary
# Name: Names, dtype: object

# %%
import pandas as pd

# %%
pd.Series?

# %%
# df['Names'][pd.Series(index=0,data=True),pd.Series(index=1,data=True),pd.Series(index=2,data=False),pd.Series(index=3,data=False)]

# %%
# df['Names'][pd.Series(index=0,data=True),pd.Series(index=1,data=True),pd.Series(index=2,data=False),pd.Series(index=3,data=False)]

# %%
#pd.Series(index=1,data='22ff')

# %%
Sorted['Names'].head(1)
# Out:
# 4    Mel
# Name: Names, dtype: object

# %%
type(Sorted['Names'].head(1).values)
# Out:
# numpy.ndarray

# %%
# help(Sorted['Names'].head(1))

# %%
# dir(Sorted['Names'].head(1))

# %%
Sorted['Names'].head(1).values[0]
# Out:
# 'Mel'

# %%
Sorted['Names'].head(1).get_values()
# Out:
# array(['Mel'], dtype=object)

# %%
help(Sorted['Names'].head(1).get_values)
# Out:
# Help on method get_values in module pandas.core.series:
#
# get_values() method of pandas.core.series.Series instance
#     same as values (but handles sparseness conversions); is a view

# %%
Sorted['Names'].head(1).get_values()
# Out:
# array(['Mel'], dtype=object)

# %%
# Create graph
df['Births'].plot()

# %%
# Maximum value in the data set
MaxValue = df['Births'].max()

# %%
MaxValue
# Out:
# 973

# %%
# Name associated with the maximum value
MaxName = df['Names'][df['Births'] == df['Births'].max()].values

# %%
MaxName
# Out:
# array(['Mel'], dtype=object)

# %%
# Text to display on graph
Text = str(MaxValue) + " - " + MaxName

# %%
Text
# Out:
# array(['973 - Mel'], dtype=object)

# %%
# Add text to graph
plt.annotate(Text, xy=(1, MaxValue), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')
# Out:
# Text(8,0,"['973 - Mel']")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     236
#     237     if 'png' in formats:
# --> 238         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     239     if 'retina' in formats or 'png2x' in formats:
#     240         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     120
# ...

# %%
# Create graph
df['Births'].plot()

# Maximum value in the data set
MaxValue = df['Births'].max()

# Name associated with the maximum value
MaxName = df['Names'][df['Births'] == df['Births'].max()].values

# Text to display on graph
Text = str(MaxValue) + " - " + MaxName

# Add text to graph
plt.annotate(Text, xy=(1, MaxValue), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')

print("The most popular name")
df[df['Births'] == df['Births'].max()]
#Sorted.head(1) can also be used
# Out:
# The most popular name
#   Names  Births
# 4   Mel     973

# %%
# Create graph
df['Births'].plot()

# Maximum value in the data set
MaxValue = df['Births'].max()

# Name associated with the maximum value
MaxName = df['Names'][df['Births'] == df['Births'].max()].values

# Text to display on graph
Text = str(MaxValue) + " - " + MaxName

# Add text to graph
plt.annotate(Text, xy=(1, MaxValue), xytext=(10, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')
# Out:
# Text(10,0,"['973 - Mel']")

# %%
df[df['Births'] == df['Births'].max()]
#Sorted.head(1) can also be used
# Out:
#   Names  Births
# 4   Mel     973

# %%
# help(plt.annotate)

# %%
type(df['Births'])
# Out:
# pandas.core.series.Series

# %%
help(pd.Series)
# Out:
# Help on class Series in module pandas.core.series:
#
# class Series(pandas.core.base.IndexOpsMixin, pandas.core.generic.NDFrame)
#  |  One-dimensional ndarray with axis labels (including time series).
#  |
#  |  Labels need not be unique but must be a hashable type. The object
#  |  supports both integer- and label-based indexing and provides a host of
#  |  methods for performing operations involving the index. Statistical
#  |  methods from ndarray have been overridden to automatically exclude
#  |  missing data (currently represented as NaN).
#  |
#  |  Operations between Series (+, -, /, *, **) align values based on their
#  |  associated index values-- they need not be the same length. The result
#  |  index will be the sorted union of the two indexes.
#  |
#  |  Parameters
#  |  ----------
#  |  data : array-like, dict, or scalar value
#  |      Contains data stored in Series
#  |  index : array-like or Index (1d)
# ...

# %%
obj = pd.Series([1,2,3])

# %%
obj
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
obj = pd.Series(data = [1,2,3],index=['jack','tom','rose'])

# %%
obj
# Out:
# jack    1
# tom     2
# rose    3
# dtype: int64

# %%
obj = pd.Series(data = [True,True,False],index=['jack','tom','rose'])
obj
# Out:
# jack     True
# tom      True
# rose    False
# dtype: bool

# %%
df['Names'][obj]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-189-cfe7dd0f9987> in <module>()
# ----> 1 df['Names'][obj]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     660
#     661         if com.is_bool_indexer(key):
# --> 662             key = check_bool_indexer(self.index, key)
#     663
#     664         return self._get_with(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(ax, key)
#    2021         mask = isna(result._values)
#    2022         if mask.any():
# -> 2023             raise IndexingError('Unalignable boolean Series provided as '
#    2024                                 'indexer (index of the boolean Series and of '
#    2025                                 'the indexed object do not match')
#
# ...
