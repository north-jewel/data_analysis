# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
x = np.linspace(-np.pi,np.pi,20,endpoint=True)

# %%
y=np.sin(x)

# %%
z = np.cos(x)

# %%
plt.figure(1)

# %%
plt.title('sin & cos') # title单独画会单独显示
plt.plot(x,y,color='green',linewidth=4.0,linestyle='--',label='sin',alpha=0.5)
plt.legend()
plt.plot(x,z,'co')

# %% [markdown]
# ### [-5,5] y=x**2 黄线 点图 标题为'y=x**2' 图例为平方图

# %%
x = np.linspace(-5,5,20,endpoint=True)

# %%
y=x**2

# %%
plt.title('y=x**2')
plt.plot(x,y,'y:',label='平方图')
plt.legend()

# %%
print(matplotlib.matplotlib_fname())
# Out:
# D:\Anaconda3-5.2\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
v = np.linspace(0,2*np.pi,100,endpoint=True)
x=np.cos(v)
y=np.sin(v)

# %%
a = np.linspace(0,2*np.pi,100,endpoint=True)
b=np.cos(a)
c=np.sin(a)

# %%
e = np.linspace(-1,1,30,endpoint=True)
n = np.cos(e*2)
f = np.sin(e*2)
l = np.linspace(-1,1,30,endpoint=True)

# %%
g1 = np.linspace(-1.8,1.8,endpoint=True)
g = np.linspace(-2,2,endpoint=True)

# %%
#plt.plot(x/5+1,y/4+0.5,'ko')
plt.plot(b/4,c/4,'g')
#plt.plot(g-1.5,g*0+0.2,'ro')
#plt.plot(x/5-1,y/4+0.5,'ko')

plt.plot(x*2,y*2,'g')
#plt.fill_between(x*2,y*2,'g')
#plt.fill_between(x*2,y*2-0.25>0,color='red')
plt.plot(e/2,f/10-1.5,'g') # 嘴
plt.plot(e/2,e*0-0.8,'g') # 上嘴唇
plt.plot(l/2,l*0-1.2,'k',alpha=0.25)
#plt.plot(l/2,l*0-1.4,'r',alpha=0.5)
#plt.fill_between(l,np.abs(l)>1.8,color='blue')
plt.plot(e*0-0.5,e/2.5-1.2,'g')
plt.plot(e*0+0.5,e/3.5-1.1,'g')
#plt.plot(g1,g1*0+0.8,'ro')
#plt.plot(g,g*0+0.2,'ro')

plt.fill_between(g1,np.abs(g1)<1.8,color='red')
plt.plot(-e/2-0.6,f/2+1.3,'m')
plt.plot(e/2+0.6,f/2+1.3,'m')
plt.plot(x/4+1,y/15+0.5,'wo')
plt.plot(x/4-1,y/15+0.5,'wo')
plt.fill_between(x/2,y-0.5,color='white')
plt.show()

# %%
#v = np.linspace(0,2*np.pi,100)
#a = np.cos(v*2)
#b = np.sin(v*2)

super_x = [0,1,2,1.6,0.4,0]
super_y = [1,0,1,1.3,1.3,1]
super_a = [0.55,0.55,1.45,1.45,0.55,0.55,1.45,1.45]
super_b = [0.65,0.6,0.6,0.9,0.9,1.2,1.2,1.15]
plt.plot(super_x,super_y)
#plt.plot(-v/8+1.4,a/8+0.8,'wo')

plt.plot(super_a,super_b,'r',linewidth=15)
plt.fill(super_x,super_y,color='y')

# %%
plt.figure()
plt.subplot(projection='polar')
t = [np.pi/2,2*np.pi*(5/8),np.pi*(1/8),np.pi*(7/8),2*np.pi*(7/8),np.pi/2,np.pi/2]
m_t = [3,3,3,3,3,3,7]
plt.plot(t,m_t,'-',c='silver')
plt.fill(np.arange(0,2*np.pi,2*np.pi/1000),np.random.randint(7,8,1000),'red',
         np.arange(0,2*np.pi,2*np.pi/1000),np.random.randint(6,7,1000),'silver',
         np.arange(0,2*np.pi,2*np.pi/1000),np.random.randint(5,6,1000),'red',
         np.arange(0,2*np.pi,2*np.pi/1000),np.random.randint(4,5,1000),'blue',
        t,m_t,'white',)
plt.xticks([])
plt.yticks([])
plt.show()
