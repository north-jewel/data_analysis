# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s = pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101',periods = 6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4),index = dates,columns = list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.699176 -0.561988  1.075385  0.735907
# 2013-01-02 -0.542667 -0.427250  0.162986 -1.614862
# 2013-01-03  1.001508  1.588235  0.161555  0.894559
# 2013-01-04  0.889631 -2.085432 -0.357393 -0.823406
# 2013-01-05 -1.235319  0.111006 -0.560676  1.186859
# 2013-01-06 -0.380834  0.644047  0.321080  0.008130

# %%
df2 = pd.DataFrame({'A':1.,
                   'B':pd.Timestamp('20130102'),
                   'C':pd.Series(1,index = list(range(4)),dtype = 'float'),
                   'D':np.array([3] * 4,dtype = 'int'),
                   'E':pd.Categorical(['test','train','test','train']),
                   'F':'foo'})

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float64
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 1.69917587, -0.56198807,  1.07538478,  0.73590689],
#        [-0.54266666, -0.42724958,  0.16298587, -1.61486203],
#        [ 1.00150776,  1.58823462,  0.16155475,  0.89455916],
#        [ 0.88963105, -2.08543239, -0.35739289, -0.82340586],
#        [-1.23531941,  0.11100584, -0.56067614,  1.18685868],
#        [-0.38083355,  0.6440466 ,  0.32108042,  0.00813015]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.238583 -0.121897  0.133823  0.064531
# std    1.123002  1.241600  0.573907  1.096475
# min   -1.235319 -2.085432 -0.560676 -1.614862
# 25%   -0.502208 -0.528303 -0.227656 -0.615522
# 50%    0.254399 -0.158122  0.162270  0.372019
# 75%    0.973539  0.510786  0.281557  0.854896
# max    1.699176  1.588235  1.075385  1.186859

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    1.699176   -0.542667    1.001508    0.889631   -1.235319   -0.380834
# B   -0.561988   -0.427250    1.588235   -2.085432    0.111006    0.644047
# C    1.075385    0.162986    0.161555   -0.357393   -0.560676    0.321080
# D    0.735907   -1.614862    0.894559   -0.823406    1.186859    0.008130

# %%
df.sort_values(by = 'B')
# Out:
#                    A         B         C         D
# 2013-01-04  0.889631 -2.085432 -0.357393 -0.823406
# 2013-01-01  1.699176 -0.561988  1.075385  0.735907
# 2013-01-02 -0.542667 -0.427250  0.162986 -1.614862
# 2013-01-05 -1.235319  0.111006 -0.560676  1.186859
# 2013-01-06 -0.380834  0.644047  0.321080  0.008130
# 2013-01-03  1.001508  1.588235  0.161555  0.894559

# %%
df['A']
# Out:
# 2013-01-01    1.699176
# 2013-01-02   -0.542667
# 2013-01-03    1.001508
# 2013-01-04    0.889631
# 2013-01-05   -1.235319
# 2013-01-06   -0.380834
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  1.699176 -0.561988  1.075385  0.735907
# 2013-01-02 -0.542667 -0.427250  0.162986 -1.614862
# 2013-01-03  1.001508  1.588235  0.161555  0.894559

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -0.542667 -0.427250  0.162986 -1.614862
# 2013-01-03  1.001508  1.588235  0.161555  0.894559
# 2013-01-04  0.889631 -2.085432 -0.357393 -0.823406

# %%
df.loc[dates[0]]
# Out:
# A    1.699176
# B   -0.561988
# C    1.075385
# D    0.735907
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01  1.699176 -0.561988
# 2013-01-02 -0.542667 -0.427250
# 2013-01-03  1.001508  1.588235
# 2013-01-04  0.889631 -2.085432
# 2013-01-05 -1.235319  0.111006
# 2013-01-06 -0.380834  0.644047

# %%
df.loc['20130102':'20130104',['A','B']]
# Out:
#                    A         B
# 2013-01-02 -0.542667 -0.427250
# 2013-01-03  1.001508  1.588235
# 2013-01-04  0.889631 -2.085432

# %%
df.loc['20130102',['A','B']]
# Out:
# A   -0.542667
# B   -0.427250
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0],'A']
# Out:
# 1.699175869938465

# %%
df.at[dates[0],'A']
# Out:
# 1.699175869938465

# %%
df.iloc[3]
# Out:
# A    0.889631
# B   -2.085432
# C   -0.357393
# D   -0.823406
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2013-01-04  0.889631 -2.085432
# 2013-01-05 -1.235319  0.111006

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.542667  0.162986
# 2013-01-03  1.001508  0.161555
# 2013-01-05 -1.235319 -0.560676

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.542667 -0.427250  0.162986 -1.614862
# 2013-01-03  1.001508  1.588235  0.161555  0.894559

# %%
df.iloc[1,1]
# Out:
# -0.42724957539428843

# %%
df.iat[1,1]
# Out:
# -0.42724957539428843

# %%
df[df.A>0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.699176 -0.561988  1.075385  0.735907
# 2013-01-03  1.001508  1.588235  0.161555  0.894559
# 2013-01-04  0.889631 -2.085432 -0.357393 -0.823406

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.699176       NaN  1.075385  0.735907
# 2013-01-02       NaN       NaN  0.162986       NaN
# 2013-01-03  1.001508  1.588235  0.161555  0.894559
# 2013-01-04  0.889631       NaN       NaN       NaN
# 2013-01-05       NaN  0.111006       NaN  1.186859
# 2013-01-06       NaN  0.644047  0.321080  0.008130

# %%
df[df>0].count()
# Out:
# A    3
# B    3
# C    4
# D    4
# dtype: int64

# %%
df[df>0].size
# Out:
# 24

# %%
df2 = df.copy()

# %%
df2['E'] = ['one','one','two','three','four','three']

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  1.699176 -0.561988  1.075385  0.735907    one
# 2013-01-02 -0.542667 -0.427250  0.162986 -1.614862    one
# 2013-01-03  1.001508  1.588235  0.161555  0.894559    two
# 2013-01-04  0.889631 -2.085432 -0.357393 -0.823406  three
# 2013-01-05 -1.235319  0.111006 -0.560676  1.186859   four
# 2013-01-06 -0.380834  0.644047  0.321080  0.008130  three

# %%
df2[df2.E.isin(['two','three'])]
# Out:
#                    A         B         C         D      E
# 2013-01-03  1.001508  1.588235  0.161555  0.894559    two
# 2013-01-04  0.889631 -2.085432 -0.357393 -0.823406  three
# 2013-01-06 -0.380834  0.644047  0.321080  0.008130  three

# %%
s1 = pd.Series([1,2,3,4,5,6],index = pd.date_range('20130102',periods= 6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %%
df.at[dates[0],'A'] = 0

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000 -0.561988  1.075385  0.735907  NaN
# 2013-01-02 -0.542667 -0.427250  0.162986 -1.614862  1.0
# 2013-01-03  1.001508  1.588235  0.161555  0.894559  2.0
# 2013-01-04  0.889631 -2.085432 -0.357393 -0.823406  3.0
# 2013-01-05 -1.235319  0.111006 -0.560676  1.186859  4.0
# 2013-01-06 -0.380834  0.644047  0.321080  0.008130  5.0

# %%
df.iat[0,1] = 0

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.000000  1.075385  0.735907  NaN
# 2013-01-02 -0.542667 -0.427250  0.162986 -1.614862  1.0
# 2013-01-03  1.001508  1.588235  0.161555  0.894559  2.0
# 2013-01-04  0.889631 -2.085432 -0.357393 -0.823406  3.0
# 2013-01-05 -1.235319  0.111006 -0.560676  1.186859  4.0
# 2013-01-06 -0.380834  0.644047  0.321080  0.008130  5.0

# %%
df.loc[:,'D'] = np.array([5]*len(df))

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  1.075385  5  NaN
# 2013-01-02 -0.542667 -0.427250  0.162986  5  1.0
# 2013-01-03  1.001508  1.588235  0.161555  5  2.0
# 2013-01-04  0.889631 -2.085432 -0.357393  5  3.0
# 2013-01-05 -1.235319  0.111006 -0.560676  5  4.0
# 2013-01-06 -0.380834  0.644047  0.321080  5  5.0

# %%
df2 = df.copy()

# %%
df2[df2>0] = -df2

# %%
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.075385 -5  NaN
# 2013-01-02 -0.542667 -0.427250 -0.162986 -5 -1.0
# 2013-01-03 -1.001508 -1.588235 -0.161555 -5 -2.0
# 2013-01-04 -0.889631 -2.085432 -0.357393 -5 -3.0
# 2013-01-05 -1.235319 -0.111006 -0.560676 -5 -4.0
# 2013-01-06 -0.380834 -0.644047 -0.321080 -5 -5.0

# %%
df1 = df.reindex(index = dates[0:4],columns = list(df.columns)+['E'])

# %%
df1
# Out:
#                    A         B         C  D    F   E
# 2013-01-01  0.000000  0.000000  1.075385  5  NaN NaN
# 2013-01-02 -0.542667 -0.427250  0.162986  5  1.0 NaN
# 2013-01-03  1.001508  1.588235  0.161555  5  2.0 NaN
# 2013-01-04  0.889631 -2.085432 -0.357393  5  3.0 NaN

# %%
df1.loc[dates[0]:dates[1],'E'] = 1

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  1.075385  5  NaN  1.0
# 2013-01-02 -0.542667 -0.427250  0.162986  5  1.0  1.0
# 2013-01-03  1.001508  1.588235  0.161555  5  2.0  NaN
# 2013-01-04  0.889631 -2.085432 -0.357393  5  3.0  NaN

# %%
df1.loc['20130101':'20130103',['A','D']]
# Out:
#                    A  D
# 2013-01-01  0.000000  5
# 2013-01-02 -0.542667  5
# 2013-01-03  1.001508  5

# %%
df1.dropna(how = 'any')
# Out:
#                    A        B         C  D    F    E
# 2013-01-02 -0.542667 -0.42725  0.162986  5  1.0  1.0

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  1.075385  5  NaN  1.0
# 2013-01-02 -0.542667 -0.427250  0.162986  5  1.0  1.0
# 2013-01-03  1.001508  1.588235  0.161555  5  2.0  NaN
# 2013-01-04  0.889631 -2.085432 -0.357393  5  3.0  NaN

# %%
df1.fillna(5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  1.075385  5  5.0  1.0
# 2013-01-02 -0.542667 -0.427250  0.162986  5  1.0  1.0
# 2013-01-03  1.001508  1.588235  0.161555  5  2.0  5.0
# 2013-01-04  0.889631 -2.085432 -0.357393  5  3.0  5.0

# %%
df.mean()
# Out:
# A   -0.044613
# B   -0.028232
# C    0.133823
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.518846
# 2013-01-02    1.038614
# 2013-01-03    1.950259
# 2013-01-04    1.289361
# 2013-01-05    1.463002
# 2013-01-06    2.116859
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8],index = dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s,axis = 'index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03  0.001508  0.588235 -0.838445  4.0  1.0
# 2013-01-04 -2.110369 -5.085432 -3.357393  2.0  0.0
# 2013-01-05 -6.235319 -4.888994 -5.560676  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  1.075385  5  NaN
# 2013-01-02 -0.542667 -0.427250  0.162986  5  1.0
# 2013-01-03  1.001508  1.588235  0.161555  5  2.0
# 2013-01-04  0.889631 -2.085432 -0.357393  5  3.0
# 2013-01-05 -1.235319  0.111006 -0.560676  5  4.0
# 2013-01-06 -0.380834  0.644047  0.321080  5  5.0

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000  1.075385   5   NaN
# 2013-01-02 -0.542667 -0.427250  1.238371  10   1.0
# 2013-01-03  0.458841  1.160985  1.399925  15   3.0
# 2013-01-04  1.348472 -0.924447  1.042533  20   6.0
# 2013-01-05  0.113153 -0.813442  0.481856  25  10.0
# 2013-01-06 -0.267681 -0.169395  0.802937  30  15.0

# %%
df.apply(lambda x:x.cumsum())
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000  1.075385   5   NaN
# 2013-01-02 -0.542667 -0.427250  1.238371  10   1.0
# 2013-01-03  0.458841  1.160985  1.399925  15   3.0
# 2013-01-04  1.348472 -0.924447  1.042533  20   6.0
# 2013-01-05  0.113153 -0.813442  0.481856  25  10.0
# 2013-01-06 -0.267681 -0.169395  0.802937  30  15.0

# %%
df.apply(lambda x:x.max() - x.min())
# Out:
# A    2.236827
# B    3.673667
# C    1.636061
# D    0.000000
# F    4.000000
# dtype: float64

# %%
df.apply(lambda x: x.max()-x.min(),axis = 1)
# Out:
# 2013-01-01    5.000000
# 2013-01-02    5.542667
# 2013-01-03    4.838445
# 2013-01-04    7.085432
# 2013-01-05    6.235319
# 2013-01-06    5.380834
# Freq: D, dtype: float64

# %%
s = pd.Series(np.random.randint(0,7,size = 10))

# %%
s
# Out:
# 0    5
# 1    5
# 2    0
# 3    5
# 4    6
# 5    5
# 6    1
# 7    3
# 8    1
# 9    1
# dtype: int32

# %%
s.value_counts()
# Out:
# 5    4
# 1    3
# 6    1
# 3    1
# 0    1
# dtype: int64

# %%
s = pd.Series(['A','B','C','Aaba','Baca',np.nan,'CABA','dog','cat'])

# %%
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5     NaN
# 6    CABA
# 7     dog
# 8     cat
# dtype: object

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10,4))

# %%
df
# Out:
#           0         1         2         3
# 0 -0.729512 -1.289645 -0.185956  0.460838
# 1 -1.243817 -0.706710  1.455102  1.284571
# 2 -0.752476 -0.078989  0.104431 -1.493394
# 3  1.165668 -0.446893 -1.433319 -0.062365
# 4  0.870534  3.062475 -0.358734  0.186429
# 5  0.610090 -0.465848  0.787512  0.269486
# 6 -1.274986 -0.343757 -1.279479  0.508625
# 7  0.401401 -0.311760  0.834925 -0.087277
# 8 -1.656625 -2.163299 -1.019592 -0.058642
# 9  1.089747  0.571007  0.867712 -0.315556

# %%
pieces = [df[:3],df[3:7],df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.729512 -1.289645 -0.185956  0.460838
# 1 -1.243817 -0.706710  1.455102  1.284571
# 2 -0.752476 -0.078989  0.104431 -1.493394
# 3  1.165668 -0.446893 -1.433319 -0.062365
# 4  0.870534  3.062475 -0.358734  0.186429
# 5  0.610090 -0.465848  0.787512  0.269486
# 6 -1.274986 -0.343757 -1.279479  0.508625
# 7  0.401401 -0.311760  0.834925 -0.087277
# 8 -1.656625 -2.163299 -1.019592 -0.058642
# 9  1.089747  0.571007  0.867712 -0.315556

# %%
left = pd.DataFrame({'key':['foo','foo'],'lval':[1,2]})

# %%
right = pd.DataFrame({'key':['foo','foo'],'rval':[4,5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left,right,on = 'key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
pd.merge(left,right,on = 'key',how = 'inner')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key':['foo','bar'],'lval':[1,2]})

# %%
right = pd.DataFrame({'key':['foo','bar'],'rval':[4,5]})

# %%
pd.merge(left,right,on = 'key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
pd.merge(left,right,on = 'key',how = 'outer')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df10 = pd.DataFrame({'A':np.array([np.nan,3,8,5]),
                       'B':np.array([np.nan]*4),
                        'C':1.0})

# %%
df10
# Out:
#      A   B    C
# 0  NaN NaN  1.0
# 1  3.0 NaN  1.0
# 2  8.0 NaN  1.0
# 3  5.0 NaN  1.0

# %%
df10.fillna(5)
# Out:
#      A    B    C
# 0  5.0  5.0  1.0
# 1  3.0  5.0  1.0
# 2  8.0  5.0  1.0
# 3  5.0  5.0  1.0

# %%
df10 = pd.Series([1,np.nan,np.nan,10,2])

# %%
df10
# Out:
# 0     1.0
# 1     NaN
# 2     NaN
# 3    10.0
# 4     2.0
# dtype: float64

# %%
df10.fillna(value = 1,limit = 1)
# Out:
# 0     1.0
# 1     1.0
# 2     NaN
# 3    10.0
# 4     2.0
# dtype: float64

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  1.075385  5  NaN  1.0
# 2013-01-02 -0.542667 -0.427250  0.162986  5  1.0  1.0
# 2013-01-03  1.001508  1.588235  0.161555  5  2.0  NaN
# 2013-01-04  0.889631 -2.085432 -0.357393  5  3.0  NaN

# %%
df1.reindex(index = dates[0:4],columns = list('TYUIOP'))
# Out:
#              T   Y   U   I   O   P
# 2013-01-01 NaN NaN NaN NaN NaN NaN
# 2013-01-02 NaN NaN NaN NaN NaN NaN
# 2013-01-03 NaN NaN NaN NaN NaN NaN
# 2013-01-04 NaN NaN NaN NaN NaN NaN

# %%
df = pd.DataFrame(np.arange(9).reshape(3,3),index = list('abc'))

# %%
df
# Out:
#    0  1  2
# a  0  1  2
# b  3  4  5
# c  6  7  8

# %%
df.reindex(index = list('abcd'),fill_value = 5)
# Out:
#    0  1  2
# a  0  1  2
# b  3  4  5
# c  6  7  8
# d  5  5  5

# %%
dates = pd.date_range('20130101',periods = 6)
df = pd.DataFrame(np.random.randn(6,4),index = dates,columns = list('ABCD'))

# %%
df.sort_index(axis=1,ascending = False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.650695  0.421827  0.736741  2.139302
# 2013-01-02  1.231565  0.168660 -0.150632  0.128706
# 2013-01-03 -0.833529  0.808109 -0.288775 -0.122669
# 2013-01-04 -0.775611  0.184000  1.191757  1.106694
# 2013-01-05  0.057211 -1.626087  0.670150  0.868394
# 2013-01-06 -0.527751  0.713755  0.766983  0.315198

# %%
df = pd.DataFrame(np.random.randn(8,4),columns = ['A','B','C','D'])

# %%
s = df.iloc[2]

# %%
df.append(s,ignore_index = True)
# Out:
#           A         B         C         D
# 0 -1.195759 -1.485010  2.242953  0.004903
# 1 -0.057418 -0.930966  1.826522  1.213711
# 2  0.600181 -0.805546  0.616090 -1.213643
# 3 -0.654348 -1.045977 -0.256079 -0.476545
# 4  1.389485  0.647408  0.195789  1.082701
# 5  0.358990 -0.595327 -1.385683 -0.406375
# 6 -1.121137 -0.487158  1.503180 -0.506729
# 7 -0.051324 -1.176529  0.559784  0.287043
# 8  0.600181 -0.805546  0.616090 -1.213643

# %%
left = pd.DataFrame({'key': ['foo', 'for'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'fok'], 'rval': [4, 5]})

# %%
df = pd.merge(left, right, how='left')

# %%
df
# Out:
#    key  lval  rval
# 0  foo     1   4.0
# 1  for     2   NaN

# %%
df = pd.DataFrame(
[[4, 7, 10],
[5, 8, 11],
[6, 9, 12],
[6, 9, 12],],
index=[1, 2, 3,4],
columns=['a', 'b', 'c'])

# %%
pieces = [df[:1], df[1:2], df[2:]]

# %%
pieces
# Out:
# [   a  b   c
#  1  4  7  10,    a  b   c
#  2  5  8  11,    a  b   c
#  3  6  9  12
#  4  6  9  12]

# %%
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.075385 -5  NaN
# 2013-01-02 -0.542667 -0.427250 -0.162986 -5 -1.0
# 2013-01-03 -1.001508 -1.588235 -0.161555 -5 -2.0
# 2013-01-04 -0.889631 -2.085432 -0.357393 -5 -3.0
# 2013-01-05 -1.235319 -0.111006 -0.560676 -5 -4.0
# 2013-01-06 -0.380834 -0.644047 -0.321080 -5 -5.0

# %%
df1 = df2.reindex(index = dates[0:4],columns = list(df2.columns)+['E'])

# %%
df1
# Out:
#                    A         B         C  D    F   E
# 2013-01-01  0.000000  0.000000 -1.075385 -5  NaN NaN
# 2013-01-02 -0.542667 -0.427250 -0.162986 -5 -1.0 NaN
# 2013-01-03 -1.001508 -1.588235 -0.161555 -5 -2.0 NaN
# 2013-01-04 -0.889631 -2.085432 -0.357393 -5 -3.0 NaN

# %%
df1.loc[dates[0]:dates[1],'E'] = 1

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -1.075385 -5  NaN  1.0
# 2013-01-02 -0.542667 -0.427250 -0.162986 -5 -1.0  1.0
# 2013-01-03 -1.001508 -1.588235 -0.161555 -5 -2.0  NaN
# 2013-01-04 -0.889631 -2.085432 -0.357393 -5 -3.0  NaN

# %%
df1.dropna(how = 'any')
# Out:
#                    A        B         C  D    F    E
# 2013-01-02 -0.542667 -0.42725 -0.162986 -5 -1.0  1.0

# %%
df1.dropna(how = 'all')
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -1.075385 -5  NaN  1.0
# 2013-01-02 -0.542667 -0.427250 -0.162986 -5 -1.0  1.0
# 2013-01-03 -1.001508 -1.588235 -0.161555 -5 -2.0  NaN
# 2013-01-04 -0.889631 -2.085432 -0.357393 -5 -3.0  NaN

# %%
df1.fillna(value = 5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -1.075385 -5  5.0  1.0
# 2013-01-02 -0.542667 -0.427250 -0.162986 -5 -1.0  1.0
# 2013-01-03 -1.001508 -1.588235 -0.161555 -5 -2.0  5.0
# 2013-01-04 -0.889631 -2.085432 -0.357393 -5 -3.0  5.0

# %%
df1.fillna(5,limit = 1)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -1.075385 -5  5.0  1.0
# 2013-01-02 -0.542667 -0.427250 -0.162986 -5 -1.0  1.0
# 2013-01-03 -1.001508 -1.588235 -0.161555 -5 -2.0  5.0
# 2013-01-04 -0.889631 -2.085432 -0.357393 -5 -3.0  NaN

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -1.075385 -5  NaN  1.0
# 2013-01-02 -0.542667 -0.427250 -0.162986 -5 -1.0  1.0
# 2013-01-03 -1.001508 -1.588235 -0.161555 -5 -2.0  NaN
# 2013-01-04 -0.889631 -2.085432 -0.357393 -5 -3.0  NaN

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# a     5.25
# b     8.25
# c    11.25
# dtype: float64

# %%
df2.mean()
# Out:
# A   -0.674993
# B   -0.809328
# C   -0.439846
# D   -5.000000
# F   -3.000000
# dtype: float64

# %%
df2.mean(1)
# Out:
# 2013-01-01   -1.518846
# 2013-01-02   -1.426580
# 2013-01-03   -1.950259
# 2013-01-04   -2.266491
# 2013-01-05   -2.181400
# 2013-01-06   -2.269192
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8],index = dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df2.sub(s,axis = 'index')
# Out:
#                    A         B         C     D    F
# 2013-01-01       NaN       NaN       NaN   NaN  NaN
# 2013-01-02       NaN       NaN       NaN   NaN  NaN
# 2013-01-03 -2.001508 -2.588235 -1.161555  -6.0 -3.0
# 2013-01-04 -3.889631 -5.085432 -3.357393  -8.0 -6.0
# 2013-01-05 -6.235319 -5.111006 -5.560676 -10.0 -9.0
# 2013-01-06       NaN       NaN       NaN   NaN  NaN

# %%
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.075385 -5  NaN
# 2013-01-02 -0.542667 -0.427250 -0.162986 -5 -1.0
# 2013-01-03 -1.001508 -1.588235 -0.161555 -5 -2.0
# 2013-01-04 -0.889631 -2.085432 -0.357393 -5 -3.0
# 2013-01-05 -1.235319 -0.111006 -0.560676 -5 -4.0
# 2013-01-06 -0.380834 -0.644047 -0.321080 -5 -5.0

# %%
df.apply(np.cumsum)
# Out:
#     a   b   c
# 1   4   7  10
# 2   9  15  21
# 3  15  24  33
# 4  21  33  45

# %%
df2.apply(lambda x: x.max()-x.min())
# Out:
# A    1.235319
# B    2.085432
# C    0.913830
# D    0.000000
# F    4.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0,7,size = 10))

# %%
s
# Out:
# 0    0
# 1    2
# 2    2
# 3    5
# 4    1
# 5    0
# 6    2
# 7    6
# 8    1
# 9    4
# dtype: int32

# %%
s.value_counts()
# Out:
# 2    3
# 1    2
# 0    2
# 6    1
# 5    1
# 4    1
# dtype: int64

# %%
s =pd.Series(['A','B','C','Aaba','Baca',np.nan,'CABA','dog','cat'])

# %%
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5     NaN
# 6    CABA
# 7     dog
# 8     cat
# dtype: object

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(8,4),columns = ['A','B','C','D'])

# %%
df
# Out:
#           A         B         C         D
# 0 -0.830872 -0.717335  0.733848  1.066337
# 1 -1.362004  0.069791  0.489168  1.935203
# 2 -1.231555  0.459950  0.837751  0.013733
# 3 -1.012315 -1.167266  0.590398 -0.539409
# 4 -1.962771 -0.615933 -0.363226  0.981181
# 5  0.598701  0.596761 -0.573647  0.065259
# 6 -0.515611  0.266502 -0.956835  0.157361
# 7 -1.115193  0.805936 -1.720726  0.671901

# %%
s = df.iloc[3]

# %%
df.append(s,ignore_index = True)
# Out:
#           A         B         C         D
# 0 -0.830872 -0.717335  0.733848  1.066337
# 1 -1.362004  0.069791  0.489168  1.935203
# 2 -1.231555  0.459950  0.837751  0.013733
# 3 -1.012315 -1.167266  0.590398 -0.539409
# 4 -1.962771 -0.615933 -0.363226  0.981181
# 5  0.598701  0.596761 -0.573647  0.065259
# 6 -0.515611  0.266502 -0.956835  0.157361
# 7 -1.115193  0.805936 -1.720726  0.671901
# 8 -1.012315 -1.167266  0.590398 -0.539409

# %%
df = pd.DataFrame({'A':['foo','bar','foo','bar','foo','bar','foo','foo'],
                  'B':['one','one','two','three','two','two','one','three'],
                  'C':np.random.randn(8),
                  'D':np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  1.311472  0.081587
# 1  bar    one -0.379372 -0.458939
# 2  foo    two -0.078349 -0.084715
# 3  bar  three  0.413776 -0.841209
# 4  foo    two -1.227827  1.099111
# 5  bar    two  0.662310  0.021329
# 6  foo    one -0.539739 -0.558149
# 7  foo  three  1.728087 -0.504970

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  0.696715 -1.278819
# foo  1.193644  0.032863

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.379372 -0.458939
#     three  0.413776 -0.841209
#     two    0.662310  0.021329
# foo one    0.771733 -0.476562
#     three  1.728087 -0.504970
#     two   -1.306177  1.014396

# %%
tuples = list(zip(*[['bar','bar','baz','baz','foo','foo','qux','qux'],
                   ['one','two','one','two','one','two','onw','two']]))

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'onw'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples,names = ['first','second'])

# %%
index
# Out:
# MultiIndex(levels=[['bar', 'baz', 'foo', 'qux'], ['one', 'onw', 'two']],
#            labels=[[0, 0, 1, 1, 2, 2, 3, 3], [0, 2, 0, 2, 0, 2, 1, 2]],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8,2),index = index,columns = ['A','B'])

# %%
df
# Out:
#                      A         B
# first second
# bar   one    -0.556892 -0.244161
#       two    -1.816588 -0.097912
# baz   one     1.161323 -2.363577
#       two     2.080299  0.735094
# foo   one    -0.684414 -0.307632
#       two     1.322011 -1.073080
# qux   onw    -2.034756 -0.594092
#       two     1.674819 -0.768045

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -0.556892 -0.244161
#       two    -1.816588 -0.097912
# baz   one     1.161323 -2.363577
#       two     2.080299  0.735094

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -0.556892
#                B   -0.244161
#        two     A   -1.816588
#                B   -0.097912
# baz    one     A    1.161323
#                B   -2.363577
#        two     A    2.080299
#                B    0.735094
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.556892 -0.244161
#       two    -1.816588 -0.097912
# baz   one     1.161323 -2.363577
#       two     2.080299  0.735094

# %%
df = pd.DataFrame({'A':['one','one','two','three']*3,
                  'B':['A','B','C']*4,
                  'C':['foo','foo','foo','bar','bar','bar']*2,
                  'D':np.random.randn(12),
                  'E':np.random.randn(12)})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.365903 -0.995224
# 1     one  B  foo  0.783964  2.297724
# 2     two  C  foo  1.506095 -0.860712
# 3   three  A  bar  0.984270  0.967085
# 4     one  B  bar -1.487142 -1.337311
# 5     one  C  bar  0.075122  1.011454
# 6     two  A  foo  0.090396 -0.000280
# 7   three  B  foo -0.903841 -0.464662
# 8     one  C  foo  0.877024 -0.284275
# 9     one  A  bar  0.424160 -2.405279
# 10    two  B  bar -1.017753 -0.629875
# 11  three  C  bar  1.553268 -1.486238

# %%
pd.pivot_table(df,values = 'D',index = ['A','B'],columns = ['C'])
# Out:
# C             bar       foo
# A     B
# one   A  0.424160 -0.365903
#       B -1.487142  0.783964
#       C  0.075122  0.877024
# three A  0.984270       NaN
#       B       NaN -0.903841
#       C  1.553268       NaN
# two   A       NaN  0.090396
#       B -1.017753       NaN
#       C       NaN  1.506095

# %%
rng = pd.date_range('1/1/2012',periods = 100,freq = 'S')

# %%
ts = pd.Series(np.random.randint(0,500,len(rng)),index = rng)

# %%
ts
# Out:
# 2012-01-01 00:00:00    235
# 2012-01-01 00:00:01    348
# 2012-01-01 00:00:02    186
# 2012-01-01 00:00:03    476
# 2012-01-01 00:00:04     14
# 2012-01-01 00:00:05    120
# 2012-01-01 00:00:06    274
# 2012-01-01 00:00:07     25
# 2012-01-01 00:00:08    289
# 2012-01-01 00:00:09    278
# 2012-01-01 00:00:10    179
# 2012-01-01 00:00:11    397
# 2012-01-01 00:00:12    172
# 2012-01-01 00:00:13    187
# 2012-01-01 00:00:14    467
# 2012-01-01 00:00:15    301
# 2012-01-01 00:00:16    239
# 2012-01-01 00:00:17    174
# 2012-01-01 00:00:18    489
# 2012-01-01 00:00:19     83
# 2012-01-01 00:00:20    247
# 2012-01-01 00:00:21    195
# 2012-01-01 00:00:22      4
# 2012-01-01 00:00:23    466
# 2012-01-01 00:00:24    453
# 2012-01-01 00:00:25     84
# 2012-01-01 00:00:26    459
# 2012-01-01 00:00:27     80
# 2012-01-01 00:00:28    207
# 2012-01-01 00:00:29    209
#                       ...
# 2012-01-01 00:01:10    464
# 2012-01-01 00:01:11    315
# 2012-01-01 00:01:12    288
# ...

# %%
ts.resample('5Min').sum()
# Out:
# 2012-01-01    25558
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range('3/6/2012 00:00',periods = 5,freq = 'D')

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)),rng)

# %%
ts
# Out:
# 2012-03-06   -0.314361
# 2012-03-07    0.491381
# 2012-03-08    0.391420
# 2012-03-09   -0.792904
# 2012-03-10   -0.008607
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.314361
# 2012-03-07 00:00:00+00:00    0.491381
# 2012-03-08 00:00:00+00:00    0.391420
# 2012-03-09 00:00:00+00:00   -0.792904
# 2012-03-10 00:00:00+00:00   -0.008607
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00   -0.314361
# 2012-03-06 19:00:00-05:00    0.491381
# 2012-03-07 19:00:00-05:00    0.391420
# 2012-03-08 19:00:00-05:00   -0.792904
# 2012-03-09 19:00:00-05:00   -0.008607
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012',periods = 5,freq = 'M')

# %%
rng
# Out:
# DatetimeIndex(['2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30',
#                '2012-05-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts = pd.Series(np.random.randn(len(rng)),index = rng)

# %%
ts
# Out:
# 2012-01-31   -0.294450
# 2012-02-29    0.712841
# 2012-03-31   -1.018065
# 2012-04-30    0.097740
# 2012-05-31   -1.357615
# Freq: M, dtype: float64

# %%
ps = ts.to_period()

# %%
ps
# Out:
# 2012-01   -0.294450
# 2012-02    0.712841
# 2012-03   -1.018065
# 2012-04    0.097740
# 2012-05   -1.357615
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01   -0.294450
# 2012-02-01    0.712841
# 2012-03-01   -1.018065
# 2012-04-01    0.097740
# 2012-05-01   -1.357615
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1','2000Q4',freq = 'Q-NOV')

# %%
prng
# Out:
# PeriodIndex(['1990Q1', '1990Q2', '1990Q3', '1990Q4', '1991Q1', '1991Q2',
#              '1991Q3', '1991Q4', '1992Q1', '1992Q2', '1992Q3', '1992Q4',
#              '1993Q1', '1993Q2', '1993Q3', '1993Q4', '1994Q1', '1994Q2',
#              '1994Q3', '1994Q4', '1995Q1', '1995Q2', '1995Q3', '1995Q4',
#              '1996Q1', '1996Q2', '1996Q3', '1996Q4', '1997Q1', '1997Q2',
#              '1997Q3', '1997Q4', '1998Q1', '1998Q2', '1998Q3', '1998Q4',
#              '1999Q1', '1999Q2', '1999Q3', '1999Q4', '2000Q1', '2000Q2',
#              '2000Q3', '2000Q4'],
#             dtype='period[Q-NOV]', freq='Q-NOV')

# %%
ts = pd.Series(np.random.randn(len(prng)),prng)

# %%
ts
# Out:
# 1990Q1   -0.792377
# 1990Q2    0.372386
# 1990Q3    0.442264
# 1990Q4    0.774093
# 1991Q1   -0.994501
# 1991Q2    0.019936
# 1991Q3   -1.148833
# 1991Q4    1.161177
# 1992Q1   -0.955284
# 1992Q2   -1.348912
# 1992Q3    0.398253
# 1992Q4    0.760618
# 1993Q1    0.308653
# 1993Q2   -0.529841
# 1993Q3    0.457676
# 1993Q4   -0.707102
# 1994Q1   -0.384925
# 1994Q2    0.632388
# 1994Q3   -0.902006
# 1994Q4   -1.826091
# 1995Q1   -2.665144
# 1995Q2   -0.813921
# 1995Q3   -0.654884
# 1995Q4    1.428195
# 1996Q1   -2.550347
# 1996Q2    1.357561
# 1996Q3    0.891354
# 1996Q4    0.929030
# 1997Q1    0.322363
# 1997Q2   -1.316086
# 1997Q3    0.263221
# 1997Q4   -0.070168
# 1998Q1   -0.082936
# 1998Q2   -1.011450
# 1998Q3    0.346681
# 1998Q4    0.365397
# 1999Q1   -0.159980
# 1999Q2   -0.710221
# 1999Q3   -0.774759
# 1999Q4    0.568507
# 2000Q1   -0.379214
# 2000Q2    0.748843
# 2000Q3    0.045112
# 2000Q4    0.180785
# Freq: Q-NOV, dtype: float64

# %%
ts.index = (prng.asfreq('M','e')+1).asfreq('H','s')+9

# %%
ts.index
# Out:
# PeriodIndex(['1990-03-01 09:00', '1990-06-01 09:00', '1990-09-01 09:00',
#              '1990-12-01 09:00', '1991-03-01 09:00', '1991-06-01 09:00',
#              '1991-09-01 09:00', '1991-12-01 09:00', '1992-03-01 09:00',
#              '1992-06-01 09:00', '1992-09-01 09:00', '1992-12-01 09:00',
#              '1993-03-01 09:00', '1993-06-01 09:00', '1993-09-01 09:00',
#              '1993-12-01 09:00', '1994-03-01 09:00', '1994-06-01 09:00',
#              '1994-09-01 09:00', '1994-12-01 09:00', '1995-03-01 09:00',
#              '1995-06-01 09:00', '1995-09-01 09:00', '1995-12-01 09:00',
#              '1996-03-01 09:00', '1996-06-01 09:00', '1996-09-01 09:00',
#              '1996-12-01 09:00', '1997-03-01 09:00', '1997-06-01 09:00',
#              '1997-09-01 09:00', '1997-12-01 09:00', '1998-03-01 09:00',
#              '1998-06-01 09:00', '1998-09-01 09:00', '1998-12-01 09:00',
#              '1999-03-01 09:00', '1999-06-01 09:00', '1999-09-01 09:00',
# ...

# %%
df = pd.DataFrame({'id':[1,2,3,4,5,6],'raw_grade':['a','b','b','a','a','e']})

# %%
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df['grade'] = df['raw_grade'].astype('category')

# %%
df['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
ts = pd.Series(np.random.randn(1000),index = pd.date_range('1/1/2000',periods = 1000))

# %%
ts.head()
# Out:
# 2000-01-01    0.750466
# 2000-01-02    1.012621
# 2000-01-03    0.031117
# 2000-01-04   -0.801684
# 2000-01-05   -0.046484
# Freq: D, dtype: float64

# %%
ts = ts.cumsum()

# %%
ts.head()
# Out:
# 2000-01-01    0.750466
# 2000-01-02    1.763086
# 2000-01-03    1.794203
# 2000-01-04    0.992519
# 2000-01-05    0.946036
# Freq: D, dtype: float64

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000,4),index = ts.index,columns = list('ABCD'))

# %%
df = df.cumsum()

# %%
df
# Out:
#                     A          B          C          D
# 2000-01-01  -0.302792   1.586798  -0.831334   0.434259
# 2000-01-02   0.778138   0.179003   0.181235  -0.280828
# 2000-01-03   0.334279  -0.441389  -0.435750   0.935961
# 2000-01-04   0.599925  -2.054442  -0.745360  -0.471157
# 2000-01-05  -0.162138  -1.290219  -1.244385   0.003597
# 2000-01-06  -0.125263  -1.592576  -0.211679   0.785662
# 2000-01-07   0.625183  -2.370822  -0.510037   1.011512
# 2000-01-08   0.830780  -1.254792   0.097336   0.891665
# 2000-01-09   0.032612  -0.536694  -0.677619  -1.636911
# 2000-01-10   1.119529  -3.524504  -2.828647  -2.437704
# 2000-01-11   0.527157  -3.240441  -2.230661  -2.719701
# 2000-01-12  -1.899135  -3.012612  -2.286142  -2.815751
# 2000-01-13  -3.087856  -3.610085  -0.527587  -2.693972
# 2000-01-14  -3.274859  -2.856809  -2.926243  -1.800817
# 2000-01-15  -4.137385  -3.337453  -2.986193   0.149256
# 2000-01-16  -6.209872  -2.005280  -4.489295   2.761083
# ...

# %%
plt.figure()
df.plot()
plt.legend(loc = 'best')

# %%
df.to_hdf('foo.h5','df')

# %%
pd.read_hdf('foo.h5','df')
# Out:
#                     A          B          C          D
# 2000-01-01  -0.302792   1.586798  -0.831334   0.434259
# 2000-01-02   0.778138   0.179003   0.181235  -0.280828
# 2000-01-03   0.334279  -0.441389  -0.435750   0.935961
# 2000-01-04   0.599925  -2.054442  -0.745360  -0.471157
# 2000-01-05  -0.162138  -1.290219  -1.244385   0.003597
# 2000-01-06  -0.125263  -1.592576  -0.211679   0.785662
# 2000-01-07   0.625183  -2.370822  -0.510037   1.011512
# 2000-01-08   0.830780  -1.254792   0.097336   0.891665
# 2000-01-09   0.032612  -0.536694  -0.677619  -1.636911
# 2000-01-10   1.119529  -3.524504  -2.828647  -2.437704
# 2000-01-11   0.527157  -3.240441  -2.230661  -2.719701
# 2000-01-12  -1.899135  -3.012612  -2.286142  -2.815751
# 2000-01-13  -3.087856  -3.610085  -0.527587  -2.693972
# 2000-01-14  -3.274859  -2.856809  -2.926243  -1.800817
# 2000-01-15  -4.137385  -3.337453  -2.986193   0.149256
# 2000-01-16  -6.209872  -2.005280  -4.489295   2.761083
# ...

# %%
df.to_excel('foo.xlsx',sheet_name = '数据集')

# %%
pd.read_excel('foo.xlsx','数据集',index_col = None,na_values = ['NA'])
# Out:
#                     A          B          C          D
# 2000-01-01  -0.302792   1.586798  -0.831334   0.434259
# 2000-01-02   0.778138   0.179003   0.181235  -0.280828
# 2000-01-03   0.334279  -0.441389  -0.435750   0.935961
# 2000-01-04   0.599925  -2.054442  -0.745360  -0.471157
# 2000-01-05  -0.162138  -1.290219  -1.244385   0.003597
# 2000-01-06  -0.125263  -1.592576  -0.211679   0.785662
# 2000-01-07   0.625183  -2.370822  -0.510037   1.011512
# 2000-01-08   0.830780  -1.254792   0.097336   0.891665
# 2000-01-09   0.032612  -0.536694  -0.677619  -1.636911
# 2000-01-10   1.119529  -3.524504  -2.828647  -2.437704
# 2000-01-11   0.527157  -3.240441  -2.230661  -2.719701
# 2000-01-12  -1.899135  -3.012612  -2.286142  -2.815751
# 2000-01-13  -3.087856  -3.610085  -0.527587  -2.693972
# 2000-01-14  -3.274859  -2.856809  -2.926243  -1.800817
# 2000-01-15  -4.137385  -3.337453  -2.986193   0.149256
# 2000-01-16  -6.209872  -2.005280  -4.489295   2.761083
# ...
