# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
location = r'C:\Users\16677\Desktop\123\train.csv'#csv格式文件的路径

# %%
import matplotlib.pyplot as plt # plt 用于显示图片
import matplotlib.image as mpimg # mpimg 用于读取图片
lena = mpimg.imread(r'C:\Users\16677\Desktop\123\泰坦尼克号.jpg') # 读取和代码处于同一目录下的 lena.png
plt.imshow(lena) # 显示图片
plt.axis('off') # 不显示坐标轴
plt.show()

# %%
from IPython.display import Image
Image(r'C:\Users\16677\Desktop\123\泰坦尼克号.jpg')

# %%
df = pd.read_csv(location)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()# 通过这个方法我们可以分析一下那些列可以使用，哪些列要丢弃，哪些列要填充，填充规则是怎样，是填充平均值还是randn，
#这个仁者见仁，智者见智，操作者本身要知道对数据有什么影响
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#df.Embarked.astype(np.object)#更改数据类型，在pd自动识别错误的情况下

# %%
df.Survived.value_counts()#总共存活了多少人
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
len(df[df.Survived ==1])#总共存活了多少人
# Out:
# 342

# %%
df[df.Survived == 1].size#size包含空值，count不包含空值
# Out:
# 4104

# %%
df.Survived.value_counts().plot.bar()#用柱状图画出死的和活着的人数

# %%
df.Survived.value_counts().plot.pie(explode = [0,0.1],startangle = 90)#用柱状图画出死的和活着的人数

# %%
df1 = df.drop('Cabin',axis = 1)# 删除Cabin，因位这列数据大部分是空值，没用

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df1.Age = df1.Age.fillna(20)#为Age列的空值填充值

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df1[df1.Embarked.isnull()].index# Embarked(地区）列中两个空值
# Out:
# Int64Index([61, 829], dtype='int64')

# %%
df2 = df1.drop([61,829])#删除这两列空值

# %%
df2.pivot_table(values = 'PassengerId',index = 'Survived',columns = 'Sex',aggfunc = 'count')#透视表
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            231   109

# %% [markdown]
# ## 年龄对生存有没有影响

# %%
df2.Age.min()#年龄列的最小值
# Out:
# 0.42

# %%
df2.Age.max()#年龄列的最大值
# Out:
# 80.0

# %%
df2.Age.describe()#获取多个统计指标，在着要用4分位数
# Out:
# count    889.000000
# mean      27.722351
# std       13.528474
# min        0.420000
# 25%       20.000000
# 50%       24.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#Survived = df2[df2.Survived == 1]
#len(Survived)
#Survived.head()

# %%
df3 = df2[df2.Age<17]#小于17岁的位小孩

# %%
df4 = df2[df2.Age>50]#大于50岁的位老人

# %%
df5 = pd.concat([df3,df4])#合并两个数据集

# %%
df5.Survived.value_counts()#计算df5中活着的人
# Out:
# 0    87
# 1    76
# Name: Survived, dtype: int64

# %%
# coor ==>判断两个事物是否有关系  关系的强弱用绝对值来看 绝对值越大越有关系  正相关   值是正数

# %%
df['Survived'].corr(df['Pclass'])
# Out:
# -0.33848103596101475
