# %%
import numpy as np 
import pandas as pd

# %%
df1 = pd.DataFrame([[1,2,3,4],[5,6,7,8],[9,1,2,3]],columns=list('abcd'))

# %%
df2 = pd.DataFrame([[9,8,7,1],[6,5,4,2],[3,2,1,0]],columns=list('zxcv'))

# %%
pd.concat([df1,df2])
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.
#      a    b  c    d    v    x    z
# 0  1.0  2.0  3  4.0  NaN  NaN  NaN
# 1  5.0  6.0  7  8.0  NaN  NaN  NaN
# 2  9.0  1.0  2  3.0  NaN  NaN  NaN
# 0  NaN  NaN  7  NaN  1.0  8.0  9.0
# 1  NaN  NaN  4  NaN  2.0  5.0  6.0
# 2  NaN  NaN  1  NaN  0.0  2.0  3.0

# %%
df1
# Out:
#    a  b  c  d
# 0  1  2  3  4
# 1  5  6  7  8
# 2  9  1  2  3

# %%
df2
# Out:
#    z  x  c  v
# 0  9  8  7  1
# 1  6  5  4  2
# 2  3  2  1  0

# %%
df1.append(df2,ignore_index=False)
# Out:
# D:\anaconda\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
#      a    b  c    d    v    x    z
# 0  1.0  2.0  3  4.0  NaN  NaN  NaN
# 1  5.0  6.0  7  8.0  NaN  NaN  NaN
# 2  9.0  1.0  2  3.0  NaN  NaN  NaN
# 0  NaN  NaN  7  NaN  1.0  8.0  9.0
# 1  NaN  NaN  4  NaN  2.0  5.0  6.0
# 2  NaN  NaN  1  NaN  0.0  2.0  3.0

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    a  b  c  d  z  x  c  v
# 0  1  2  3  4  9  8  7  1
# 1  5  6  7  8  6  5  4  2
# 2  9  1  2  3  3  2  1  0

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
chipo = pd.read_csv(url,sep='\t')

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %% [markdown]
#  # step4

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# #  step 5

# %%
len(chipo)
# Out:
# 4622

# %%
chipo.shape[0]
# Out:
# 4622

# %%
chipo.shape
# Out:
# (4622, 5)

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %% [markdown]
# # step6

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# #  step7

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# # step8

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
chipo.loc[1]
# Out:
# order_id                         1
# quantity                         1
# item_name                     Izze
# choice_description    [Clementine]
# item_price                  $3.39
# Name: 1, dtype: object

# %% [markdown]
# # step9

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
a = chipo.groupby('item_name').sum()

# %%
a.quantity.sort_values(ascending=False).head(1)
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %% [markdown]
# # step10

# %%
a2 = chipo.groupby(by=['item_name']).sum()

# %%
a2['quantity'].sort_values(ascending=False).head(1)
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %% [markdown]
# # step11

# %%
chipo.groupby('choice_description').sum().sort_values(['quantity'],ascending=False).head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
chipo.groupby('choice_description').sum()['quantity'].sort_values(ascending=False).head(1)
# Out:
# choice_description
# [Diet Coke]    159
# Name: quantity, dtype: int64

# %% [markdown]
# # step12

# %%
chipo.quantity.sum()
# Out:
# 4972

# %% [markdown]
# # step13

# %%
chipo.item_price.dtypes
# Out:
# dtype('O')

# %%
chipo.item_price.apply(lambda x: float(x[1:-1]))
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
# 5       10.98
# 6        1.69
# 7       11.75
# 8        9.25
# 9        9.25
# 10       4.45
# 11       8.75
# 12       8.75
# 13      11.25
# 14       4.45
# 15       2.39
# 16       8.49
# 17       8.49
# 18       2.18
# 19       8.75
# 20       4.45
# 21       8.99
# 22       3.39
# 23      10.98
# 24       3.39
# 25       2.39
# 26       8.49
# 27       8.99
# 28       1.09
# 29       8.49
#         ...
# 4592    11.75
# 4593    11.75
# 4594    11.75
# 4595     8.75
# 4596     4.45
# 4597     1.25
# 4598     1.50
# 4599     8.75
# 4600     4.45
# 4601     1.25
# 4602     9.25
# 4603     9.25
# 4604     8.75
# 4605     4.45
# 4606     1.25
# 4607    11.75
# 4608    11.25
# 4609     1.25
# 4610    11.75
# 4611    11.25
# 4612     9.25
# 4613     2.15
# 4614     1.50
# 4615     8.75
# 4616     4.45
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# ...

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# # step14

# %%
(chipo.quantity*chipo.item_price.apply(lambda x: float(x[1:-1]))).sum()
# Out:
# 39237.02

# %% [markdown]
# # step15

# %%
chipo.order_id.value_counts().count()
# Out:
# 1834

# %% [markdown]
# # step 16

# %%
chipo.revenue = chipo.item_price*chipo.item_price
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\anaconda\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1008         try:
# -> 1009             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1010         except TypeError:
#
# D:\anaconda\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# D:\anaconda\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %% [markdown]
# # step17

# %%
chipo.item_name.value_counts().count()
# Out:
# 50
