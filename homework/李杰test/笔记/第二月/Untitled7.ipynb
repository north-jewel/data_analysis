# %%
import numpy as np
import pandas as pd

# %%
np.convolve(np.array([1,2,3,4]),np.array([3,4]))
# Out:
# array([ 3, 10, 17, 24, 16])

# %%
np.convolve(np.array([1,2,3,4]),np.array([3,4]),'valid')
# Out:
# array([10, 17, 24])

# %%
        #[1,2]
      #[6,5,4]

# %%
   #[1,2,3,4]
  #[6,5,4]

# %%
#array([ 3, 10, 17, 24, 31, 20])

# %%
np.convolve(np.array([1,1,1,1,0,1,1,1,1,]),np.array([1,1,1,0,0,1,0,1]),'valid')
# Out:
# array([5, 5])

# %%
np.convolve(np.array([1,1,1,1,1,1,1,1]),np.array([1,0,1,0,0,1,0,0]))
# Out:
# array([1, 1, 2, 2, 2, 3, 3, 3, 2, 2, 1, 1, 1, 0, 0])

# %%
import matplotlib 


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import Image
from IPython.display import *

# %matplotlib inline

# %%
matplotlib.__version__
# Out:
# '2.2.2'

# %%
df = pd.read_csv(r'C:\Users\Administrator\tutorail\weather_2012.csv')

# %%
df
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# 5     2012-01-01 05:00:00      -1.4                -3.3           87
# 6     2012-01-01 06:00:00      -1.5                -3.1           89
# 7     2012-01-01 07:00:00      -1.4                -3.6           85
# 8     2012-01-01 08:00:00      -1.4                -3.6           85
# 9     2012-01-01 09:00:00      -1.3                -3.1           88
# 10    2012-01-01 10:00:00      -1.0                -2.3           91
# 11    2012-01-01 11:00:00      -0.5                -2.1           89
# 12    2012-01-01 12:00:00      -0.2                -2.0           88
# ...

# %%
df.shape
# Out:
# (8784, 8)

# %% [markdown]
# ## simple plot

# %%
pd.set_option('display.mpl_style', 'default')
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-11-e13e29d3e7fa> in <module>()
# ----> 1 pd.set_option('display.mpl_style', 'default')
#
# D:\anaconda\lib\site-packages\pandas\core\config.py in __call__(self, *args, **kwds)
#     225
#     226     def __call__(self, *args, **kwds):
# --> 227         return self.__func__(*args, **kwds)
#     228
#     229     @property
#
# D:\anaconda\lib\site-packages\pandas\core\config.py in _set_option(*args, **kwargs)
#     117
#     118     for k, v in zip(args[::2], args[1::2]):
# --> 119         key = _get_single_key(k, silent)
#     120
#     121         o = _get_registered_option(key)
#
# D:\anaconda\lib\site-packages\pandas\core\config.py in _get_single_key(pat, silent)
#      81         if not silent:
#      82             _warn_if_deprecated(pat)
# ...

# %%
weather_2012_final = pd.read_csv(r'C:\Users\Administrator\tutorail\weather_2012.csv',index_col='Date/Time')

# %%
weather_2012_final
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
# 2012-01-01 05:00:00      -1.4                -3.3           87
# 2012-01-01 06:00:00      -1.5                -3.1           89
# 2012-01-01 07:00:00      -1.4                -3.6           85
# 2012-01-01 08:00:00      -1.4                -3.6           85
# 2012-01-01 09:00:00      -1.3                -3.1           88
# 2012-01-01 10:00:00      -1.0                -2.3           91
# 2012-01-01 11:00:00      -0.5                -2.1           89
# 2012-01-01 12:00:00      -0.2                -2.0           88
# 2012-01-01 13:00:00       0.2                -1.7           87
# ...

# %%
weather_2012_finall['Temp (C)'].plot(figsize=(15,6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-197d6843ffd1> in <module>()
# ----> 1 weather_2012_finall['Temp (C)'].plot(figsize=(15,6))
#
# NameError: name 'weather_2012_finall' is not defined

# %%
print(weather_2012_final.shape)
weather_2012_final.head(5)
# Out:
# (8784, 7)
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather
# Date/Time
# 2012-01-01 00:00:00                   Fog
# ...

# %% [markdown]
# ## Histogram

# %%
np.random.seed(2018)
mu,sigma = 100,15
x = mu+sigma*np.random.randn(100000)
n,bins,patches = plt.hist(x,50,normed=1,facecolor='b',alpha=0.5)
# Out:
# D:\anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)


# create some data to use for the plot
#*rect* = [left, bottom, width, height] 

dt = 0.001
t = np.arange(0.0, 10.0, dt)
r = np.exp(-t[:1000] / 0.05)  # impulse response
x = np.random.randn(len(t))
s = np.convolve(x, r)[:len(x)] * dt  # colored noise

# %%
plt.plot(t, s)
plt.axis([0, 1, 1.1 * np.min(s), 2 * np.max(s)])
plt.xlabel('time (s)')
plt.ylabel('current (nA)')
plt.title('Gaussian colored noise')


a = plt.axes([.65,.6,.2,.2],facecolor='k')
n,bins,patches = plt.hist(s,40,normed=1)
plt.title('Probability')
plt.xticks([])
plt.yticks([])

a = plt.axes([0.2,0.6,.2,.2],facecolor='k')
plt.plot(t[:len(r)],r)
plt.title('Impulse response')
plt.xlim(0,0.2)
plt.yticks([])
plt.xticks([])
# Out:
# D:\anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ([], <a list of 0 Text xticklabel objects>)

# %% [markdown]
# ##  About Sub-plots

# %%
plt.plot([1,2,3])
plt.subplot(211)
plt.plot(range(12))
plt.subplot(212,facecolor='y')
plt.grid()

# %% [markdown]
# ##  Pie chart

# %%
labels = 'Cats','Birds','Dogs','Pandas'
sizes = [25,35,300,10]
explode=(0,0.08,0,0)

# %%
fig1,ax1=plt.subplots()
plt.pie(sizes,explode=explode,labels=labels,autopct='%1.1f%%',shadow=False,startangle=90)
ax1.axis('equal')
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors =np.random.rand(N)
area = np.pi*(150*np.random.rand(N)**20)

# %%
plt.scatter(x,y,s=area,c=colors,alpha=0.5)
plt.show()

# %%
weather_2012_final.columns
# Out:
# Index(['Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)', 'Wind Spd (km/h)',
#        'Visibility (km)', 'Stn Press (kPa)', 'Weather'],
#       dtype='object')

# %%
N = weather_2012_final.shape[0]
colors =np.random.rand(N)
plt.scatter(weather_2012_final['Temp (C)'],weather_2012_final['Dew Point Temp (C)'],c=colors,alpha=0.5)
plt.xlabel('Temp (C)')
plt.ylabel('Dew Point Temp (C)')
plt.title('Histogram of Temperture in year 2012')
plt.show()

# %% [markdown]
# ##  Histogram

# %%
np.random.seed(2018)
mu,sigma = 100,15
x = mu + sigma*np.random.randn(10000)
n,bins,patches = plt.hist(x,50,normed=1,facecolor='b',alpha=0.5)
print('n=',n)
print('bins=',bins)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60,.025,r'$\mu=100,\ \sigma=15$')
#plt.text(60,.025,r'$\mu=100,\ \sigma=15%')
plt.axis([40,160,0,0.03])
plt.grid()
plt.show()
# Out:
# D:\anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# n= [4.08262010e-05 4.08262010e-05 4.08262010e-05 4.08262010e-05
#  8.16524021e-05 8.16524021e-05 1.63304804e-04 2.44957206e-04
#  4.08262010e-04 4.49088211e-04 9.39002624e-04 1.55139564e-03
#  2.16378865e-03 3.02113888e-03 3.55187949e-03 5.87897295e-03
#  6.77714937e-03 8.85928562e-03 1.20845555e-02 1.41666918e-02
#  1.44116490e-02 1.85759215e-02 2.16787127e-02 2.44957206e-02
#  2.51081136e-02 2.66595093e-02 2.63328997e-02 2.59654639e-02
#  2.61287687e-02 2.48631564e-02 2.24544106e-02 1.83717905e-02
#  1.56772612e-02 1.39625608e-02 1.17171197e-02 8.45102361e-03
#  6.65467077e-03 5.02162273e-03 3.30692228e-03 2.44957206e-03
#  1.46974324e-03 1.18395983e-03 1.02065503e-03 6.12393015e-04
#  4.89914412e-04 2.85783407e-04 1.63304804e-04 8.16524021e-05
# ...

# %%
n,bins,patches = plt.hist(weather_2012_final['Temp (C)'],6,facecolor='g',alpha=0.5)
plt.xlabel('Temperture is C')
plt.ylabel('Counts of Days')
plt.title('Histogram of Temperture in year 2012')
plt.grid()
plt.show()

# %% [markdown]
# ## 3Dplot

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-5,5,0.25)
Y = np.arange(-5,5,0.25)
X,Y = np.meshgrid(X,Y)
R = np.sqrt(X**2,Y**2)
Z = np.sin(R)

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X,Y,Z,rstride=1,cstride=1,cmap=cm.Greens)

# %% [markdown]
# ## What about Math Functions?

# %%
t = np.arange(0.0,2.0,0.01)
s = np.sin(2*np.pi*t)

plt.plot(t,s)
plt.title(r'$\alpha_i > \beta_i$',fontsize=20)
plt.text(1, -0.6, r'$\sum_{i=0}^\infty x_i$', fontsize=20)
plt.text(0.6,0.6,r'$\mathcal{A}\mathrm{sin}(2 \omega t)$',fontsize=20)
# Out:
# Text(0.6,0.6,'$\\mathcal{A}\\mathrm{sin}(2 \\omega t)$')

# %% [markdown]
# ##  Barchart

# %%
import numpy as np
import matplotlib.pyplot as plt
men_means,men_std = (25,35,30,35,27),(2,3,4,1,2)
women_means,women_std= (25,32,34,20,25),(3,5,2,3,3)
ind = np.arange(len(men_means))
width=0.35
fig,ax = plt.subplots()
rects1 = ax.bar(ind - width/2,men_means,width,yerr=men_std,color='SkyBlue',label='Men')
rects2 = ax.bar(ind - width/2,women_means,width,yerr=women_std,color='IndianRed',label='Women')
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticklabels(('G1','G2','G3','G4','G5'))


ax.legend()
