# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv(r'C:\Users\Administrator\test\info(1).csv')

# %%
disbig = []
dissmal = []
for i in df.Displacement:
    disbig.append(str(i).replace('T','').replace('纯电动','').replace('L','').replace(", ''",'').replace("'",'').replace(',','')[:4])
    dissmal.append(str(i).replace('T','').replace('纯电动','').replace('L','').replace('\r\n','').replace(", ''",'').replace("'",'')[-4:])

# %%
df
# Out:
#              Carname Officialprice            Carfuelc  Brand  \
# 0       smart fortwo  11.68-30.89万   5.00-11.80L/100km  smart
# 1      smart forfour  12.58-22.08万   5.10-12.00L/100km  smart
# 2              比亚迪F0    3.79-4.79万    5.20-6.60L/100km    比亚迪
# 3                 奥拓    4.18-6.19万    5.20-8.30L/100km     铃木
# 4               奇瑞QQ    3.79-5.09万    5.50-5.80L/100km     奇瑞
# 5              北斗星X5    4.69-5.19万    6.20-6.70L/100km     铃木
# 6                 奔奔    4.09-5.69万    6.30-8.50L/100km   长安汽车
# 7                北斗星    3.99-4.49万    6.70-7.00L/100km     铃木
# 8              启辰R30    3.99-5.19万    4.90-6.00L/100km   东风启辰
# 9              宝骏310    3.68-6.08万    5.00-8.10L/100km     宝骏
# 10              夏利A+    2.88-3.78万    5.00-9.00L/100km     一汽
# 11              威驰FS   6.98-10.98万    5.00-9.00L/100km     丰田
# 12                玛驰    5.98-8.75万    5.20-8.00L/100km     日产
# 13                威驰   6.98-11.38万    5.50-8.30L/100km     丰田
# ...

# %%
df['dissmal'] = dissmal

# %%
df['disbig'] = disbig

# %%
df
# Out:
#              Carname Officialprice            Carfuelc  Brand  \
# 0       smart fortwo  11.68-30.89万   5.00-11.80L/100km  smart
# 1      smart forfour  12.58-22.08万   5.10-12.00L/100km  smart
# 2              比亚迪F0    3.79-4.79万    5.20-6.60L/100km    比亚迪
# 3                 奥拓    4.18-6.19万    5.20-8.30L/100km     铃木
# 4               奇瑞QQ    3.79-5.09万    5.50-5.80L/100km     奇瑞
# 5              北斗星X5    4.69-5.19万    6.20-6.70L/100km     铃木
# 6                 奔奔    4.09-5.69万    6.30-8.50L/100km   长安汽车
# 7                北斗星    3.99-4.49万    6.70-7.00L/100km     铃木
# 8              启辰R30    3.99-5.19万    4.90-6.00L/100km   东风启辰
# 9              宝骏310    3.68-6.08万    5.00-8.10L/100km     宝骏
# 10              夏利A+    2.88-3.78万    5.00-9.00L/100km     一汽
# 11              威驰FS   6.98-10.98万    5.00-9.00L/100km     丰田
# 12                玛驰    5.98-8.75万    5.20-8.00L/100km     日产
# 13                威驰   6.98-11.38万    5.50-8.30L/100km     丰田
# ...

# %% [markdown]
# # 最大排量

# %%
df.sort_values('dissmal',ascending=False).head()
# Out:
#          Carname    Officialprice            Carfuelc Brand  \
# 266           幻影  688.00-1488.00万  13.00-31.00L/100km  劳斯莱斯
# 1043       道奇Ram     65.00-72.00万  17.40-19.00L/100km    道奇
# 1009       道奇Ram     65.00-72.00万  17.40-19.00L/100km    道奇
# 964      Huracan   280.00-395.00万   8.70-19.50L/100km  兰博基尼
# 975   GranCabrio   268.80-302.80万  14.30-21.30L/100km  玛莎拉蒂
#
#                MIITfuelc Rank Displacement Gearbox Cartype  \
# 266   15.70-17.00L/100km  大型车       '6.7L'      自动     三厢车
# 1043        19.50L/100km   皮卡       '5.7L'    手自一体      皮卡
# 1009        19.50L/100km   皮卡       '5.7L'    手自一体      皮卡
# 964                  NaN   跑车       '5.2L'     双离合   软顶敞篷车
# 975                  NaN   跑车       '4.7L'    手自一体   软顶敞篷车
#
#                      Ranking  ...    Major Ownerevaluate Price  \
# 266   该车暂未被列入榜单，暂无排名信息查看详情>>  ...      测试中            良好    良好
# 1043  该车暂未被列入榜单，暂无排名信息查看详情>>  ...      测试中            优秀    优秀
# ...

# %% [markdown]
# # 最小排量

# %%
df.sort_values('dissmal',ascending=True).head()
# Out:
#             Carname Officialprice           Carfuelc  Brand         MIITfuelc  \
# 0      smart fortwo  11.68-30.89万  5.00-11.80L/100km  smart  4.20-5.20L/100km
# 1     smart forfour  12.58-22.08万  5.10-12.00L/100km  smart               NaN
# 1012             优优    4.10-5.59万   5.60-8.00L/100km     开瑞               NaN
# 976            优优2代    3.40-4.40万   5.20-7.30L/100km     开瑞               NaN
# 1010           优优2代    3.40-4.40万   5.20-7.30L/100km     开瑞               NaN
#
#      Rank                    Displacement Gearbox Cartype  \
# 0     微型车   '0.9T', '1.0L', '1.0T', '纯电动'     双离合     两厢车
# 1     微型车                  '0.9T', '1.0L'     双离合     两厢车
# 1012   微面  '1.0L', '1.0T', '1.1L', '1.2L'      手动      客车
# 976    微面                  '1.0L', '1.2L'      手动      客车
# 1010   微面                  '1.0L', '1.2L'      手动      客车
#
#                      Ranking  ...    Major Ownerevaluate Price  \
# 0     该车暂未被列入榜单，暂无排名信息查看详情>>  ...      测试中            优秀    优秀
# ...

# %% [markdown]
# # 最贵的是哪款车

# %%
df
# Out:
#              Carname Officialprice            Carfuelc  Brand  \
# 0       smart fortwo  11.68-30.89万   5.00-11.80L/100km  smart
# 1      smart forfour  12.58-22.08万   5.10-12.00L/100km  smart
# 2              比亚迪F0    3.79-4.79万    5.20-6.60L/100km    比亚迪
# 3                 奥拓    4.18-6.19万    5.20-8.30L/100km     铃木
# 4               奇瑞QQ    3.79-5.09万    5.50-5.80L/100km     奇瑞
# 5              北斗星X5    4.69-5.19万    6.20-6.70L/100km     铃木
# 6                 奔奔    4.09-5.69万    6.30-8.50L/100km   长安汽车
# 7                北斗星    3.99-4.49万    6.70-7.00L/100km     铃木
# 8              启辰R30    3.99-5.19万    4.90-6.00L/100km   东风启辰
# 9              宝骏310    3.68-6.08万    5.00-8.10L/100km     宝骏
# 10              夏利A+    2.88-3.78万    5.00-9.00L/100km     一汽
# 11              威驰FS   6.98-10.98万    5.00-9.00L/100km     丰田
# 12                玛驰    5.98-8.75万    5.20-8.00L/100km     日产
# 13                威驰   6.98-11.38万    5.50-8.30L/100km     丰田
# ...

# %%
df2 = df

# %%
JA = []
for i in df2.Officialprice:
    JA.append(i.split('-')[0])

# %%
df2['JA']=JA

# %%
df2.sort_values(['JA'],ascending=False).head(1)
# Out:
#       Carname  Officialprice            Carfuelc Brand          MIITfuelc  \
# 264  Panamera  99.80-217.80万  11.50-15.50L/100km   保时捷  9.30-12.20L/100km
#
#     Rank                                    Displacement Gearbox Cartype  \
# 264  大型车  '2.9T', '3.0T', '3.6L', '4.0T', '4.8L', '4.8T'     双离合     掀背车
#
#                     Ranking  ...    Ownerevaluate Price  \
# 264  该车暂未被列入榜单，暂无排名信息查看详情>>  ...               优秀    优秀
#
#                                  Versions_1 Versionsp_1  \
# 264   2019款 Panamera GTS Sport Turismo 4.0T      187.8万
#
#                    Versions_2 Versionsp_2  \
# 264   2019款 Panamera GTS 4.0T      184.8万
#
#                                      URL dissmal disbig     JA
# 264  https://price.pcauto.com.cn/sg3756/     4.8   2.9   99.80
#
# [1 rows x 23 columns]

# %% [markdown]
# # 那些评价较高

# %%
df[df.Ownerevaluate=='优秀']
# Out:
#              Carname   Officialprice            Carfuelc   Brand  \
# 0       smart fortwo    11.68-30.89万   5.00-11.80L/100km   smart
# 1      smart forfour    12.58-22.08万   5.10-12.00L/100km   smart
# 5              北斗星X5      4.69-5.19万    6.20-6.70L/100km      铃木
# 19             凯翼C3R      4.58-6.08万    6.00-9.10L/100km      凯翼
# 24                瑞纳      4.99-7.39万    6.10-8.50L/100km      现代
# 25                悦翔      4.99-6.59万    6.10-9.30L/100km    长安汽车
# 29              凯翼C3      4.58-6.08万    6.30-7.70L/100km      凯翼
# 35                悦纳     7.28-10.58万    6.60-7.10L/100km      现代
# 46       MINI CABRIO    29.88-38.50万   7.30-13.30L/100km    MINI
# 47      MINI CLUBMAN    23.98-35.08万   7.50-10.20L/100km    MINI
# 49           秦Pro新能源    14.99-29.99万    2.50-5.00L/100km     比亚迪
# 50             荣威ei6    20.18-22.28万    3.40-8.20L/100km      荣威
# 53               普锐斯    22.98-26.98万         4.70L/100km      丰田
# ...

# %%
df
# Out:
#              Carname Officialprice            Carfuelc  Brand  \
# 0       smart fortwo  11.68-30.89万   5.00-11.80L/100km  smart
# 1      smart forfour  12.58-22.08万   5.10-12.00L/100km  smart
# 2              比亚迪F0    3.79-4.79万    5.20-6.60L/100km    比亚迪
# 3                 奥拓    4.18-6.19万    5.20-8.30L/100km     铃木
# 4               奇瑞QQ    3.79-5.09万    5.50-5.80L/100km     奇瑞
# 5              北斗星X5    4.69-5.19万    6.20-6.70L/100km     铃木
# 6                 奔奔    4.09-5.69万    6.30-8.50L/100km   长安汽车
# 7                北斗星    3.99-4.49万    6.70-7.00L/100km     铃木
# 8              启辰R30    3.99-5.19万    4.90-6.00L/100km   东风启辰
# 9              宝骏310    3.68-6.08万    5.00-8.10L/100km     宝骏
# 10              夏利A+    2.88-3.78万    5.00-9.00L/100km     一汽
# 11              威驰FS   6.98-10.98万    5.00-9.00L/100km     丰田
# 12                玛驰    5.98-8.75万    5.20-8.00L/100km     日产
# 13                威驰   6.98-11.38万    5.50-8.30L/100km     丰田
# ...

# %% [markdown]
# # 最贵的Gearbox

# %%
df2.sort_values(['JA'],ascending=False).head(1)['Gearbox']
# Out:
# 264    双离合
# Name: Gearbox, dtype: object

# %%
#最贵的
