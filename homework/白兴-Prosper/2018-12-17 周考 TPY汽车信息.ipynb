# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\Sbaix\Desktop\info.csv')

# %%
df.head()
# Out:
#          Carname Officialprice           Carfuelc  Brand         MIITfuelc  \
# 0   smart fortwo  11.68-30.89万  5.00-11.80L/100km  smart  4.20-5.20L/100km
# 1  smart forfour  12.58-22.08万  5.10-12.00L/100km  smart               NaN
# 2          比亚迪F0    3.79-4.79万   5.20-6.60L/100km    比亚迪       4.20L/100km
# 3             奥拓    4.18-6.19万   5.20-8.30L/100km     铃木  3.60-4.00L/100km
# 4           奇瑞QQ    3.79-5.09万   5.50-5.80L/100km     奇瑞               NaN
#
#   Rank                   Displacement Gearbox Cartype                 Ranking  \
# 0  微型车  '0.9T', '1.0L', '1.0T', '纯电动'     双离合     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>
# 1  微型车                 '0.9T', '1.0L'     双离合     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>
# 2  微型车                         '1.0L'      手动     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>
# 3  微型车                         '1.0L'      手动     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>
# 4  微型车                         '1.0L'      手动     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>
#
# ...

# %% [markdown]
# # 大排量车有哪些?

# %%
df.Displacement=df.Displacement.apply(lambda x: x.replace('L','').replace('T','').replace('纯电动','').replace("''",'').replace(',','').strip())

df.Displacement=df.Displacement.apply(lambda x:x[-5:])
df[df.Displacement==df.Displacement.max()]
# Out:
#     Carname    Officialprice            Carfuelc Brand           MIITfuelc  \
# 233   C级AMG    61.88-134.80万  12.00-13.80L/100km    奔驰        13.40L/100km
# 256    奔驰S级    86.38-173.28万   7.40-13.00L/100km    奔驰   9.40-23.10L/100km
# 257   奥迪A8L    87.68-256.80万   7.50-14.00L/100km    奥迪   9.10-20.00L/100km
# 258    宝马7系    82.80-248.80万   9.00-12.30L/100km    宝马   8.50-13.60L/100km
# 263   迈巴赫S级   139.88-309.88万  11.00-15.40L/100km    奔驰                 NaN
# 265      飞驰   278.00-435.80万  11.50-21.60L/100km    宾利  11.00-16.30L/100km
# 266      幻影  688.00-1488.00万  13.00-31.00L/100km  劳斯莱斯  15.70-17.00L/100km
# 523      途锐     63.68-84.98万   9.20-14.30L/100km    大众   7.40-15.70L/100km
# 545    奥迪Q7     69.98-98.48万   9.90-14.00L/100km    奥迪   7.40-13.60L/100km
# 550    大切诺基     52.99-71.49万  10.10-12.60L/100km  Jeep  11.90-18.70L/100km
# 565   YUKON   118.80-238.00万  11.00-22.50L/100km   GMC                 NaN
# ...

# %% [markdown]
# # 小排量车有哪些?

# %%
df.Displacement=df.Displacement.apply(lambda x: x.replace('L','').replace('T','').replace('纯电动','').replace("''",'').replace(',','').strip())
df[df.Displacement==df.Displacement.min()]
# Out:
#      Carname Officialprice          Carfuelc Brand    MIITfuelc Rank  \
# 989    佳宝V52    2.72-2.92万  6.70-7.10L/100km    一汽  6.00L/100km   微面
# 1022   佳宝V52    2.72-2.92万  6.70-7.10L/100km    一汽  6.00L/100km   微面
#
#      Displacement Gearbox Cartype                 Ranking  Carstrength  \
# 989             '      手动      客车  该车暂未被列入榜单，暂无排名信息查看详情>>         30.9
# 1022            '      手动      客车  该车暂未被列入榜单，暂无排名信息查看详情>>         30.9
#
#      Configuration Major Ownerevaluate Price               Versions_1  \
# 989             较弱   测试中            较弱    较弱   2012款 1.0 DA465QA 实用型
# 1022            较弱   测试中            较弱    较弱   2012款 1.0 DA465QA 实用型
#
#      Versionsp_1 Versions_2 Versionsp_2                                  URL
# 989        2.72万        NaN         NaN  https://price.pcauto.com.cn/sg4421/
# 1022       2.72万        NaN         NaN  https://price.pcauto.com.cn/sg4421/

# %% [markdown]
# # 最贵的是哪款车?

# %%
def new_int(data_list):
    return_list = [float(i) for i in data_list]
    return return_list

def a(df,off):
    data = df[off]
    data = data.replace('万','').split('-')
    data = new_int(data)
    return sum(data)/len(data)

# %%
df.Officialprice = df.apply(a,axis = 1,off = 'Officialprice')

# %%
df.nlargest(1,'Officialprice')
# Out:
#     Carname  Officialprice            Carfuelc Brand           MIITfuelc Rank  \
# 266      幻影         1088.0  13.00-31.00L/100km  劳斯莱斯  15.70-17.00L/100km  大型车
#
#     Displacement Gearbox Cartype                 Ranking  Carstrength  \
# 266       '6.7L'      自动     三厢车  该车暂未被列入榜单，暂无排名信息查看详情>>         52.3
#
#     Configuration Major Ownerevaluate Price      Versions_1 Versionsp_1  \
# 266            良好   测试中            良好    良好   2018款 绅士之旅定制版         未上市
#
#          Versions_2 Versionsp_2                                  URL
# 266   2018款 私享秘境特别版         未上市  https://price.pcauto.com.cn/sg2313/

# %% [markdown]
# # 那些车主评价比较高?

# %%
evaluate_df=df[df.Ownerevaluate == '优秀']

# %%
evaluate_df.head()
# Out:
#           Carname Officialprice           Carfuelc  Brand         MIITfuelc  \
# 0    smart fortwo  11.68-30.89万  5.00-11.80L/100km  smart  4.20-5.20L/100km
# 1   smart forfour  12.58-22.08万  5.10-12.00L/100km  smart               NaN
# 5           北斗星X5    4.69-5.19万   6.20-6.70L/100km     铃木               NaN
# 19          凯翼C3R    4.58-6.08万   6.00-9.10L/100km     凯翼               NaN
# 24             瑞纳    4.99-7.39万   6.10-8.50L/100km     现代  4.80-5.00L/100km
#
#    Rank                   Displacement Gearbox Cartype  \
# 0   微型车  '0.9T', '1.0L', '1.0T', '纯电动'     双离合     两厢车
# 1   微型车                 '0.9T', '1.0L'     双离合     两厢车
# 5   微型车                 '1.0L', '1.4L'      手动     两厢车
# 19  小型车                         '1.5L'      手动     两厢车
# 24  小型车                 '1.4L', '1.6L'      手动     三厢车
#
#                     Ranking  Carstrength Configuration Major Ownerevaluate  \
# 0    该车暂未被列入榜单，暂无排名信息查看详情>>         45.0            较弱   测试中            优秀
# ...

# %% [markdown]
# # 配置水平优秀的车中价格最贵的车?

# %%
df[df.Configuration == '优秀'].max()
# Out:
# Carname                                      迈巴赫S级
# Officialprice                        92.18-128.58万
# Carfuelc                         9.90-11.00L/100km
# Brand                                           路虎
# Rank                                           大型车
# Displacement                '3.0T', '4.0T', '6.0T'
# Gearbox                                         自动
# Cartype                                        旅行车
# Ranking                    该车车实力评分高于89%同级别车系查看详情>>
# Carstrength                                   86.9
# Configuration                                   优秀
# Major                                          测试中
# Ownerevaluate                                   优秀
# Price                                           优秀
# Versions_1                             2019款 S 680
# Versionsp_1                                    未上市
# Versions_2                             2019款 S 560
# Versionsp_2                                    未上市
# ...

# %% [markdown]
# # 哪种车型最多?

# %%
df.Brand.value_counts()
# Out:
# 大众           34
# 日产           27
# 现代           26
# 比亚迪          25
# 奔驰           24
# 宝马           23
# 众泰           23
# 丰田           23
# 本田           22
# 哈弗           22
# 长安汽车         21
# 吉利汽车         21
# 起亚           21
# Jeep         18
# 江淮           18
# 长安欧尚         17
# 铃木           17
# 奥迪           17
# 福特           16
# 奇瑞           16
# 东风风行         15
# 荣威           15
# 广汽传祺         15
# 一汽           14
# 力帆           14
# 中华           14
# 北汽绅宝         13
# 斯柯达          13
# 北汽幻速         13
# 别克           13
#              ..
# GMC           3
# 林肯            3
# 讴歌            3
# 上汽大通MAXUS     3
# 观致            3
# 凯迪拉克          3
# 菲亚特           2
# 星驰            2
# 永源            2
# 红旗            2
# 斯达泰克          2
# 捷途            2
# 广汽吉奥          2
# 福迪            2
# smart         2
# 广汽新能源         2
# 宾利            2
# 依维柯           2
# 赛麟            2
# 卡威汽车          2
# 欧尚汽车          2
# 思铭            1
# 阿斯顿・马丁        1
# 东风小康          1
# ...

# %% [markdown]
# # 车主平均油耗最大的是那辆车?

# %%
df[df.Carfuelc==df.Carfuelc.max()]
# Out:
#     Carname Officialprice           Carfuelc Brand          MIITfuelc    Rank  \
# 545    奥迪Q7  69.98-98.48万  9.90-14.00L/100km    奥迪  7.40-13.60L/100km  中大型SUV
# 871    奥迪Q7  69.98-98.48万  9.90-14.00L/100km    奥迪  7.40-13.60L/100km  中大型SUV
#
#                                Displacement Gearbox Cartype  \
# 545  '2.0T', '3.0T', '3.6L', '4.2L', '6.0T'    手自一体     SUV
# 871  '2.0T', '3.0T', '3.6L', '4.2L', '6.0T'    手自一体     SUV
#
#                      Ranking  Carstrength Configuration Major Ownerevaluate  \
# 545  该车车实力评分高于53%同级别车系查看详情>>         80.6            良好    良好            优秀
# 871  该车车实力评分高于53%同级别车系查看详情>>         80.6            良好    良好            优秀
#
#     Price                  Versions_1 Versionsp_1  \
# 545    优秀   2018款 45 TFSI quattro 技术型      78.78万
# 871    优秀   2018款 45 TFSI quattro 技术型      78.78万
#
#                            Versions_2 Versionsp_2  \
# 545   2018款 45 TFSI quattro S line运动型       84.5万
# 871   2018款 45 TFSI quattro S line运动型       84.5万
#
# ...
