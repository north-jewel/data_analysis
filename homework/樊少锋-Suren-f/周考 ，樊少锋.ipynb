# %%
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pylab import *
mpl.rcParams['font.sans-serif']=['SimHei']
import random

# %%
data = pd.read_csv('info(1).csv')
data
# Out:
#              Carname Officialprice            Carfuelc  Brand  \
# 0       smart fortwo  11.68-30.89万   5.00-11.80L/100km  smart
# 1      smart forfour  12.58-22.08万   5.10-12.00L/100km  smart
# 2              比亚迪F0    3.79-4.79万    5.20-6.60L/100km    比亚迪
# 3                 奥拓    4.18-6.19万    5.20-8.30L/100km     铃木
# 4               奇瑞QQ    3.79-5.09万    5.50-5.80L/100km     奇瑞
# 5              北斗星X5    4.69-5.19万    6.20-6.70L/100km     铃木
# 6                 奔奔    4.09-5.69万    6.30-8.50L/100km   长安汽车
# 7                北斗星    3.99-4.49万    6.70-7.00L/100km     铃木
# 8              启辰R30    3.99-5.19万    4.90-6.00L/100km   东风启辰
# 9              宝骏310    3.68-6.08万    5.00-8.10L/100km     宝骏
# 10              夏利A+    2.88-3.78万    5.00-9.00L/100km     一汽
# 11              威驰FS   6.98-10.98万    5.00-9.00L/100km     丰田
# 12                玛驰    5.98-8.75万    5.20-8.00L/100km     日产
# 13                威驰   6.98-11.38万    5.50-8.30L/100km     丰田
# ...

# %% [markdown]
# # 最贵de车

# %%
data[data['Officialprice'] == a.max()]['Carname']
# Out:
# Series([], Name: Carname, dtype: object)

# %% [markdown]
# # 评价比较高的车

# %%
data[data['Ownerevaluate'] == '优秀']['Carname'].values
# Out:
# array(['smart fortwo', 'smart forfour', '北斗星X5', '凯翼C3R', '瑞纳', '悦翔',
#        '凯翼C3', '悦纳', 'MINI CABRIO', 'MINI CLUBMAN', '秦Pro新能源', '荣威ei6',
#        '普锐斯', '凌派', '阅朗', '名爵6新能源', '骐达', '奥迪A3', '缤瑞', '启辰D60', '启悦',
#        '雷克萨斯CT', '科鲁兹', '科沃兹', '标致408', '名爵GT', '艾瑞泽GX', '名爵6', '奔腾B50',
#        '艾瑞泽EX', '逸动', '荣威e550', '思域', '标致308S', '蓝鸟', '宝马1系', '高尔夫・嘉旅',
#        '帝豪GL', '东风风神L60', '全新悦动', '荣威360', '荣威i5', '艾瑞泽7', '荣威i6', '沃兰多',
#        '奔驰A级(进口)', '昕动', '比亚迪G5', '宝马2系旅行车', 'LA FESTA菲斯塔', 'DS 5LS',
#        '全新爱丽舍', '宝马2系', 'DS 4S', '福美来F5', '奔驰B级', '秦Pro', '纳5', '起亚K5新能源',
#        '起亚K5', '传祺GA6', '博瑞GE', '大众CC', '睿骋CC', '宝马3系', '沃尔沃S60L', '速派',
#        '力狮', '名图', '海马M6', '君威', '迈腾', '迈锐宝XL', '起亚K4', '帕萨特', '比亚迪G6',
#        '蒙迪欧', '迈锐宝', '阿特兹', '宝马3系GT', '红旗H5', '博瑞', '凯泽西', '天籁', 'DS 5',
#        'Giulia', '凯尊', '西玛', '速尊', '讴歌TLX', '英菲尼迪Q50', '雷克萨斯ES', '东风A9',
#        '奔驰E级(进口)', '奥迪A6L', '雪铁龙C6', '奔驰E级', '奥迪A7', '瑞风A60', '众泰Z700',
# ...

# %% [markdown]
# # 大排量的车

# %%
data[data['Displacement']==data['Displacement'].max()]['Carname']
# Out:
# 266    幻影
# Name: Carname, dtype: object

# %% [markdown]
# # 小排量的车

# %%
data[data['Displacement']==data['Displacement'].min()]['Carname']
# Out:
# 989     佳宝V52
# 1022    佳宝V52
# Name: Carname, dtype: object

# %% [markdown]
# # 卖的最多的牌子

# %%
data['Carname'].value_counts().head(1)
# Out:
# 创酷TRAX    2
# Name: Carname, dtype: int64

# %%
问题：车的实力与售价的关系

# %%
问题：油耗和排量的关系
