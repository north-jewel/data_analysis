# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
help(np.linspace)
# Out:
# Help on function linspace in module numpy.core.function_base:
#
# linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None)
#     Return evenly spaced numbers over a specified interval.
#
#     Returns `num` evenly spaced samples, calculated over the
#     interval [`start`, `stop`].
#
#     The endpoint of the interval can optionally be excluded.
#
#     Parameters
#     ----------
#     start : scalar
#         The starting value of the sequence.
#     stop : scalar
#         The end value of the sequence, unless `endpoint` is set to False.
#         In that case, the sequence consists of all but the last of ``num + 1``
#         evenly spaced samples, so that `stop` is excluded.  Note that the step
#         size changes when `endpoint` is False.
#     num : int, optional
#         Number of samples to generate. Default is 50. Must be non-negative.
#     endpoint : bool, optional
#         If True, `stop` is the last sample. Otherwise, it is not included.
# ...

# %%
x = np.arange(-2,2,0.1)
x
# Out:
# array([-2.00000000e+00, -1.90000000e+00, -1.80000000e+00, -1.70000000e+00,
#        -1.60000000e+00, -1.50000000e+00, -1.40000000e+00, -1.30000000e+00,
#        -1.20000000e+00, -1.10000000e+00, -1.00000000e+00, -9.00000000e-01,
#        -8.00000000e-01, -7.00000000e-01, -6.00000000e-01, -5.00000000e-01,
#        -4.00000000e-01, -3.00000000e-01, -2.00000000e-01, -1.00000000e-01,
#         1.77635684e-15,  1.00000000e-01,  2.00000000e-01,  3.00000000e-01,
#         4.00000000e-01,  5.00000000e-01,  6.00000000e-01,  7.00000000e-01,
#         8.00000000e-01,  9.00000000e-01,  1.00000000e+00,  1.10000000e+00,
#         1.20000000e+00,  1.30000000e+00,  1.40000000e+00,  1.50000000e+00,
#         1.60000000e+00,  1.70000000e+00,  1.80000000e+00,  1.90000000e+00])

# %%
y=x

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
#     control on the  appearance. Line properties and *fmt* can be mixed.
# ...

# %%
theta = np.arange(0, 2*np.pi, 0.02)
plt.subplot(121, polar=True)
plt.plot(theta, linewidth=2)
plt.show()

# %%
an = np.linspace(0, 2 * np.pi, 100)
fig, axs = plt.subplots(2, 2)

axs[0, 0].plot(3 * np.cos(an), 3 * np.sin(an))
axs[0, 0].set_title('not equal, looks like ellipse', fontsize=10)

axs[0, 1].plot(3 * np.cos(an), 3 * np.sin(an))
axs[0, 1].axis('equal')
axs[0, 1].set_title('equal, looks like circle', fontsize=10)

axs[1, 0].plot(3 * np.cos(an), 3 * np.sin(an))
axs[1, 0].axis('equal')
axs[1, 0].axis([-3, 3, -3, 3])
axs[1, 0].set_title('still a circle, even after changing limits', fontsize=10)

axs[1, 1].plot(3 * np.cos(an), 3 * np.sin(an))
axs[1, 1].set_aspect('equal', 'box')


axs[1, 1].set_title('still a circle, auto-adjusted data limits', fontsize=10)

fig.tight_layout()

plt.show()

# %%
var = np.linspace(-np.pi,np.pi,266,endpoint=True)

# %%
x2=np.linspace(0,-0.3,150,endpoint=True)
x2
# Out:
# array([ 0.        , -0.00201342, -0.00402685, -0.00604027, -0.00805369,
#        -0.01006711, -0.01208054, -0.01409396, -0.01610738, -0.01812081,
#        -0.02013423, -0.02214765, -0.02416107, -0.0261745 , -0.02818792,
#        -0.03020134, -0.03221477, -0.03422819, -0.03624161, -0.03825503,
#        -0.04026846, -0.04228188, -0.0442953 , -0.04630872, -0.04832215,
#        -0.05033557, -0.05234899, -0.05436242, -0.05637584, -0.05838926,
#        -0.06040268, -0.06241611, -0.06442953, -0.06644295, -0.06845638,
#        -0.0704698 , -0.07248322, -0.07449664, -0.07651007, -0.07852349,
#        -0.08053691, -0.08255034, -0.08456376, -0.08657718, -0.0885906 ,
#        -0.09060403, -0.09261745, -0.09463087, -0.0966443 , -0.09865772,
#        -0.10067114, -0.10268456, -0.10469799, -0.10671141, -0.10872483,
#        -0.11073826, -0.11275168, -0.1147651 , -0.11677852, -0.11879195,
#        -0.12080537, -0.12281879, -0.12483221, -0.12684564, -0.12885906,
# ...

# %%
x=np.cos(var)
y=np.sin(var)
l_x=0.15*np.cos(var)-0.39
l_y=0.145*np.sin(var)+0.38
r_x=0.15*np.cos(var)+0.39
r_y=0.145*np.sin(var)+0.38
x1=np.cos(np.linspace(-np.pi,0,266,endpoint=True))*0.3
y1=np.sin(np.linspace(-np.pi,0,266,endpoint=True))*0.3-0.25
x2=np.cos(np.linspace(-np.pi,0,266,endpoint=True))*0.3
y2=np.sin(np.linspace(-np.pi,0,266,endpoint=True))*0.3-0.17

# %%
x3=0.1*np.cos(var)-0.7
y3=0.1*np.sin(var)-0.1
x4=0.1*np.cos(var)+0.7
y4=0.1*np.sin(var)-0.1
l_x1=0.07*np.cos(var)-0.39
l_y1=0.07*np.sin(var)+0.38
l_x2=0.07*np.cos(var)+0.39
l_y2=0.07*np.sin(var)+0.38

# %%
# plt.figure(1)
plt.plot(x,y,linewidth=4.0,linestyle='-',alpha=0.5,color='pink')
plt.axis('equal')
plt.plot(l_x,l_y,r_x,r_y,linewidth=4.0,linestyle='-',alpha=0.6,color='white')
# plt.plot(r_x,r_y,linewidth=4.0,linestyle='-',alpha=0.6,color='blue')
plt.plot(x1,y1,x2,y2,x3,y3,x4,y4,linewidth=4.0,linestyle='-',alpha=0.6,color='red')
# plt.plot(x2,y2,linewidth=4.0,linestyle='-',color='red')
# plt.plot(x3,y3,linewidth=4.0,linestyle='-',color='pink')
# plt.plot(x4,y4,linewidth=4.0,linestyle='-',color='pink')
plt.fill(x,y,'pink',l_x,l_y,'white',r_x,r_y,'white',l_x1,l_y1,'gray',l_x2,l_y2,'gray')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(-np.pi,np.pi,266,endpoint=True)
a=np.sin(x)
b=np.cos(x)

# %%
plt.figure()  #所有图的容器
plt.plot(x,a,linewidth=3.0,linestyle='--',color='gray',label='sin',alpha=0.65)
plt.plot(x,b,linewidth=3.0,linestyle='--',color='red',label='cos',alpha=0.65)
plt.title('sin & cos')   #标题
# plt.subplots(2, 2)
ax = plt.gca()
ax.spines['bottom']. set_position(('data',0))   #改变线框，移动下面的线到0原点
ax.spines['bottom'].set_color('red')
ax.spines['left']. set_position(('data',0))
ax.spines['left'].set_color('gray')
ax.spines['top']. set_color('none')
ax.spines['right']. set_color('none')
plt.xticks([-np.pi,-np.pi/2,0,np.pi/2,np.pi],
         [r'$-\pi$',r'$-\pi/2$',r'$0$',r'$+\pi/2$',r'$\pi$'])
plt.yticks([1,0.5,0,-0.5,-1])    #改变y轴的点
plt.tight_layout()  #紧密布局
plt.legend()   #图列
# plt.show()
for l in ax.get_xticklabels()+ax.get_yticklabels():
    l.set_fontsize(18)     #字体大小
    l.set_bbox(dict(edgecolor='white',alpha=0.65))   #字体边框的颜色，透明度
    l.set_color('red')     #字体颜色
    l.set_backgroundcolor('pink')   #字体背景
ax.grid()  #网格线
ax.fill_between(x,b*(np.abs(x)<0.5),color='green',alpha=0.25)
ax.fill_between(x,0,a*(x<np.pi/4)-a*(x<0)+b*(x>np.pi/4)-b*(x>np.pi/2),color='blue',alpha=0.5)
ax.fill_between(x,a,color='gray',alpha=0.25)
ax.fill_between(x,x>0,b,b<0.5,color='red',alpha=0.25)
# ax.fill_between(x,0,b,b<0.5,color='red',alpha=0.25)
ax.fill_between(x,np.abs(x)<0.5,b,abs(x-0.25)<0.25,color='black')

# %%
a=np.linspace(-2,2,10,endpoint=True)
a

# abs(a-0.25)

# abs(a-0.25)<0.25

# abs(a)<0.25

# abs(a+0.5)

# a+0.5

a-0.5
# Out:
# array([-2.5       , -2.05555556, -1.61111111, -1.16666667, -0.72222222,
#        -0.27777778,  0.16666667,  0.61111111,  1.05555556,  1.5       ])

# %%
def f(t):
    si=np.cos(2*np.pi*t)
    ei=np.exp(-t)
    return si*ei

# %%
t1 = np.arange(0.0,5.0,0.2)
l = plt.plot(t1,f(t1),'o')
xmin, xmax = xlim = 0, 10
ymin, ymax = ylim = 0, 1

fig, ax = plt.subplots()
ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)

X = [[0, 0], [1, 1]]
ax.imshow(X, interpolation='bicubic', cmap=plt.cm.copper,
          extent=(xmin, xmax, ymin, ymax), alpha=1)

plt.setp(l,markersize=30)
# plt.setp(l,markerfacecolor='C0')
# plt.minorticks_on()
# plt.colormaps('gist_earth')
ax.set_aspect('auto')
# plt.imshow()
plt.show()

# %%
np.random.seed(19680801)


def gbar(ax, x, y, width=0.5, bottom=0):
    X = [[.6, .6], [.7, .7]]
    for left, top in zip(x, y):
        right = left + width
        ax.imshow(X, interpolation='bicubic', cmap=plt.cm.Blues,
                  extent=(left, right, bottom, top), alpha=1)


xmin, xmax = xlim = 0, 10
ymin, ymax = ylim = 0, 1

fig, ax = plt.subplots()
ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)

X = [[.6, .6], [.7, .7]]
ax.imshow(X, interpolation='bicubic', cmap=plt.cm.copper,
          extent=(xmin, xmax, ymin, ymax), alpha=1)

N = 10
x = np.arange(N) + 0.25
y = np.random.rand(N)
gbar(ax, x, y, width=0.7)
ax.set_aspect('auto')
plt.show()

# %%
np.random.seed(19680801)

def gbar(ax,x,y,width=0.5,bottom=0):
    n = [[0,1],[0,1]]
    for left,top in zip(x,y):
        right=left+width
        ax.imshow(n,interpolation='bicubic',cmap=plt.cm.Blues,
                  extent=(left,right,bottom,top),alpha=1)
        
xmin,xmax=xlim=0,10
ymin,ymax=ylim=0,1

fig,ax=plt.subplots()
ax.set(xlim=xlim,ylim=ylim,autoscale_on=False)

X=[[0,0],[1,1]]
ax.imshow(X,interpolation='bicubic',cmap=plt.cm.copper,extent=(xmin,xmax,ymin,ymax),alpha=0.68)

N=10
x=np.arange(N)+0.25
y=np.random.rand(N)
gbar(ax,x,y,width=0.7)
ax.set_aspect('auto')
plt.show()

# %%
N=10
x=np.arange(N)+0.25
x
# Out:
# array([0.25, 1.25, 2.25, 3.25, 4.25, 5.25, 6.25, 7.25, 8.25, 9.25])

# %%
x=[0,2,4,6]
y=[0,2,1,4]
plt.figure()
plt.plot(x,y,'black',linestyle='-',linewidth=6)
plt.annotate('2',xy=(4,1),xytext=(2,4),arrowprops=dict(facecolor='red',shrink=0.05))
plt.annotate('2',xy=(4,1),xytext=(2,4),arrowprops = dict(arrowstyle = "<->",
        connectionstyle = "angle,angleA=0,angleB=90,rad=10"))
plt.show()

# %%
fig =plt.figure()
ax = fig.add_subplot(2,2,1,frameon=False)
x=[0,2,4,6]
y=[0,2,1,4]
plt.plot(x,y)
ax = fig.add_subplot(2,2,2, facecolor='red')
x=[0,2,4,6]
y=[0,2,1,2]
plt.plot(x,y)
ax = fig.add_subplot(2,2,3)
x=[0,2,4,6]
y=[0,2,4,6]
plt.plot(x,y)
ax = fig.add_subplot(2,2,4,projection='polar')
x=[0,2,4,6]
y=[0,2,4,6]
plt.plot(x,y)
plt.tight_layout() 
plt.show()

# %%
from numpy.random import rand
fig, ax = plt.subplots()
for color in ['red', 'green', 'blue']:
    n = 50
    x, y = rand(2, n)
    scale = 200.0 * rand(n)
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)

plt.show()

# %%
x
# Out:
# array([0.65158463, 0.45478884, 0.10799192, 0.15033529, 0.74624683,
#        0.49642103, 0.69102908, 0.7217347 , 0.17328427, 0.18852234,
#        0.31915315, 0.64358953, 0.35201455, 0.5147325 , 0.64755334,
#        0.56944952, 0.57465831, 0.88133596, 0.13030377, 0.31379371,
#        0.53574617, 0.01378443, 0.75405994, 0.59584176, 0.41748322,
#        0.79540394, 0.82957669, 0.46547425, 0.30569805, 0.97617182,
#        0.24621541, 0.56302617, 0.99581308, 0.67963193, 0.90970073,
#        0.20529684, 0.17333268, 0.97542916, 0.22195421, 0.6032333 ,
#        0.70847   , 0.98600336, 0.97675257, 0.80496089, 0.33151835,
#        0.70424757, 0.81488359, 0.95638465, 0.81566509, 0.01930152])

# %%
plt.figure()
# fig.add_subplot()
n=10
X=np.arange(n)
Y1 = (1-X/float(n)*np.random.uniform(0.5,1.0,n))
Y2 = (1-X/float(n)*np.random.uniform(0.5,1.0,n))
plt.bar(X,+Y1,facecolor='#9999ff',edgecolor='white')
plt.bar(X,-Y2,facecolor='#ff9999',edgecolor='white')
for x,y in zip(X,Y1):
    plt.text(x+0.1,y,'%.2f'%y,ha='center',va='bottom') # 给上边添加注释
for x,y in zip(X,Y2):
    plt.text(x,-y-0.05,'%.2f'%y,ha='center',va='top') # 给下边添加注释
plt.tight_layout()
plt.show()

# %%
n = 5
x1 = np.arange(1,n)
x1
# Out:
# array([1, 2, 3, 4])

# %%
y1=x1
y2=x1*(3/4)

plt.bar(x1,+y1,facecolor='#2419f3',edgecolor='white')
plt.bar(x1,-y2,facecolor='#25e40c',edgecolor='white')
for x,y in zip(x1,y1):
    plt.text(x,y,'%.2f'%y,ha='center',va='bottom')
for x,y in zip(x1,y2):
    plt.text(x,-y,'%.2f'%y,ha='center',va='top')

# %%
n = np.arange(10)
a = n
b = n
fig =plt.figure()
ax = fig.add_subplot(2,2,1,projection='polar')
plt.plot(a,b)

# %%
a = plt.subplot(121, projection='polar')

b = plt.subplot(122, projection='polar')

t=np.linspace(0,2*np.pi,30) #采样

a.plot(t,np.sin(3*t),'.',c='g',)

b.plot(t,np.sin(3*t),'-',c='r',)

plt.show()

# %%
plt.figure()
plt.subplot(projection='polar')
t=np.arange(0,2*np.pi+1,2*np.pi/6) #采样
b = [6,6,6,6,6,6,6]
plt.plot(t,b,'-',c='r',)
plt.show()

# %%
plt.figure()
plt.subplot(projection='polar')
t=[np.pi/2,2*np.pi*(5/8),np.pi*(1/8),np.pi*(7/8),2*np.pi*(7/8),np.pi/2,np.pi/2] #采样
b = [3,3,3,3,3,3,7]
plt.plot(t,b,'-',c='silver',)
plt.fill(np.arange(0,2*np.pi,2*np.pi/1000),np.random.randint(7,8,1000),'red',
         np.arange(0,2*np.pi,2*np.pi/1000),np.random.randint(6,7,1000),'silver',
         np.arange(0,2*np.pi,2*np.pi/1000),np.random.randint(5,6,1000),'red',
         np.arange(0,2*np.pi,2*np.pi/1000),np.random.randint(4,5,1000),'blue',
         t,b,'white',)
plt.show()

# %%
np.random.randint(4,5,6)
# Out:
# array([4, 4, 4, 4, 4, 4])

# %%
labels='a','b','c','d'
sizes=[20,15,35,30]
explode=(0,0,0,0.1)
fig = plt.figure()
ax = fig.add_subplot(1,2,1)
plt.pie(sizes,explode=explode,labels=labels,autopct='%1.0f%%',shadow=True,startangle=180)
ax.axis('equal')
ax = fig.add_subplot(1,2,2)
plt.pie(sizes,explode=explode,labels=labels,autopct='%.0f%%',shadow=False,startangle=180)
ax.axis('equal')
plt.show()

# %%
n = 20
z=np.ones(n)
z[-1]*=2
# plt.figure(10)
fig,ax=plt.subplots(2,2)
ax[0,0].pie(z,explode=z*0.05,colors=['%f'%(i/float(n)) for i in range(n)],    #白黑色
        labels=['%.2f'%(i/float(n))for i in range(n)])
ax[0,0].set_aspect('equal')
ax[0,1].pie(z,explode=z*0.05,    #默认彩色
        labels=['%.2f'%(i/float(n))for i in range(n)])
ax[0,1].set_aspect('equal')
ax[1,0].pie(z,explode=z*0.05,colors=('b','g','r','snow','aqua'),    #指定颜色
        labels=['%.2f'%(i/float(n))for i in range(n)],radius=2)   #radius 图的大小，默认1
ax[1,0].set_aspect('equal')
ax[1,1].pie(z, explode=None, labels=['%.2f'%(i/float(n))for i in range(n)],  
    colors=('b', 'g', 'r', 'c', 'm', 'y', 'k', 'w'),  
    center = (0, 0.1), frame = True ) #center(x,y) 圆中心的位置
ax[1,1].set_aspect('equal')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
#半径为r的球的方程为： r**2=x**2+y**2+z**2
X = np.arange(-np.pi, np.pi, 0.1)
Y = np.arange(-np.pi, np.pi, 0.1)
# Z = np.arange(0, np.pi, 0.1)
X, Y = np.meshgrid(X,Y)
# Z = np.cos(X**2 + Y**2)
R = np.sqrt(X**2 + Y**2)
Z = R

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.Blues)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.cbook as cbook
with cbook.get_sample_data(r'C:\Users\ZDH\Pictures\Camera Roll\pyt.jpg') as image_file:
    image = plt.imread(image_file)

fig, ax = plt.subplots()
im = ax.imshow(image)
patch = patches.Circle((260, 200), radius=200, transform=ax.transData)
im.set_clip_path(patch)

ax.axis('off')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from itertools import product, combinations
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_aspect("equal")

#draw cube
r = [-1, 1]
for s, e in combinations(np.array(list(product(r,r,r))), 2):
    if np.sum(np.abs(s-e)) == r[1]-r[0]:
        ax.plot3D(*zip(s,e), color="b")

#draw sphere
u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:10j]
x=np.cos(u)*np.sin(v)
y=np.sin(u)*np.sin(v)
z=np.cos(v)
ax.plot_wireframe(x, y, z, color="r")

#draw a point
ax.scatter([0],[0],[0],color="g",s=100)

#draw a vector
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d

class Arrow3D(FancyArrowPatch):
    def __init__(self, xs, ys, zs, *args, **kwargs):
        FancyArrowPatch.__init__(self, (0,0), (0,0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
        FancyArrowPatch.draw(self, renderer)

a = Arrow3D([0,1],[0,1],[0,1], mutation_scale=20, lw=1, arrowstyle="-|>", color="k")
ax.add_artist(a)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D, axes3d
import matplotlib.pyplot as plt
import numpy as np

# center and radius
center = [1,2,3]
radius = 10

# data
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = radius * np.outer(np.cos(u), np.sin(v)) + center[0]
y = radius * np.outer(np.sin(u), np.sin(v)) + center[1]
z = radius * np.outer(np.ones(np.size(u)), np.cos(v)) + center[2]

# plot
fig = plt.figure()
ax = fig.add_subplot(121, projection='3d')

# surface plot
ax.plot_surface(x, y, z,  rstride=4, cstride=4, color='b')

# wire frame
ax = fig.add_subplot(122, projection='3d')
ax.plot_wireframe(x, y, z, rstride=10, cstride=10)

# show
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd

# %%
img = mpimg.imread(r'C:\Users\ZDH\Pictures\Saved Pictures\t.jpg')
# Out:
# [[[10  7 28]
#   [22 19 40]
#   [18 15 36]
#   ...
#   [11 18 28]
#   [13 17 28]
#   [ 6 10 19]]
#
#  [[10  7 28]
#   [23 20 41]
#   [18 15 36]
#   ...
#   [11 18 28]
#   [12 16 27]
#   [ 6 10 21]]
#
#  [[11  8 29]
#   [23 20 41]
#   [19 16 37]
#   ...
#   [10 17 27]
#   [11 15 26]
#   [ 7 11 22]]
#
#  ...
#
#  [[29 32 73]
#   [32 35 76]
#   [13 18 58]
#   ...
#   [ 7  3  0]
#   [ 7  3  0]
#   [ 7  3  0]]
#
#  [[28 33 75]
#   [16 23 65]
#   [ 0  6 48]
#   ...
#   [ 7  3  0]
#   [ 7  3  0]
#   [ 7  3  0]]
#
#  [[14 23 66]
#   [12 19 63]
#   [ 6 13 57]
#   ...
#   [ 7  3  0]
#   [ 7  3  0]
#   [ 7  3  0]]]

# %%
img
# Out:
# array([[[10,  7, 28],
#         [22, 19, 40],
#         [18, 15, 36],
#         ...,
#         [11, 18, 28],
#         [13, 17, 28],
#         [ 6, 10, 19]],
#
#        [[10,  7, 28],
#         [23, 20, 41],
#         [18, 15, 36],
#         ...,
#         [11, 18, 28],
#         [12, 16, 27],
#         [ 6, 10, 21]],
#
#        [[11,  8, 29],
#         [23, 20, 41],
#         [19, 16, 37],
#         ...,
#         [10, 17, 27],
#         [11, 15, 26],
#         [ 7, 11, 22]],
#
#        ...,
#
#        [[29, 32, 73],
#         [32, 35, 76],
#         [13, 18, 58],
#         ...,
#         [ 7,  3,  0],
#         [ 7,  3,  0],
#         [ 7,  3,  0]],
#
#        [[28, 33, 75],
#         [16, 23, 65],
#         [ 0,  6, 48],
#         ...,
#         [ 7,  3,  0],
#         [ 7,  3,  0],
#         [ 7,  3,  0]],
#
#        [[14, 23, 66],
#         [12, 19, 63],
#         [ 6, 13, 57],
#         ...,
#         [ 7,  3,  0],
#         [ 7,  3,  0],
#         [ 7,  3,  0]]], dtype=uint8)

# %%
df = pd.read_csv(r'../train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
help(df.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise') method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Whether to drop labels from the index (0 or 'index') or
#         columns (1 or 'columns').
#     index, columns : single label or list-like
#         Alternative to specifying axis (``labels, axis=1``
#         is equivalent to ``columns=labels``).
#
#         .. versionadded:: 0.21.0
# ...

# %%
df = df.drop(columns=['PassengerId','Name','Ticket','Cabin'])

# %%
a = df.Embarked.isnull()
b = a[a==True].index
df = df.drop(index=b)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  22.0      1      0    7.2500        S
# 1           1       1  female  38.0      1      0   71.2833        C
# 2           1       3  female  26.0      0      0    7.9250        S
# 3           1       1  female  35.0      1      0   53.1000        S
# 4           0       3    male  35.0      0      0    8.0500        S
# 6           0       1    male  54.0      0      0   51.8625        S
# 7           0       3    male   2.0      3      1   21.0750        S
# 8           1       3  female  27.0      0      2   11.1333        S
# 9           1       2  female  14.0      1      0   30.0708        C
# 10          1       3  female   4.0      1      1   16.7000        S
# 11          1       1  female  58.0      0      0   26.5500        S
# 12          0       3    male  20.0      0      0    8.0500        S
# 13          0       3    male  39.0      1      5   31.2750        S
# ...

# %%
s = df[df['Survived']==1]

# %%
len(s)
# Out:
# 342

# %%
df['Survived'].value_counts().plot.bar()

# %%
df.groupby('Survived').count()
# Out:
#           Pclass  Sex  Age  SibSp  Parch  Fare  Embarked
# Survived
# 0            549  549  424    549    549   549       549
# 1            342  342  290    342    342   342       340

# %%
df.Age.min()
# Out:
# 0.42

# %%
df1=df[df.Age<16]
df2=df[df.Age>50]
df3=pd.concat([df1,df2])

# %%
df3.Survived.value_counts()
# Out:
# 0    76
# 1    70
# Name: Survived, dtype: int64

# %%
df['Survived'].corr(df['Pclass'])
# Out:
# -0.3564615884452385

# %%
df['Survived'].corr(df['SibSp'])
# Out:
# -0.015523023631749507

# %%
--
