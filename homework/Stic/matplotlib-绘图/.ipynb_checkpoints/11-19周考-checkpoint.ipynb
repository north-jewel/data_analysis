# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1

# %%
x = [0,1,2,1,0]
y = [1,0,1,2,1]
plt.figure()
plt.plot(x,y)
plt.fill_between(x,y,'b')

# %% [markdown]
# # 2

# %%
x=[0,2,4,5]
y=[0,3,4,2]
plt.figure()
plt.plot(x,y,'yellow',linewidth=6)
plt.annotate('(4,4)',xy=(4,4),xytext=(4,5),arrowprops=dict(arrowstyle = "<-",))
# Out:
# Text(4,5,'(4,4)')

# %% [markdown]
# # 3

# %%
def draw_curcle(c,l,arg=1):
    var = np.linspace(-np.pi,np.pi,266,endpoint=True)
    x=np.cos(var)*arg
    y=np.sin(var)*arg
    plt.plot(x,y,linewidth=4.0,linestyle=l,color=c,alpha=0.5)
    plt.axis('equal')

# %%
draw_curcle('black','-',5)
plt.legend('圆')
ax = plt.gca()
ax.spines['bottom']. set_position(('data',0))   
ax.spines['left']. set_position(('data',0))
ax.spines['top']. set_color('none')
ax.spines['right']. set_color('none')
plt.xticks([-1.0,0,1.0],[-5,0,5]) 
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %% [markdown]
# # 4

# %%
draw_curcle('red','--',3)
plt.legend('圆')
ax = plt.gca()
ax.spines['bottom']. set_position(('data',0))   
ax.spines['left']. set_position(('data',0))
ax.spines['top']. set_color('none')
ax.spines['right']. set_color('none')
plt.xticks([-1.0,0,1.0],[-5,0,5]) 
ax.fill_between(x*3,0,y*3,y>0,color='blue')
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)
