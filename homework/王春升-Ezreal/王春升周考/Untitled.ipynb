# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib #only needed to determine Matplotlib version number
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']

# %%
info = pd.read_csv(r'C:\Users\12193\Desktop\info.csv')

# %% [markdown]
# ### 车主评价比较高

# %%
info[info['Ownerevaluate']=='优秀']
# Out:
#              Carname   Officialprice            Carfuelc   Brand  \
# 0       smart fortwo    11.68-30.89万   5.00-11.80L/100km   smart
# 1      smart forfour    12.58-22.08万   5.10-12.00L/100km   smart
# 5              北斗星X5      4.69-5.19万    6.20-6.70L/100km      铃木
# 19             凯翼C3R      4.58-6.08万    6.00-9.10L/100km      凯翼
# 24                瑞纳      4.99-7.39万    6.10-8.50L/100km      现代
# 25                悦翔      4.99-6.59万    6.10-9.30L/100km    长安汽车
# 29              凯翼C3      4.58-6.08万    6.30-7.70L/100km      凯翼
# 35                悦纳     7.28-10.58万    6.60-7.10L/100km      现代
# 46       MINI CABRIO    29.88-38.50万   7.30-13.30L/100km    MINI
# 47      MINI CLUBMAN    23.98-35.08万   7.50-10.20L/100km    MINI
# 49           秦Pro新能源    14.99-29.99万    2.50-5.00L/100km     比亚迪
# 50             荣威ei6    20.18-22.28万    3.40-8.20L/100km      荣威
# 53               普锐斯    22.98-26.98万         4.70L/100km      丰田
# ...

# %% [markdown]
# ### 价格最大

# %%
info[info['Officialprice'] == info['Officialprice'].max()]#有问题~并不是价格最大
# Out:
#       Carname  Officialprice            Carfuelc Brand          MIITfuelc  \
# 264  Panamera  99.80-217.80万  11.50-15.50L/100km   保时捷  9.30-12.20L/100km
#
#     Rank                                    Displacement Gearbox Cartype  \
# 264  大型车  '2.9T', '3.0T', '3.6L', '4.0T', '4.8L', '4.8T'     双离合     掀背车
#
#                     Ranking  Carstrength Configuration Major Ownerevaluate  \
# 264  该车暂未被列入榜单，暂无排名信息查看详情>>         56.7            良好   测试中            优秀
#
#     Price                              Versions_1 Versionsp_1  \
# 264    优秀   2019款 Panamera GTS Sport Turismo 4.0T      187.8万
#
#                    Versions_2 Versionsp_2                                  URL
# 264   2019款 Panamera GTS 4.0T      184.8万  https://price.pcauto.com.cn/sg3756/

# %% [markdown]
# ### 排量最大

# %%
info[info['Displacement'] == info['Displacement'].max()]
# Out:
#     Carname    Officialprice            Carfuelc Brand           MIITfuelc  \
# 266      幻影  688.00-1488.00万  13.00-31.00L/100km  劳斯莱斯  15.70-17.00L/100km
#
#     Rank Displacement Gearbox Cartype                 Ranking  Carstrength  \
# 266  大型车       '6.7L'      自动     三厢车  该车暂未被列入榜单，暂无排名信息查看详情>>         52.3
#
#     Configuration Major Ownerevaluate Price      Versions_1 Versionsp_1  \
# 266            良好   测试中            良好    良好   2018款 绅士之旅定制版         未上市
#
#          Versions_2 Versionsp_2                                  URL
# 266   2018款 私享秘境特别版         未上市  https://price.pcauto.com.cn/sg2313/

# %% [markdown]
# ### 排量最小

# %%
info[info['Officialprice'] == info['Officialprice'].min()]
# Out:
#      Carname Officialprice           Carfuelc Brand MIITfuelc Rank  \
# 997    五十铃皮卡  10.13-14.08万  7.00-15.00L/100km   五十铃       NaN   皮卡
# 1037   五十铃皮卡  10.13-14.08万  7.00-15.00L/100km   五十铃       NaN   皮卡
#
#                       Displacement Gearbox Cartype                 Ranking  \
# 997   '2.6L', '2.8T', '--', '3.0T'      手动      皮卡  该车暂未被列入榜单，暂无排名信息查看详情>>
# 1037  '2.6L', '2.8T', '--', '3.0T'      手动      皮卡  该车暂未被列入榜单，暂无排名信息查看详情>>
#
#       Carstrength Configuration Major Ownerevaluate Price  Versions_1  \
# 997          30.6            较弱   测试中            较弱    较弱   2015款 基本型
# 1037         30.6            较弱   测试中            较弱    较弱   2015款 基本型
#
#      Versionsp_1                  Versions_2 Versionsp_2  \
# 997         即将上市   2014款 2.8L四驱 QL10302DWS/Y      11.57万
# 1037        即将上市   2014款 2.8L四驱 QL10302DWS/Y      11.57万
#
#                                        URL
# 997   https://price.pcauto.com.cn/sg10690/
# 1037  https://price.pcauto.com.cn/sg10690/

# %% [markdown]
# ### 未上市的车有哪些

# %%
info[info['Versionsp_1'] == '未上市']
# Out:
#            Carname   Officialprice            Carfuelc      Brand  \
# 0     smart fortwo    11.68-30.89万   5.00-11.80L/100km      smart
# 4             奇瑞QQ      3.79-5.09万    5.50-5.80L/100km         奇瑞
# 7              北斗星      3.99-4.49万    6.70-7.00L/100km         铃木
# 18          中华H220      5.48-7.98万    6.00-8.70L/100km         中华
# 19           凯翼C3R      4.58-6.08万    6.00-9.10L/100km         凯翼
# 24              瑞纳      4.99-7.39万    6.10-8.50L/100km         现代
# 32           MINI     18.50-34.38万   6.40-13.10L/100km       MINI
# 38              骊威     8.58-11.72万    6.80-9.00L/100km         日产
# 44             速翼特    17.88-18.88万    7.30-7.80L/100km         铃木
# 46     MINI CABRIO    29.88-38.50万   7.30-13.30L/100km       MINI
# 47    MINI CLUBMAN    23.98-35.08万   7.50-10.20L/100km       MINI
# 48              焕驰      4.99-7.39万   8.20-10.30L/100km         起亚
# 51           卡罗拉双擎    13.98-17.58万    4.40-9.00L/100km         丰田
# ...

# %% [markdown]
# ### 小型车有哪些

# %%
info[info['Rank'] == '小型车']
# Out:
#          Carname Officialprice           Carfuelc Brand         MIITfuelc  \
# 8          启辰R30    3.99-5.19万   4.90-6.00L/100km  东风启辰               NaN
# 9          宝骏310    3.68-6.08万   5.00-8.10L/100km    宝骏               NaN
# 10          夏利A+    2.88-3.78万   5.00-9.00L/100km    一汽  5.00-6.00L/100km
# 11          威驰FS   6.98-10.98万   5.00-9.00L/100km    丰田               NaN
# 12            玛驰    5.98-8.75万   5.20-8.00L/100km    日产  6.20-6.60L/100km
# 13            威驰   6.98-11.38万   5.50-8.30L/100km    丰田  5.20-8.10L/100km
# 14         绅宝D20    4.88-8.28万  5.70-10.00L/100km  北汽绅宝               NaN
# 15           爱唯欧   7.39-10.99万   5.80-9.60L/100km   雪佛兰  6.00-7.20L/100km
# 16          悦翔V3    4.39-4.99万   5.90-8.80L/100km  长安汽车               NaN
# 17          夏利N5    3.89-5.19万   5.90-8.90L/100km    一汽  5.40-5.49L/100km
# 18        中华H220    5.48-7.98万   6.00-8.70L/100km    中华               NaN
# 19         凯翼C3R    4.58-6.08万   6.00-9.10L/100km    凯翼               NaN
# ...

# %% [markdown]
# ### 车实力评分最高的是哪个？

# %%
info[info['Carstrength'] == info['Carstrength'].max()]
# Out:
#     Carname  Officialprice           Carfuelc Brand          MIITfuelc Rank  \
# 258    宝马7系  82.80-248.80万  9.00-12.30L/100km    宝马  8.50-13.60L/100km  大型车
#
#                                           Displacement Gearbox Cartype  \
# 258  '2.0T', '3.0L', '3.0T', '4.0T', '4.4T', '6.0T'...    手自一体     三厢车
#
#                      Ranking  Carstrength Configuration Major Ownerevaluate  \
# 258  该车车实力评分高于75%同级别车系查看详情>>         86.9            优秀    优秀            优秀
#
#     Price                  Versions_1 Versionsp_1            Versions_2  \
# 258    优秀   2018款 M760Li xDrive 卓越奢华版      248.8万   2018款 M760Li xDrive
#
#     Versionsp_2                                 URL
# 258      248.8万  https://price.pcauto.com.cn/sg164/
