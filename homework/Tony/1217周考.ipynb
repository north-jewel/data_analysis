# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\15730\notebook\car\info.csv')

# %%
df.columns = ['车名','官方价','车主平均油耗','品牌','工信部油耗','级别','排量','变速箱','车身类型','排名','车实力','配置水平','专业测评','车主评价','价格','版本1','版本售价1','版本2','版本售价2','url']

# %%
df.head()
# Out:
#               车名           官方价             车主平均油耗     品牌             工信部油耗  \
# 0   smart fortwo  11.68-30.89万  5.00-11.80L/100km  smart  4.20-5.20L/100km
# 1  smart forfour  12.58-22.08万  5.10-12.00L/100km  smart               NaN
# 2          比亚迪F0    3.79-4.79万   5.20-6.60L/100km    比亚迪       4.20L/100km
# 3             奥拓    4.18-6.19万   5.20-8.30L/100km     铃木  3.60-4.00L/100km
# 4           奇瑞QQ    3.79-5.09万   5.50-5.80L/100km     奇瑞               NaN
#
#     级别                             排量  变速箱 车身类型                      排名   车实力  \
# 0  微型车  '0.9T', '1.0L', '1.0T', '纯电动'  双离合  两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>  45.0
# 1  微型车                 '0.9T', '1.0L'  双离合  两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>  44.7
# 2  微型车                         '1.0L'   手动  两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>  35.7
# 3  微型车                         '1.0L'   手动  两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>  37.2
# 4  微型车                         '1.0L'   手动  两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>  37.2
#
# ...

# %% [markdown]
# # 最贵的是哪款车?

# %%
df1 = df
df1.官方价 = df1.官方价.apply(lambda x:x[0:-2])
df1.官方价 = df1.官方价.apply(lambda x:x.split('-'))
df1.官方价 = df1.官方价.apply(lambda x:float(max(x)))

# %%
df1[df1['官方价'] == df1['官方价'].max()]
# Out:
#      车名    官方价              车主平均油耗    品牌               工信部油耗   级别      排量 变速箱  \
# 266  幻影  688.0  13.00-31.00L/100km  劳斯莱斯  15.70-17.00L/100km  大型车  '6.7L'  自动
#
#     车身类型                      排名   车实力 配置水平 专业测评 车主评价  价格             版本1  \
# 266  三厢车  该车暂未被列入榜单，暂无排名信息查看详情>>  52.3   良好  测试中   良好  良好   2018款 绅士之旅定制版
#
#     版本售价1             版本2 版本售价2                                  url
# 266   未上市   2018款 私享秘境特别版   未上市  https://price.pcauto.com.cn/sg2313/

# %%
df.shape
# Out:
# (1044, 20)

# %% [markdown]
# # 小排量车有哪些?

# %%
df.排量.sort_values().head()
# Out:
# 989                                       '--'
# 1022                                      '--'
# 7       '0.8L', '1.0L', '1.1L', '1.2L', '1.4L'
# 1                               '0.9T', '1.0L'
# 0                '0.9T', '1.0L', '1.0T', '纯电动'
# Name: 排量, dtype: object

# %% [markdown]
# # 大排量车有哪些?

# %%
df.排量.sort_values().tail()
# Out:
# 565     '5.3L', '6.2L'
# 884     '5.3L', '6.2L'
# 1009            '5.7L'
# 1043            '5.7L'
# 266             '6.7L'
# Name: 排量, dtype: object

# %%
df.车名.value_counts()
# Out:
# 荣威W5           2
# 睿行             2
# 讴歌CDX          2
# 途昂             2
# STARTECH揽胜     2
# 比速T5           2
# 景逸X6           2
# 柯珞克            2
# 海马S7           2
# 奔驰GLE          2
# 北汽威旺M20        2
# 力帆X60          2
# 力帆X50          2
# 瑞虎5x           2
# 林肯MKC          2
# GLE级AMG        2
# 超级维特拉          2
# 圣达菲            2
# 全新胜达(进口)       2
# 比亚迪S6          2
# 森林人            2
# 蒂维拉            2
# 远景SUV          2
# 缤智             2
# 荣威RX3          2
# 雷克萨斯RX         2
# 风行T5           2
# 帕杰罗(进口)        2
# 优优             2
# 长安之星2          2
#               ..
# 比亚迪M6          1
# 赛欧3            1
# 伽途im           1
# 宝骏730          1
# 普瑞维亚           1
# 长安CX20         1
# 宝马7系           1
# 风光330          1
# 中华H220         1
# 风行S500         1
# 欧陆             1
# 哥瑞             1
# 观致3            1
# 夏利N7           1
# LA FESTA菲斯塔    1
# 君威             1
# 飞驰             1
# 风行CM7          1
# 起亚K5           1
# 传祺GM8          1
# MINI CABRIO    1
# ...

# %% [markdown]
# # 哪些车车主评价比较高?

# %%
df1[df1['车主评价'] == '优秀']['车名']
# Out:
# 0         smart fortwo
# 1        smart forfour
# 5                北斗星X5
# 19               凯翼C3R
# 24                  瑞纳
# 25                  悦翔
# 29                凯翼C3
# 35                  悦纳
# 46         MINI CABRIO
# 47        MINI CLUBMAN
# 49             秦Pro新能源
# 50               荣威ei6
# 53                 普锐斯
# 57                  凌派
# 58                  阅朗
# 60              名爵6新能源
# 62                  骐达
# 63                奥迪A3
# 67                  缤瑞
# 68               启辰D60
# 70                  启悦
# 71              雷克萨斯CT
# 74                 科鲁兹
# 77                 科沃兹
# 79               标致408
# 96                名爵GT
# 97               艾瑞泽GX
# 109                名爵6
# 111              奔腾B50
# 114              艾瑞泽EX
#              ...
# 946                 威霆
# 947              星驰斯宾特
# 948         C4 PICASSO
# 949              福美来F7
# 956               星驰V级
# 960                 塞纳
# 961                 贵士
# 962               DB11
# 963           捷豹F-TYPE
# ...

# %%
df1[df1['车主评价'] == '优秀'].groupby(by = ['级别']).head()
# Out:
#                   车名     官方价              车主平均油耗      品牌               工信部油耗  \
# 0       smart fortwo   30.80   5.00-11.80L/100km   smart    4.20-5.20L/100km
# 1      smart forfour   22.00   5.10-12.00L/100km   smart                 NaN
# 5              北斗星X5    5.10    6.20-6.70L/100km      铃木                 NaN
# 19             凯翼C3R    6.00    6.00-9.10L/100km      凯翼                 NaN
# 24                瑞纳    7.30    6.10-8.50L/100km      现代    4.80-5.00L/100km
# 25                悦翔    6.50    6.10-9.30L/100km    长安汽车    6.90-7.80L/100km
# 29              凯翼C3    6.00    6.30-7.70L/100km      凯翼                 NaN
# 35                悦纳    7.28    6.60-7.10L/100km      现代                 NaN
# 49           秦Pro新能源   29.90    2.50-5.00L/100km     比亚迪                 NaN
# 50             荣威ei6   22.20    3.40-8.20L/100km      荣威                 NaN
# 53               普锐斯   26.90         4.70L/100km      丰田    4.30-4.70L/100km
# ...
