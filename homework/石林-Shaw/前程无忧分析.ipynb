# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
mpl.rcParams['font.sans-serif']=['SimHei']#显示中文
mpl.rcParams['font.serif'] = ['KaiTi']
matplotlib.rcParams['axes.unicode_minus']=False#显示负号
from wordcloud import WordCloud

# %%
df = pd.read_csv(r'C:\Users\Shilin\Desktop\qiancheng_data.csv',encoding = 'gbk')
df
# Out:
#                                                 title       company_name  \
# 0                                         Python开发工程师   联合永道（上海）信息技术有限公司
# 1                                     Python实习-机器学习方向   寰宇优才教育科技（北京）有限公司
# 2                                         Python开发工程师     北京万维盈创科技发展有限公司
# 3                                         Python开发工程师         北京学神科技有限公司
# 4     Python研发负责人(001066)\t\t\t\t(职位编号：rong360001066)     北京融联世纪信息技术有限公司
# 5                                       全栈python开发工程师       北京道冲泰科科技有限公司
# 6                                       Python高级开发工程师     叠云（北京）科技股份有限公司
# 7                                       Python高级开发工程师         南京高泰科技有限公司
# 8                                    Python开发工程师(石家庄）         北京慧铭软件有限公司
# 9                                      Python开发工程师-ZH     北京四维图新科技股份有限公司
# 10                                        Python开发工程师  中国广视索福瑞媒介研究有限责任公司
# 11                                      Python高级开发工程师       北京棣南新宇科技有限公司
# ...

# %%
df = df[df.company_site.str.startswith('北京')==True]
df
# Out:
#                                                 title       company_name  \
# 0                                         Python开发工程师   联合永道（上海）信息技术有限公司
# 1                                     Python实习-机器学习方向   寰宇优才教育科技（北京）有限公司
# 2                                         Python开发工程师     北京万维盈创科技发展有限公司
# 3                                         Python开发工程师         北京学神科技有限公司
# 4     Python研发负责人(001066)\t\t\t\t(职位编号：rong360001066)     北京融联世纪信息技术有限公司
# 5                                       全栈python开发工程师       北京道冲泰科科技有限公司
# 6                                       Python高级开发工程师     叠云（北京）科技股份有限公司
# 7                                       Python高级开发工程师         南京高泰科技有限公司
# 9                                      Python开发工程师-ZH     北京四维图新科技股份有限公司
# 10                                        Python开发工程师  中国广视索福瑞媒介研究有限责任公司
# 11                                      Python高级开发工程师       北京棣南新宇科技有限公司
# 12                              云平台开发工程师（JAVA、Python）     航天星图科技（北京）有限公司
# ...

# %%
df.columns
# Out:
# Index(['title', 'company_name', 'salary', 'company_site',
#        'experience_required', 'edu_required', 'release_time',
#        'company_welfare', 'job_info', 'company_location', 'company_info'],
#       dtype='object')

# %% [markdown]
# # 薪资分布

# %%
s = df.groupby(by = 'salary').count()
s1 = s.sort_values(by = 'title',ascending = False)
s1
# Out:
#             title  company_name  company_site  experience_required  \
# salary
# 1-1.5万/月      625           625           625                  625
# 1.5-2万/月      462           462           462                  462
# 1-2万/月        336           336           336                  336
# 2-4万/月        269           269           269                  269
# 1.5-2.5万/月    249           249           249                  249
# 1.5-3万/月      245           245           245                  245
# 0.8-1万/月      172           172           172                  172
# 2-2.5万/月      164           164           164                  164
# 0.8-1.5万/月    147           147           147                  147
# 2-3万/月        122           122           122                  122
# 2.5-3万/月      122           122           122                  122
# 2.5-5万/月      109           109           109                  109
# 6-8千/月         92            92            92                   92
# ...

# %%
s = df.salary.value_counts()
s
# Out:
# 1-1.5万/月      625
# 1.5-2万/月      462
# 1-2万/月        336
# 2-4万/月        269
# 1.5-2.5万/月    249
# 1.5-3万/月      245
# 0.8-1万/月      172
# 2-2.5万/月      164
# 0.8-1.5万/月    147
# 2-3万/月        122
# 2.5-3万/月      122
# 2.5-5万/月      109
# 6-8千/月         92
# 3-4万/月         70
# 2-3.5万/月       67
# 0.8-1.2万/月     58
# 0.8-1.6万/月     52
# 0.6-1万/月       51
# 2.5-3.5万/月     50
# 3-6万/月         46
# 3-5万/月         45
# 1.2-2万/月       43
# 2.5-4万/月       36
# 0.6-1.2万/月     34
# 4.5-6千/月       30
# 4-5万/月         30
# 1-3万/月         30
# 2-3千/月         29
# 1-1.8万/月       29
# 1.2-2.4万/月     27
#              ...
# 5.5-6.5千/月      1
# 70元/天           1
# 2.8-3.3万/月      1
# 2-6万/月          1
# 3-3.5万/月        1
# 0.7-2万/月        1
# 3.5-6千/月        1
# 0.7-1.6万/月      1
# 24-120万/年       1
# 30-70万/年        1
# 2.9-4.5万/月      1
# 4-4.5万/月        1
# 1.2-2.2万/月      1
# 0.8-2.2万/月      1
# 1.4-1.8万/月      1
# 1.6-1.8万/月      1
# 5.2-8.2千/月      1
# 5-10万/年         1
# 2.2-4万/月        1
# ...

# %%
wc = WordCloud(font_path='./fonts/simhei.ttf',background_color="white")
wc.fit_words(df.salary.value_counts())
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# # 北京地区提供的岗位

# %%
c = df.groupby(by = 'company_site').count()
c1 = c.sort_values(by = 'title',ascending = False)
bj = c1.head(12)
bj
# Out:
#               title  company_name  salary  experience_required  edu_required  \
# company_site
# 北京             1957          1957    1443                 1957          1957
# 北京-海淀区         1727          1727    1712                 1727          1727
# 北京-朝阳区         1053          1053    1046                 1053          1053
# 北京-西城区          174           174     174                  174           174
# 北京-昌平区          164           164     164                  164           164
# 北京-东城区          134           134     126                  134           134
# 北京-丰台区          130           130     126                  130           130
# 北京-大兴区          109           109     108                  109           109
# 北京-石景山区          41            41      41                   41            41
# 北京-通州区           23            23      23                   23            23
# 北京-顺义区           20            20      20                   20            20
# ...

# %%
site = df.company_site.value_counts()
site
# Out:
# 北京         1957
# 北京-海淀区     1727
# 北京-朝阳区     1053
# 北京-西城区      174
# 北京-昌平区      164
# 北京-东城区      134
# 北京-丰台区      130
# 北京-大兴区      109
# 北京-石景山区      41
# 北京-通州区       23
# 北京-顺义区       20
# 北京-房山区       19
# 北京-门头沟区       3
# 北京-延庆区        2
# Name: company_site, dtype: int64

# %%
wc = WordCloud(font_path='./fonts/simhei.ttf',background_color="white")
wc.fit_words(df.company_site.value_counts())
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# # 工作年限要求

# %%
ex= df.groupby(by='experience_required').count()

# %%
ex
# Out:
#                      title  company_name  salary  company_site  edu_required  \
# experience_required
# 10年以上经验                 23            23      20            23            23
# 1年经验                   347           347     338           347           347
# 2年经验                   847           847     784           847           847
# 3-4年经验                1691          1691    1569          1691          1691
# 5-7年经验                 677           677     621           677           677
# 8-9年经验                  39            39      35            39            39
# 无工作经验                 1932          1932    1640          1932          1932
#
#                      release_time  company_welfare  job_info  \
# experience_required
# 10年以上经验                        23               23        23
# 1年经验                          347              347       347
# 2年经验                          847              847       847
# 3-4年经验                       1691             1691      1691
# ...

# %%
wc = WordCloud(font_path='./fonts/simhei.ttf',background_color="white")
wc.fit_words(df.experience_required.value_counts())
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# # 需要的技能

# %%
skill = df['job_info']
skill
# Out:
# 0       ['1.精通Python', '2.熟悉SQL语言，能熟练使用mysql，了解常用的SQL性...
# 1       ['（能力不足，但有Python开发意向者，可放宽要求提供实习岗位）', '', '1.本科...
# 2       ['岗位职责：', '1.协助团队进行桌面应用开开发框架的搭建、设计及开发规划；', '2....
# 3       ['', '岗位职责：', '1.围绕项目开展教学工作；', '2.给学生讲授知识点技术点以...
# 4       ['1.负责RC系统整体规划工作,负责团队工作；2.负责风控系统在线服务的设计、优化和研发工...
# 5       ['工作描述:', '*为桥梁、隧道、地铁等施工建设过程开发安全监测web平台', '*为公...
# 6       ['岗位职责：', '1、进行电子教室后台部分研发', '2、进行云端运维系统的研发', '...
# 7       ['1.5年以上开发经验，基本功扎实，精通Java；', '2.5年以上Linux经验，熟练...
# 9       ['岗位职责：', '1、负责公司内部管理后台及商业化应用产品的开发；', '2、负责项目文...
# 10      ['', '', '**工作职责**', '', '1Web系统开发和维护；', '', '...
# 11      ['\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t互联网软件开发工程师\...
# 12      ['岗位职责：', '1、开发和维护公司核心产品的存储管理层；', '2、开发和维护公司核心...
# 13                                                     []
# 14      ['岗位职责：', '1.研发python课程内容及课件；', '2.按照教学大纲、教学进度...
# 15      ['\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t...
# 16      ['【岗位职责】', '1、深入分布式平台架构，发现并解决系统的重大故障及性能瓶颈，打造一流...
# ...

# %%
nn = skill.str[1:-1].str.replace('xa0','').str.replace('工作职责:','').str.replace('岗位职责：','').str.replace('n','').str.replace('职能类别','').str.replace('任职资格','')
nn
# Out:
# 0       '1.精通Pytho', '2.熟悉SQL语言，能熟练使用mysql，了解常用的SQL性能优...
# 1       '（能力不足，但有Pytho开发意向者，可放宽要求提供实习岗位）', '', '1.本科以上...
# 2       '', '1.协助团队进行桌面应用开开发框架的搭建、设计及开发规划；', '2.协助团队撰写...
# 3       '', '', '1.围绕项目开展教学工作；', '2.给学生讲授知识点技术点以及项目实现思...
# 4       '1.负责RC系统整体规划工作,负责团队工作；2.负责风控系统在线服务的设计、优化和研发工作...
# 5       '工作描述:', '*为桥梁、隧道、地铁等施工建设过程开发安全监测web平台', '*为公司...
# 6       '', '1、进行电子教室后台部分研发', '2、进行云端运维系统的研发', '3、与终端团...
# 7       '1.5年以上开发经验，基本功扎实，精通Java；', '2.5年以上Liux经验，熟练使用...
# 9       '', '1、负责公司内部管理后台及商业化应用产品的开发；', '2、负责项目文档编写、配合...
# 10      '', '', '**工作职责**', '', '1Web系统开发和维护；', '', '2...
# 11      '\：\\r\\t\t\t\t\t\t\t\t\t\t互联网软件开发工程师\t\t\t\t\...
# 12      '', '1、开发和维护公司核心产品的存储管理层；', '2、开发和维护公司核心产品的服务容...
# 13
# 14      '', '1.研发pytho课程内容及课件；', '2.按照教学大纲、教学进度，高质量地完成...
# 15      '\：\\r\\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t...
# 16      '【岗位职责】', '1、深入分布式平台架构，发现并解决系统的重大故障及性能瓶颈，打造一流的...
# 17      '', '1、负责业务、财务与绩效指标的BI应用设计、开发与测试。', '2、解决在使用前端...
# ...

# %%
wc = WordCloud(font_path='./fonts/simhei.ttf',background_color="white")
wc.generate(str(nn))
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# # 公司福利

# %%
welfare = df.company_welfare.value_counts()
welfare
# Out:
# []                                                                                    1554
# ['周末双休', '带薪年假', '五险一金', '免费班车', '绩效奖金', '节日福利', '专业培训', '餐饮补贴', '免费健身']                54
# ['五险一金']                                                                                40
# ['五险一金', '补充医疗保险', '免费班车', '员工旅游', '专业培训', '餐饮补贴', '弹性工作', '定期体检']                      34
# ['五险一金', '年终奖金', '定期体检', '员工旅游', '专业培训', '餐饮补贴']                                        28
# ['六险一金', '弹性工作', '免费三餐', '租房补贴']                                                        23
# ['带薪年假', '五险一金', '弹性工作']                                                                21
# ['五险一金', '餐饮补贴']                                                                        19
# ['六险一金', '弹性工作', '免费三餐', '租房补贴', '休闲下午茶', '扁平管理', '健身瑜伽', '过亿用户', '职业大牛', '晋升空间']       18
# ['五险一金', '员工旅游', '年终奖金', '定期体检']                                                        17
# ...

# %%
wc = WordCloud(font_path='./fonts/simhei.ttf',background_color="white")
wc.fit_words(df.company_welfare.value_counts())
wc.generate(str(welfare).replace(',',''))
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# # 薪资和地区

# %%
ww = df.groupby(['salary','company_site']).salary.count()
ww
# Out:
# salary      company_site
# 0.4-1万/月    北京-海淀区           1
# 0.5-1.2万/月  北京               1
#             北京-海淀区           1
# 0.5-1.5万/月  北京-朝阳区           2
#             北京-海淀区           5
#             北京-通州区           1
# 0.5-1万/月    北京              11
#             北京-东城区           4
#             北京-朝阳区           1
#             北京-海淀区           4
#             北京-西城区           2
# 0.5-2万/月    北京               1
#             北京-海淀区           2
# 0.6-1.2万/月  北京               7
#             北京-东城区           1
#             北京-丰台区           1
#             北京-大兴区           1
#             北京-房山区           1
#             北京-昌平区           4
#             北京-朝阳区           2
#             北京-海淀区          14
#             北京-西城区           2
#             北京-通州区           1
# 0.6-1.3万/月  北京-门头沟区          2
# 0.6-1.4万/月  北京-东城区           1
# 0.6-1.5万/月  北京               3
#             北京-东城区           1
#             北京-朝阳区           1
#             北京-海淀区           5
# ...

# %% [markdown]
# # 薪资和工作年限

# %%
df.groupby(['salary','experience_required']).salary.count()
# Out:
# salary      experience_required
# 0.4-1万/月    无工作经验                   1
# 0.5-1.2万/月  无工作经验                   2
# 0.5-1.5万/月  1年经验                    2
#             2年经验                    4
#             3-4年经验                  1
#             无工作经验                   1
# 0.5-1万/月    1年经验                    4
#             2年经验                    4
#             无工作经验                  14
# 0.5-2万/月    8-9年经验                  1
#             无工作经验                   2
# 0.6-1.2万/月  1年经验                   11
#             2年经验                    5
#             3-4年经验                  6
#             无工作经验                  12
# 0.6-1.3万/月  1年经验                    2
# 0.6-1.4万/月  2年经验                    1
# 0.6-1.5万/月  1年经验                    4
#             2年经验                    5
#             无工作经验                   2
# 0.6-1.7万/月  无工作经验                   1
# 0.6-1.8万/月  1年经验                    1
#             无工作经验                   1
# 0.6-1万/月    1年经验                   11
# ...

# %% [markdown]
# # 学历要求

# %%
edu = df.edu_required.value_counts()
edu
# Out:
# 本科       3636
# 硕士        492
# 大专        443
# 招1人       336
# 招若干人      287
# 招2人       178
# 招3人        56
# 招5人        44
# 博士         22
# 招10人       21
# 招4人        20
# 招6人        10
# 中专          6
# 初中及以下       2
# 招8人         1
# 招15人        1
# 招12人        1
# Name: edu_required, dtype: int64

# %%
wc = WordCloud(font_path='./fonts/simhei.ttf',background_color="white")
wc.fit_words(df.edu_required.value_counts())
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
