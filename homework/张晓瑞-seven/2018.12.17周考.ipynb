# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
from wordcloud import WordCloud
from pylab import *
mpl.rcParams['font.sans-serif']=['SimHei']

# %%
Location = r'C:\Users\28646\ANumpy,Pandas,Matplotlib\info.csv'
df = pd.read_csv(Location)
df.head()
# Out:
#          Carname Officialprice           Carfuelc  Brand         MIITfuelc  \
# 0   smart fortwo  11.68-30.89万  5.00-11.80L/100km  smart  4.20-5.20L/100km
# 1  smart forfour  12.58-22.08万  5.10-12.00L/100km  smart               NaN
# 2          比亚迪F0    3.79-4.79万   5.20-6.60L/100km    比亚迪       4.20L/100km
# 3             奥拓    4.18-6.19万   5.20-8.30L/100km     铃木  3.60-4.00L/100km
# 4           奇瑞QQ    3.79-5.09万   5.50-5.80L/100km     奇瑞               NaN
#
#   Rank                   Displacement Gearbox Cartype                 Ranking  \
# 0  微型车  '0.9T', '1.0L', '1.0T', '纯电动'     双离合     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>
# 1  微型车                 '0.9T', '1.0L'     双离合     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>
# 2  微型车                         '1.0L'      手动     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>
# 3  微型车                         '1.0L'      手动     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>
# 4  微型车                         '1.0L'      手动     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>
#
# ...

# %%
df.isnull().sum()
# Out:
# Carname            0
# Officialprice      0
# Carfuelc           0
# Brand              0
# MIITfuelc        798
# Rank               0
# Displacement       0
# Gearbox            0
# Cartype            0
# Ranking            0
# Carstrength        0
# Configuration      0
# Major              0
# Ownerevaluate      0
# Price              0
# Versions_1         1
# Versionsp_1        1
# Versions_2        24
# Versionsp_2       24
# URL                0
# dtype: int64

# %% [markdown]
# # 排量最大的车

# %%
df1 = df.sort_values(['Displacement'],ascending=False)
df1.head(1).Carname
# Out:
# 266    幻影
# Name: Carname, dtype: object

# %% [markdown]
# # 排量最小的车

# %%
df2 = df.sort_values(['Displacement'])
df2['Displacement'].head()
# Out:
# 989                                       '--'
# 1022                                      '--'
# 7       '0.8L', '1.0L', '1.1L', '1.2L', '1.4L'
# 1                               '0.9T', '1.0L'
# 0                '0.9T', '1.0L', '1.0T', '纯电动'
# Name: Displacement, dtype: object

# %% [markdown]
# # 最贵的是哪款车

# %%
df3 = df.sort_values(['Officialprice'],ascending=False)
df3['Brand'].head(1)
# Out:
# 264    保时捷
# Name: Brand, dtype: object

# %% [markdown]
# # 哪些车主评价比较高

# %%
df4 = df[df['Ownerevaluate'] == '优秀']
df4.groupby('Carname').sum()
# Out:
#                Carstrength
# Carname
# C4 PICASSO            50.2
# DB11                  48.5
# DS 4S                 51.0
# DS 5                  55.0
# DS 5LS                51.8
# DS 6                 107.0
# DS 7                 159.2
# GLC级AMG              155.8
# GX3                   83.4
# GX6                   89.0
# Genesis G80           54.6
# Giulia                48.7
# LA FESTA菲斯塔           70.6
# MINI CABRIO           44.8
# MINI CLUBMAN          49.2
# Macan                159.0
# Mattu                140.4
# Panamera              56.7
# RAV4荣放               155.8
# STARTECH揽胜           107.6
# SWM斯威G01             141.6
# SWM斯威X7              101.0
# T-ROC探歌              146.8
# YUKON                106.8
# mu-X牧游侠               98.2
# smart forfour         44.7
# smart fortwo          45.0
# 东南DX3                 97.4
# 东南DX7                139.2
# 东风A9                  56.6
# ...                    ...
# 速尊                    51.1
# 速派                    53.3
# ...

# %%
df3
# Out:
#          Carname  Officialprice            Carfuelc Brand          MIITfuelc  \
# 1037       五十铃皮卡   10.13-14.08万   7.00-15.00L/100km   五十铃                NaN
# 997        五十铃皮卡   10.13-14.08万   7.00-15.00L/100km   五十铃                NaN
# 552         旗胜V3   10.18-11.38万  10.30-10.50L/100km    黄海                NaN
# 844         旗胜V3   10.18-11.38万  10.30-10.50L/100km    黄海                NaN
# 745         哈弗H6   10.20-14.20万   8.40-11.70L/100km    哈弗   7.40-8.70L/100km
# 476         哈弗H6   10.20-14.20万   8.40-11.70L/100km    哈弗   7.40-8.70L/100km
# 183        传祺GA6   10.28-19.68万   6.70-11.00L/100km  广汽传祺                NaN
# 711      东风风度MX5   10.36-13.56万    8.00-9.20L/100km  东风风度                NaN
# 418      东风风度MX5   10.36-13.56万    8.00-9.20L/100km  东风风度                NaN
# 952        比亚迪M6   10.39-15.39万   9.60-11.10L/100km   比亚迪                NaN
# 209        奔腾B70   10.48-15.08万   8.00-11.00L/100km    奔腾   6.00-6.40L/100km
# ...

# %% [markdown]
# # 车的类型和数量

# %%
df.groupby(['Rank']).count()
# Out:
#         Carname  Officialprice  Carfuelc  Brand  MIITfuelc  Displacement  \
# Rank
# MPV          77             77        77     77         19            77
# 中型SUV       172            172       172    172         24           172
# 中型车          56             56        56     56         24            56
# 中大型SUV       56             56        56     56         20            56
# 中大型车         21             21        21     21          7            21
# 大型SUV         4              4         4      4          0             4
# 大型车          11             11        11     11          9            11
# 小型SUV       144            144       144    144         10           144
# 小型车          41             41        41     41         18            41
# 微卡            2              2         2      2          0             2
# 微型车           8              8         8      8          4             8
# 微面           40             40        40     40         14            40
# ...

# %% [markdown]
# # 车的品牌和数量

# %%
df.groupby(['Brand']).count()
# Out:
#            Carname  Officialprice  Carfuelc  MIITfuelc  Rank  Displacement  \
# Brand
# DS               7              7         7          0     7             7
# GMC              3              3         3          1     3             3
# Jeep            18             18        18          8    18            18
# MG名爵             9              9         9          1     9             9
# MINI             5              5         5          4     5             5
# SWM斯威汽车          6              6         6          0     6             6
# WEY              6              6         6          0     6             6
# smart            2              2         2          1     2             2
# 一汽              14             14        14          4    14            14
# 三菱               6              6         6          0     6             6
# 上汽大通MAXUS        3              3         3          0     3             3
# ...

# %% [markdown]
# # 车实力评分高于98%的车名

# %%
df5 = df.sort_values(['Ranking'],ascending=False)
df5.head(5)['Carname']
# Out:
# 483     DS 7
# 55       高尔夫
# 349    奔驰GLC
# 779    奔驰GLC
# 752     DS 7
# Name: Carname, dtype: object

# %% [markdown]
# # 车箱的类型

# %%
df.groupby(['Cartype']).sum()
# Out:
#          Carstrength
# Cartype
# MPV           3835.3
# SUV          35167.0
# 三厢车          10388.0
# 两厢车           2728.7
# 客车            1452.6
# 掀背车            587.6
# 旅行车            659.3
# 皮卡             578.0
# 硬顶敞篷车           47.3
# 硬顶跑车           614.3
# 货车             141.6
# 软顶敞篷车          355.0

# %% [markdown]
# # 变速器的种类

# %%
df.groupby(['Gearbox']).sum()
# Out:
#                 Carstrength
# Gearbox
# 双离合                  4631.3
# 固定齿比                   92.6
# 手动                  33644.3
# 手自一体                14917.2
# 无级变速                 2216.3
# 电子无级变速箱(E-CVT)        386.3
# 自动                    666.7
