# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import Image
from IPython.display import *
from pylab import *
mpl.rcParams['font.sans-serif']=['SimHei'] #正常显示中文
plt.rcParams['axes.unicode_minus']=False   #正常显示负号
# %matplotlib inline

# %%
Location = r'C:\Users\28646\ANumpy,Pandas,Matplotlib\pandas\train.csv'
df = pd.read_csv(Location)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 处理空值

# %%
df.isnull().sum()#统计null值的个数
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Age.fillna(df.Age.median(),inplace=True)#填充空值

# %%
df.Age.median()
# Out:
# 28.0

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # 尝试从性别分析

# %%
df.Sex.count()
# Out:
# 891

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df[df.Survived==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
shenghuanzhe = df[df.Survived==1].Sex.value_counts()
shenghuanzhe
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
shenghuanzhe.plot.bar();

# %%
df[df.Survived==1].Sex.count()
# Out:
# 342

# %% [markdown]
# # 从年龄进行分析

# %%
df.Age.value_counts()
# Out:
# 28.00    202
# 24.00     30
# 22.00     27
# 18.00     26
# 19.00     25
# 30.00     25
# 21.00     24
# 25.00     23
# 36.00     22
# 29.00     20
# 32.00     18
# 27.00     18
# 35.00     18
# 26.00     18
# 16.00     17
# 31.00     17
# 34.00     15
# 20.00     15
# 23.00     15
# 33.00     15
# 39.00     14
# 17.00     13
# 42.00     13
# 40.00     13
# 45.00     12
# 38.00     11
# 50.00     10
# 2.00      10
# 4.00      10
# 47.00      9
#         ...
# 71.00      2
# 59.00      2
# 63.00      2
# 0.83       2
# 30.50      2
# 70.00      2
# 57.00      2
# 0.75       2
# 13.00      2
# 10.00      2
# 64.00      2
# 40.50      2
# 32.50      2
# 45.50      2
# 20.50      1
# 24.50      1
# 0.67       1
# 14.50      1
# 0.92       1
# 74.00      1
# 34.50      1
# 80.00      1
# 12.00      1
# 36.50      1
# 53.00      1
# 55.50      1
# 70.50      1
# 66.00      1
# 23.50      1
# 0.42       1
# Name: Age, Length: 88, dtype: int64

# %%
df.Age.value_counts().plot.hist();

# %%
dead = df[df.Survived==1].Age
deadd = df[df.Survived==0].Age
deaddd = pd.DataFrame([dead,deadd],index=['survived','dead'])
deaddd.T
# Out:
#      survived  dead
# 0         NaN  22.0
# 1        38.0   NaN
# 2        26.0   NaN
# 3        35.0   NaN
# 4         NaN  35.0
# 5         NaN  28.0
# 6         NaN  54.0
# 7         NaN   2.0
# 8        27.0   NaN
# 9        14.0   NaN
# 10        4.0   NaN
# 11       58.0   NaN
# 12        NaN  20.0
# 13        NaN  39.0
# 14        NaN  14.0
# 15       55.0   NaN
# 16        NaN   2.0
# 17       28.0   NaN
# 18        NaN  31.0
# 19       28.0   NaN
# 20        NaN  35.0
# 21       34.0   NaN
# 22       15.0   NaN
# 23       28.0   NaN
# 24        NaN   8.0
# 25       38.0   NaN
# 26        NaN  28.0
# 27        NaN  19.0
# 28       28.0   NaN
# 29        NaN  28.0
# ..        ...   ...
# 861       NaN  21.0
# 862      48.0   NaN
# 863       NaN  28.0
# 864       NaN  24.0
# 865      42.0   NaN
# 866      27.0   NaN
# 867       NaN  31.0
# 868       NaN  28.0
# 869       4.0   NaN
# 870       NaN  26.0
# 871      47.0   NaN
# 872       NaN  33.0
# 873       NaN  47.0
# ...

# %%
deaddd = deaddd.T
deaddd.plot.hist(bins=30)

# %%
df.Age.plot.kde(xlim=0);

# %%
df.Age.describe()
# Out:
# count    891.000000
# mean      29.361582
# std       13.019697
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
young = df[df.Age>=16]['Survived'].sum()
young
# Out:
# 293

# %% [markdown]
# # 分析票价

# %%
df.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 26.5500     15
# 0.0000      15
# 7.2292      15
# 7.8542      13
# 8.6625      13
# 7.2500      13
# 7.2250      12
# 16.1000      9
# 9.5000       9
# 24.1500      8
# 15.5000      8
# 56.4958      7
# 52.0000      7
# 14.5000      7
# 14.4542      7
# 69.5500      7
# 7.0500       7
# 31.2750      7
# 46.9000      6
# 30.0000      6
# 7.7958       6
# 39.6875      6
#             ..
# 7.1417       1
# 42.4000      1
# 211.5000     1
# 12.2750      1
# 61.1750      1
# 8.4333       1
# 51.4792      1
# 7.8875       1
# 8.6833       1
# 7.5208       1
# 34.6542      1
# 28.7125      1
# 25.5875      1
# 7.7292       1
# 12.2875      1
# 8.6542       1
# 8.7125       1
# 61.3792      1
# 6.9500       1
# 9.8417       1
# 8.3000       1
# 13.7917      1
# 9.4750       1
# 13.4167      1
# 26.3875      1
# 8.4583       1
# 9.8375       1
# ...

# %%
survived = df[df.Survived==1].Fare
dead = df[df.Survived==0].Fare
dff = pd.DataFrame([survived,dead],index=['survived','dead'])
dff = dff.T
dff.plot.kde()
dff
# Out:
#      survived      dead
# 0         NaN    7.2500
# 1     71.2833       NaN
# 2      7.9250       NaN
# 3     53.1000       NaN
# 4         NaN    8.0500
# 5         NaN    8.4583
# 6         NaN   51.8625
# 7         NaN   21.0750
# 8     11.1333       NaN
# 9     30.0708       NaN
# 10    16.7000       NaN
# 11    26.5500       NaN
# 12        NaN    8.0500
# 13        NaN   31.2750
# 14        NaN    7.8542
# 15    16.0000       NaN
# 16        NaN   29.1250
# 17    13.0000       NaN
# 18        NaN   18.0000
# 19     7.2250       NaN
# 20        NaN   26.0000
# 21    13.0000       NaN
# 22     8.0292       NaN
# 23    35.5000       NaN
# 24        NaN   21.0750
# 25    31.3875       NaN
# 26        NaN    7.2250
# 27        NaN  263.0000
# 28     7.8792       NaN
# 29        NaN    7.8958
# ..        ...       ...
# 861       NaN   11.5000
# 862   25.9292       NaN
# 863       NaN   69.5500
# 864       NaN   13.0000
# 865   13.0000       NaN
# 866   13.8583       NaN
# ...

# %%
df.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
dff.plot(kind='kde',xlim=(0,513));

# %% [markdown]
# # 组合特征

# %%
ax = plt.subplot()
age = df[df.Survived==0].Age
fare = df[df.Survived==0].Fare
plt.scatter(age,fare,s=20,alpha=0.3,linewidths=3,edgecolors='green')
age = df[df.Survived==1].Age
fare = df[df.Survived==1].Fare
plt.scatter(age,fare,s=20,alpha=0.3,linewidths=3,edgecolors='red')
ax.set_xlabel('age')
ax.set_ylabel('fare')
# Out:
# Text(0,0.5,'fare')

# %% [markdown]
# # 隐含特征

# %%
df.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
df.Name.describe()
# Out:
# count                   891
# unique                  891
# top       Karaic, Mr. Milan
# freq                      1
# Name: Name, dtype: object

# %%
help(np.convolve)
# Out:
# Help on function convolve in module numpy.core.numeric:
#
# convolve(a, v, mode='full')
#     Returns the discrete, linear convolution of two one-dimensional sequences.
#
#     The convolution operator is often seen in signal processing, where it
#     models the effect of a linear time-invariant system on a signal [1]_.  In
#     probability theory, the sum of two independent random variables is
#     distributed according to the convolution of their individual
#     distributions.
#
#     If `v` is longer than `a`, the arrays are swapped before computation.
#
#     Parameters
#     ----------
#     a : (N,) array_like
#         First one-dimensional input array.
#     v : (M,) array_like
#         Second one-dimensional input array.
#     mode : {'full', 'valid', 'same'}, optional
#         'full':
#           By default, mode is 'full'.  This returns the convolution
#           at each point of overlap, with an output shape of (N+M-1,). At
# ...

# %%
np.convolve([1,2,3],[0,1,1.5])
# Out:
# array([0. , 1. , 3.5, 6. , 4.5])

# %%
np.convolve([1,2,3],[0,1,0.5],'same')
# Out:
# array([1. , 2.5, 4. ])

# %%
np.convolve([1,2,3],[0,1,0.5],'valid')
# Out:
# array([2.5])

# %%
np.convolve([1,2,3],[0,1,1.5],'full')
# Out:
# array([0. , 1. , 3.5, 6. , 4.5])

# %%
a = [1,2,3,4,5]
b = [2,3]
#full =# 1,2,3,4,5
     #          3 2
    #[2,7,12,17,22,15]
#same = #1,2,3,4,5 #取最长的
    #3,2
    #[2,7,12,17,22]
#valid = #1,2,3,4,5  #长的减去短的再加一
      #3,2
    #[7,12,17,22]

# %%
np.convolve([1,2,3,4,5],[2,3],'full')
# Out:
# array([ 2,  7, 12, 17, 22, 15])

# %%
np.convolve([1,2,3,4,5],[2,3],'same')
# Out:
# array([ 2,  7, 12, 17, 22])

# %%
np.convolve([1,2,3,4,5],[2,3],'valid')
# Out:
# array([ 7, 12, 17, 22])

# %%
a = np.array([1,0,1,0,0,0,0,1,0])
b = np.array([1,1,1,1,0,1,1,1,1])
np.convolve(a,b,'valid')
# Out:
# array([3])

# %% [markdown]
# # 第一种方法

# %%
def sum_total(around,mask):
    return np.convolve(around,mask,'valid')[0]

# %%
np.random.seed(1)
around_life = np.random.randint(0,2,(3,3))
around_life_ravel = np.ravel(around_life)
around_life_ravel
# Out:
# array([1, 1, 0, 0, 1, 1, 1, 1, 1])

# %%
mask = np.ones(9)
mask[4] = 0
mask
# Out:
# array([1., 1., 1., 1., 0., 1., 1., 1., 1.])

# %%
sum_total(around_life_ravel,mask)
# Out:
# 6.0

# %% [markdown]
# # 第二种方法

# %%
sum(around_life_ravel*mask)
# Out:
# 6.0

# %% [markdown]
# # 第三种方法

# %%
around_life_ravel[4]=0
sum(around_life_ravel)
# Out:
# 6

# %%
n = 50
x = np.random.rand(n)
y = np.random.rand(n)
colors = np.random.rand(n)
area = np.pi*(15*np.random.rand(n))**2
plt.scatter(x,y,s=area,c=colors,alpha=0.5)
plt.show()

# %%
x = np.random.normal(size=100)
n,bins,pathches = plt.hist(x)
print(pathches[1])
plt.setp(pathches[1],'facecolor','r',alpha=0.4)
# Out:
# Rectangle(xy=(-1.76039, 0), width=0.494373, height=15, angle=0)
# [None, None]

# %%
Location = r'C:\Users\28646\ANumpy,Pandas,Matplotlib\weather_2012.csv'
df = pd.read_csv(Location)
df
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# 5     2012-01-01 05:00:00      -1.4                -3.3           87
# 6     2012-01-01 06:00:00      -1.5                -3.1           89
# 7     2012-01-01 07:00:00      -1.4                -3.6           85
# 8     2012-01-01 08:00:00      -1.4                -3.6           85
# 9     2012-01-01 09:00:00      -1.3                -3.1           88
# 10    2012-01-01 10:00:00      -1.0                -2.3           91
# 11    2012-01-01 11:00:00      -0.5                -2.1           89
# 12    2012-01-01 12:00:00      -0.2                -2.0           88
# ...

# %%
df.describe()
# Out:
#           Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# count  8784.000000         8784.000000  8784.000000      8784.000000
# mean      8.798144            2.555294    67.431694        14.945469
# std      11.687883           10.883072    16.918881         8.688696
# min     -23.300000          -28.500000    18.000000         0.000000
# 25%       0.100000           -5.900000    56.000000         9.000000
# 50%       9.300000            3.300000    68.000000        13.000000
# 75%      18.800000           11.800000    81.000000        20.000000
# max      33.000000           24.400000   100.000000        83.000000
#
#        Visibility (km)  Stn Press (kPa)
# count      8784.000000      8784.000000
# mean         27.664447       101.051623
# std          12.622688         0.844005
# min           0.200000        97.520000
# 25%          24.100000       100.560000
# 50%          25.000000       101.070000
# 75%          25.000000       101.590000
# ...

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)',
#        'Wind Spd (km/h)', 'Visibility (km)', 'Stn Press (kPa)', 'Weather'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.values
# Out:
# array([['2012-01-01 00:00:00', -1.8, -3.9, ..., 8.0, 101.24, 'Fog'],
#        ['2012-01-01 01:00:00', -1.8, -3.7, ..., 8.0, 101.24, 'Fog'],
#        ['2012-01-01 02:00:00', -1.8, -3.4, ..., 4.0, 101.26,
#         'Freezing Drizzle,Fog'],
#        ...,
#        ['2012-12-31 21:00:00', -0.5, -1.5, ..., 4.8, 99.95, 'Snow'],
#        ['2012-12-31 22:00:00', -0.2, -1.8, ..., 9.7, 99.91, 'Snow'],
#        ['2012-12-31 23:00:00', 0.0, -2.1, ..., 11.3, 99.89, 'Snow']],
#       dtype=object)

# %%
df['Temp (C)'].value_counts().plot();

# %%
df.shape
# Out:
# (8784, 8)

# %%
df['Weather'].value_counts().plot.bar();

# %%
df['Temp (C)'].plot(figsize=(15,6))

# %%
n = df.shape[0]
colors = np.random.rand(n)
plt.scatter(df['Temp (C)'],df['Dew Point Temp (C)'],c=colors,alpha=0.5)
plt.xlabel('Temp (C)')
plt.ylabel('Dew Point Temp (C)')
plt.title('Histogram of Temperture in year 2012')
plt.show()

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-5,5,0.25)
Y = np.arange(-5,5,0.25)
X,Y = np.meshgrid(X,Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X,Y,Z,rstride=1,cstride=1,cmap=cm.viridis)
plt.show()

# %%
t = np.arange(0.0,2.0,0.01)
s = np.sin(2*np.pi*t)
plt.plot(t,s);
plt.title(r'$\alpha_i > \beta_i$',fontsize=20)
plt.text(1,-0.6,r'$\sum_{i=0}^\infty x_i$',fontsize=20)
plt.text(0.6,0.6,r'$\mathcal{A}\mathrm{sin}(2 \ omega t)$',fontsize=20)
plt.xlabel('time(s)')
plt.ylabel('volts(mV)')
plt.show()

# %%
a = np.linspace(-np.pi,np.pi,256,endpoint=True)
x = np.sin(a)
y = np.cos(a)
left_x = 0.2*np.cos(a)-0.5
left_y = 0.2*np.sin(a)+0.5
right_x = 0.2*np.cos(a)+0.5
right_y = 0.2*np.sin(a)+0.5
nose_x = 0.1*np.cos(a)
nose_y = 0.1*np.sin(a)
mouth_x = -0.3*np.sin(a/2)
mouth_y = -0.1*np.cos(a)-0.6
plt.plot(x,y)
plt.plot(left_x,left_y)
plt.plot(right_x,right_y)
plt.plot(nose_x,nose_y)
plt.plot(mouth_x,mouth_y)
plt.show()

# %%
a = np.array([0,1,2,1,0])
b = np.array([1,2,1,0,1])
#plt.fill(a,b)
plt.plot(a,b)
plt.fill_between(a,b)

# %%
x = [0,2,4,5]
y = [0,3,4,2]
plt.plot(x,y,c='y',lw=3)
plt.title('折线图')
plt.annotate('(4,4)',xy=(4,4),xytext=(5,5),arrowprops=dict(facecolor='red'))
# Out:
# Text(5,5,'(4,4)')

# %%
help(plt.annotate)
# Out:
# Help on function annotate in module matplotlib.pyplot:
#
# annotate(*args, **kwargs)
#     Annotate the point ``xy`` with text ``s``.
#
#     Additional kwargs are passed to `~matplotlib.text.Text`.
#
#     Parameters
#     ----------
#
#     s : str
#         The text of the annotation
#
#     xy : iterable
#         Length 2 sequence specifying the *(x,y)* point to annotate
#
#     xytext : iterable, optional
#         Length 2 sequence specifying the *(x,y)* to place the text
#         at.  If None, defaults to ``xy``.
#
#     xycoords : str, Artist, Transform, callable or tuple, optional
#
#         The coordinate system that ``xy`` is given in.
#
#         For a `str` the allowed values are:
#
#         =================   ===============================================
#         Property            Description
#         =================   ===============================================
#         'figure points'     points from the lower left of the figure
# ...
