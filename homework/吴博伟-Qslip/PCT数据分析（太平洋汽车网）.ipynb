# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('PCTT.csv')

# %%
df.head()
# Out:
#          carname officialprice           carfuelc  brand         MIITfuelc  \
# 0   smart fortwo  11.68-30.89万  5.00-11.80L/100km  smart  4.20-5.20L/100km
# 1  smart forfour  12.58-22.08万  5.10-12.00L/100km  smart              暂无信息
# 2          比亚迪F0    3.79-4.79万   5.20-6.60L/100km    比亚迪       4.20L/100km
# 3             奥拓    4.18-6.19万   5.20-8.30L/100km     铃木  3.60-4.00L/100km
# 4           奇瑞QQ    3.79-5.09万   5.50-5.80L/100km     奇瑞              暂无信息
#
#                       displacement rank         gearbox cartype  \
# 0  ['0.9T', '1.0L', '1.0T', '纯电动']  微型车         ['双离合']   软顶敞篷车
# 1                 ['0.9T', '1.0L']  微型车         ['双离合']     两厢车
# 2                         ['1.0L']  微型车          ['手动']     两厢车
# 3                         ['1.0L']  微型车    ['手动', '自动']     两厢车
# 4                         ['1.0L']  微型车  ['手动', '手自一体']     两厢车
#
#                 ranking carstrength configuration major ownerevaluate price  \
# ...

# %% [markdown]
# # 哪种车的排量最大

# %%
df1 = df.loc[:,('carname','displacement')]

# %%
max_a = df.displacement.apply(lambda x:eval(x)[-1] if '纯电动' not in x else eval(x)[-2])
min_b = df.displacement.apply(lambda x:eval(x)[0] if '--' not in eval(x)[0] else '0')
#b = df.displacement.apply(lambda x:eval(x) if '纯电动' not in x else eval(x)[:-1])
df['max_a'] = max_a
df['min_b'] = min_b
df[df.max_a ==df.max_a.max()]
df[df.min_b==df.min_b.min()]
# Out:
#     carname officialprice          carfuelc brand    MIITfuelc displacement  \
# 889   佳宝V52    2.72-2.92万  6.70-7.10L/100km    一汽  6.00L/100km       ['--']
# 910   佳宝V52    2.72-2.92万  6.70-7.10L/100km    一汽  6.00L/100km       ['--']
#
#     rank gearbox cartype               ranking  ...  configuration major  \
# 889   微面  ['手动']  ['客车']  该车暂未被列入榜单，暂无排名信息查看详情  ...             较弱   测试中
# 910   微面  ['手动']  ['客车']  该车暂未被列入榜单，暂无排名信息查看详情  ...             较弱   测试中
#
#     ownerevaluate price                versions1 versionsp1 versions2  \
# 889            较弱    良好   2012款 1.0 DA465QA 实用型       2.72万       NaN
# 910            较弱    良好   2012款 1.0 DA465QA 实用型       2.72万       NaN
#
#     versionsp2 max_a min_b
# 889        NaN    --     0
# 910        NaN    --     0
#
# [2 rows x 21 columns]

# %% [markdown]
# # 哪些车使用了双离合？

# %%
df[df.gearbox.apply(lambda x:True if '手自一体' in x else False)]
# Out:
#          carname   officialprice            carfuelc      brand  \
# 4           奇瑞QQ      3.79-5.09万    5.50-5.80L/100km         奇瑞
# 8           奔驰S级   86.38-173.28万   7.40-13.00L/100km         奔驰
# 9          奥迪A8L   87.68-256.80万   7.50-14.00L/100km         奥迪
# 10          宝马7系   82.80-248.80万   9.00-12.30L/100km         宝马
# 11        雷克萨斯LS   82.40-119.60万   9.10-11.10L/100km       雷克萨斯
# 12          捷豹XJ   88.80-106.80万  10.00-12.30L/100km         捷豹
# 13           雅科仕   73.80-132.00万  10.40-15.80L/100km         现代
# 14            总裁  143.90-194.08万  10.50-14.00L/100km       玛莎拉蒂
# 15         迈巴赫S级  139.88-309.88万  11.00-15.40L/100km         奔驰
# 17            飞驰  278.00-435.80万  11.50-21.60L/100km         宾利
# 25           高尔夫    12.19-23.99万   5.00-11.50L/100km         大众
# 26            英朗    10.99-14.49万    5.10-8.50L/100km         别克
# 28            阅朗    11.99-14.79万    5.20-9.50L/100km         别克
# 31           福克斯    10.88-16.58万   5.40-11.80L/100km         福特
# ...

# %%
b = []
for i in df1.displacement:
    for x in eval(i):
        if x != '纯电动':
            if x[:-1] != '-':
                b.append(x[:-1])
c = sorted(b)[-1]#最大排量

for i in df1.displacement:
    if c in i:
        d = i
df[df.displacement==d]
# Out:
#    carname    officialprice            carfuelc brand           MIITfuelc  \
# 18      幻影  688.00-1488.00万  13.00-31.00L/100km  劳斯莱斯  15.70-17.00L/100km
#
#    displacement rank gearbox cartype               ranking carstrength  \
# 18     ['6.7L']  大型车    [自动]     三厢车  该车暂未被列入榜单，暂无排名信息查看详情    非总得分52.3
#
#    configuration major ownerevaluate price       versions1 versionsp1  \
# 18            良好   测试中            良好    较弱   2018款 绅士之旅定制版        未上市
#
#          versions2 versionsp2
# 18   2018款 私享秘境特别版        未上市

# %% [markdown]
# # 那种车最贵

# %%
df2 = df.loc[:,('carname','officialprice')]

# %%
d = []
for i in df2.officialprice:
    d.append(i[:-1])
f = []
for i in d:
    if len(i.split('-'))==2:
        f.append(float(i.split('-')[1]))
    else:
        f.append(float(i.split('-')[0]))
f
max_price = sorted(f)[-1]
for i  in df2.officialprice:
    if str(max_price) in i:
        max_price = i

# %%
max_price
df[df.officialprice==max_price]
# Out:
#    carname    officialprice            carfuelc brand           MIITfuelc  \
# 18      幻影  688.00-1488.00万  13.00-31.00L/100km  劳斯莱斯  15.70-17.00L/100km
#
#    displacement rank gearbox cartype               ranking carstrength  \
# 18     ['6.7L']  大型车    [自动]     三厢车  该车暂未被列入榜单，暂无排名信息查看详情    非总得分52.3
#
#    configuration major ownerevaluate price       versions1 versionsp1  \
# 18            良好   测试中            良好    较弱   2018款 绅士之旅定制版        未上市
#
#          versions2 versionsp2
# 18   2018款 私享秘境特别版        未上市

# %% [markdown]
# # 哪些车车主评价比较高?

# %%
df3 = df.ownerevaluate

# %%
df[df.ownerevaluate=='优秀'].head()
# Out:
#          carname  officialprice           carfuelc  brand          MIITfuelc  \
# 0   smart fortwo   11.68-30.89万  5.00-11.80L/100km  smart   4.20-5.20L/100km
# 1  smart forfour   12.58-22.08万  5.10-12.00L/100km  smart               暂无信息
# 5          北斗星X5     4.69-5.19万   6.20-6.70L/100km     铃木               暂无信息
# 8           奔驰S级  86.38-173.28万  7.40-13.00L/100km     奔驰  9.40-23.10L/100km
# 9          奥迪A8L  87.68-256.80万  7.50-14.00L/100km     奥迪  9.10-20.00L/100km
#
#                                         displacement rank gearbox cartype  \
# 0                    ['0.9T', '1.0L', '1.0T', '纯电动']  微型车   [双离合]   软顶敞篷车
# 1                                   ['0.9T', '1.0L']  微型车   [双离合]     两厢车
# 5                                   ['1.0L', '1.4L']  微型车    [手动]     两厢车
# 8  ['2.0T', '3.0L', '3.0T', '3.5L', '4.0T', '4.7T...  大型车  [手自一体]    硬顶跑车
# 9  ['2.0T', '2.5L', '2.8L', '3.0T', '3.2L', '4.0T...  大型车  [手自一体]     三厢车
#
# ...

# %% [markdown]
# # 那种品牌的车最多

# %%
df.groupby('brand').size().sort_values().tail(1)
# Out:
# brand
# 大众    32
# dtype: int64

# %% [markdown]
# # 那些车得分最高

# %%
b = []
for i in df.carstrength	:
    if '非总得分' in i:
        b.append(i[4:])
    else:
        b.append(i)
c = sorted(b)[-1]
for i in df.carstrength:
    if c in i:
        print(i)
df[df.carstrength == c]
# Out:
# 86.9
#    carname  officialprice           carfuelc brand          MIITfuelc  \
# 10    宝马7系  82.80-248.80万  9.00-12.30L/100km    宝马  8.50-13.60L/100km
#
#                                          displacement rank gearbox cartype  \
# 10  ['2.0T', '3.0L', '3.0T', '4.0T', '4.4T', '6.0T...  大型车  [手自一体]     三厢车
#
#                   ranking carstrength configuration major ownerevaluate price  \
# 10  该车车实力评分高于75%同级别车系查看详情        86.9            优秀    优秀            优秀    较弱
#
#                      versions1 versionsp1             versions2 versionsp2
# 10   2018款 M760Li xDrive 卓越奢华版     248.8万   2018款 M760Li xDrive     248.8万
