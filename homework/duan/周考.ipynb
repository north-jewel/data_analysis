# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\DYJ05\Desktop\info(1).csv')

# %%
df.columns = ['车名','官方价','车主平均油耗','品牌','工信部油耗','级别','排量','变速箱','车身类型','排名','车实力','配置水平','专业测评','车主评价','价格','版本1','版本售价1','版本2','版本售价2','连接']

# %%
df.head(10)
# Out:
#               车名           官方价             车主平均油耗     品牌             工信部油耗  \
# 0   smart fortwo  11.68-30.89万  5.00-11.80L/100km  smart  4.20-5.20L/100km
# 1  smart forfour  12.58-22.08万  5.10-12.00L/100km  smart               NaN
# 2          比亚迪F0    3.79-4.79万   5.20-6.60L/100km    比亚迪       4.20L/100km
# 3             奥拓    4.18-6.19万   5.20-8.30L/100km     铃木  3.60-4.00L/100km
# 4           奇瑞QQ    3.79-5.09万   5.50-5.80L/100km     奇瑞               NaN
# 5          北斗星X5    4.69-5.19万   6.20-6.70L/100km     铃木               NaN
# 6             奔奔    4.09-5.69万   6.30-8.50L/100km   长安汽车               NaN
# 7            北斗星    3.99-4.49万   6.70-7.00L/100km     铃木  4.00-6.40L/100km
# 8          启辰R30    3.99-5.19万   4.90-6.00L/100km   东风启辰               NaN
# 9          宝骏310    3.68-6.08万   5.00-8.10L/100km     宝骏               NaN
#
#     级别                                      排量  变速箱 车身类型  \
# 0  微型车           '0.9T', '1.0L', '1.0T', '纯电动'  双离合  两厢车
# ...

# %%
df1 = df

# %% [markdown]
# 官方价最高的车

# %%
df1['车名'].value_counts().max()
# Out:
# 2

# %%
df1['官方价'] = df1['官方价'].apply(lambda x:x[0:-2])

# %%
df1['官方价'] = df1['官方价'].apply(lambda x:x.split('-'))
df1['官方价'] = df1['官方价'].apply(lambda x:float(max(x)))

# %%
df1.head()
# Out:
#               车名   官方价             车主平均油耗     品牌             工信部油耗   级别  \
# 0   smart fortwo  30.8  5.00-11.80L/100km  smart  4.20-5.20L/100km  微型车
# 1  smart forfour  22.0  5.10-12.00L/100km  smart               NaN  微型车
# 2          比亚迪F0   4.7   5.20-6.60L/100km    比亚迪       4.20L/100km  微型车
# 3             奥拓   6.1   5.20-8.30L/100km     铃木  3.60-4.00L/100km  微型车
# 4           奇瑞QQ   5.0   5.50-5.80L/100km     奇瑞               NaN  微型车
#
#                               排量  变速箱 车身类型                      排名   车实力 配置水平  \
# 0  '0.9T', '1.0L', '1.0T', '纯电动'  双离合  两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>  45.0   较弱
# 1                 '0.9T', '1.0L'  双离合  两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>  44.7   较弱
# 2                         '1.0L'   手动  两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>  35.7   较弱
# 3                         '1.0L'   手动  两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>  37.2   较弱
# 4                         '1.0L'   手动  两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>  37.2   较弱
#
# ...

# %%
df1['官方价'][266]
# Out:
# 688.0

# %%
df1[df1['官方价'] == df1['官方价'].max()]
# Out:
#      车名    官方价              车主平均油耗    品牌               工信部油耗   级别      排量 变速箱  \
# 266  幻影  688.0  13.00-31.00L/100km  劳斯莱斯  15.70-17.00L/100km  大型车  '6.7L'  自动
#
#     车身类型                      排名   车实力 配置水平 专业测评 车主评价  价格             版本1  \
# 266  三厢车  该车暂未被列入榜单，暂无排名信息查看详情>>  52.3   良好  测试中   良好  良好   2018款 绅士之旅定制版
#
#     版本售价1             版本2 版本售价2                                   连接
# 266   未上市   2018款 私享秘境特别版   未上市  https://price.pcauto.com.cn/sg2313/

# %% [markdown]
# 排量大的车

# %%
df1['排量'].sort_values().tail()
# Out:
# 565     '5.3L', '6.2L'
# 884     '5.3L', '6.2L'
# 1009            '5.7L'
# 1043            '5.7L'
# 266             '6.7L'
# Name: 排量, dtype: object

# %% [markdown]
# 排量小的车

# %%
df1['排量'].sort_values().head()
# Out:
# 989                                       '--'
# 1022                                      '--'
# 7       '0.8L', '1.0L', '1.1L', '1.2L', '1.4L'
# 1                               '0.9T', '1.0L'
# 0                '0.9T', '1.0L', '1.0T', '纯电动'
# Name: 排量, dtype: object

# %% [markdown]
# 那些车的车主评价优秀

# %%
df1[df1['车主评价'] == '优秀']['车名']
# Out:
# 0         smart fortwo
# 1        smart forfour
# 5                北斗星X5
# 19               凯翼C3R
# 24                  瑞纳
# 25                  悦翔
# 29                凯翼C3
# 35                  悦纳
# 46         MINI CABRIO
# 47        MINI CLUBMAN
# 49             秦Pro新能源
# 50               荣威ei6
# 53                 普锐斯
# 57                  凌派
# 58                  阅朗
# 60              名爵6新能源
# 62                  骐达
# 63                奥迪A3
# 67                  缤瑞
# 68               启辰D60
# 70                  启悦
# 71              雷克萨斯CT
# 74                 科鲁兹
# 77                 科沃兹
# 79               标致408
# 96                名爵GT
# 97               艾瑞泽GX
# 109                名爵6
# 111              奔腾B50
# 114              艾瑞泽EX
#              ...
# 946                 威霆
# 947              星驰斯宾特
# 948         C4 PICASSO
# 949              福美来F7
# 956               星驰V级
# 960                 塞纳
# 961                 贵士
# 962               DB11
# 963           捷豹F-TYPE
# ...

# %% [markdown]
# 车的级别与受欢迎程度

# %%
df1[df1['车主评价'] == '优秀'].groupby(by = ['级别']).max()
# Out:
#                  车名           官方价             车主平均油耗      品牌  \
# 级别
# MPV           风光360   95.80,118.0  9.90-13.00L/100km     雪铁龙
# 中型SUV         风光580     9.99,13.9  9.90-10.60L/100km    雷克萨斯
# 中型车             阿特兹     8.99,13.8  9.80-12.10L/100km     马自达
# 中大型SUV       雷克萨斯RX   92.18,128.5  9.90-14.00L/100km    雷克萨斯
# 中大型车         雷克萨斯ES    55.60,87.9  9.90-11.00L/100km    雷克萨斯
# 大型SUV         奔驰GLS  118.80,238.0  8.60-11.00L/100km      奔驰
# 大型车              飞驰   99.80,217.8  9.00-12.30L/100km      现代
# 小型SUV   长安CS35 PLUS     9.99,14.9   8.30-8.60L/100km     雪铁龙
# 小型车              瑞纳     7.28,10.5  7.50-10.20L/100km    长安汽车
# 微型车           北斗星X5      4.69,5.1   6.20-6.70L/100km      铃木
# 微面           海狮X30L      4.68,5.8   7.00-8.00L/100km      金杯
# 皮卡               锐骐     8.58,12.1  9.70-11.70L/100km      道奇
# 紧凑型SUV      马自达CX-4     9.98,18.8   9.30-9.60L/100km     马自达
# 紧凑型车         高尔夫・嘉旅     9.99,13.4  8.60-11.80L/100km    雷克萨斯
# ...
