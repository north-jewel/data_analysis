# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('info.csv')

# %%
df.tail(2)
# Out:
#      Carname Officialprice            Carfuelc Brand     MIITfuelc Rank  \
# 1042     纳瓦拉  13.98-18.78万   9.70-11.70L/100km    日产           NaN   皮卡
# 1043   道奇Ram  65.00-72.00万  17.40-19.00L/100km    道奇  19.50L/100km   皮卡
#
#      Displacement Gearbox Cartype                 Ranking  Carstrength  \
# 1042       '2.5L'      手动      皮卡  该车暂未被列入榜单，暂无排名信息查看详情>>         41.3
# 1043       '5.7L'    手自一体      皮卡  该车暂未被列入榜单，暂无排名信息查看详情>>         43.4
#
#      Configuration Major Ownerevaluate Price  \
# 1042            较弱   测试中            优秀    优秀
# 1043            一般   测试中            优秀    优秀
#
#                                              Versions_1 Versionsp_1  \
# 1042                             2017款 2.5L 自动四驱豪华版QR25      18.78万
# 1043   2018款 Laramie Longhorn Crew Cab Off Road Package         未上市
#
#                    Versions_2 Versionsp_2  \
# 1042   2017款 2.5L 自动两驱豪华版QR25      16.18万
# 1043   2018款 Laramie Crew Cab         未上市
#
#                                        URL
# ...

# %%
df.iloc[0].Displacement.split(',')[0].replace(' ','')[1:-2]
# Out:
# '0.9'

# %%
d_dict = {}
for i in range(1043):
    d_dict[i] = df.iloc[i].Displacement.split(',')[0].replace(' ','')[1:-2]
d_series = pd.Series(d_dict)

# %%
df.Displacement = d_series

# %%
df.head(2)
# Out:
#          Carname Officialprice           Carfuelc  Brand         MIITfuelc  \
# 0   smart fortwo  11.68-30.89万  5.00-11.80L/100km  smart  4.20-5.20L/100km
# 1  smart forfour  12.58-22.08万  5.10-12.00L/100km  smart               NaN
#
#   Rank Displacement Gearbox Cartype                 Ranking  Carstrength  \
# 0  微型车          0.9     双离合     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>         45.0
# 1  微型车          0.9     双离合     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>         44.7
#
#   Configuration Major Ownerevaluate Price                Versions_1  \
# 0            较弱   测试中            优秀    优秀                 2018款 基本型
# 1            较弱   测试中            优秀    优秀   2017款 Crosstown Edition
#
#   Versionsp_1              Versions_2 Versionsp_2  \
# 0         未上市   2018款 1.0L 52千瓦巧克力特别版    13.0888万
# 1          停售    2017款 0.9T 66千瓦挚爱特别版          停售
#
#                                     URL
# 0    https://price.pcauto.com.cn/sg903/
# 1  https://price.pcauto.com.cn/sg11251/

# %% [markdown]
# # 1.大排量车有哪些?
# 幻影
# 道奇Ram
# YUKON
# SAVANA
# YUKON

# %%
inde = df.Displacement.sort_values(ascending=False).head(5).index

# %%
for i in inde:
    print(df.iloc[i].Carname)
# Out:
# 幻影
# 道奇Ram
# YUKON
# SAVANA
# YUKON

# %% [markdown]
# # 2.小排量车有哪些?
# 北斗星
# smart fortwo
# smart forfour
# 力帆丰顺
# 五菱之光

# %%
inde = df.Displacement.sort_values().head(7).index

# %%
for i in inde[2:]:
#     print(i)
    print(df.iloc[i].Carname)
# Out:
# 北斗星
# smart fortwo
# smart forfour
# 力帆丰顺
# 五菱之光

# %% [markdown]
# # 3. 最贵的是哪款车?
# 揽胜星脉

# %%
df.head(2)
# Out:
#          Carname Officialprice           Carfuelc  Brand         MIITfuelc  \
# 0   smart fortwo  11.68-30.89万  5.00-11.80L/100km  smart  4.20-5.20L/100km
# 1  smart forfour  12.58-22.08万  5.10-12.00L/100km  smart               NaN
#
#   Rank Displacement Gearbox Cartype                 Ranking  Carstrength  \
# 0  微型车          0.9     双离合     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>         45.0
# 1  微型车          0.9     双离合     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>         44.7
#
#   Configuration Major Ownerevaluate Price                Versions_1  \
# 0            较弱   测试中            优秀    优秀                 2018款 基本型
# 1            较弱   测试中            优秀    优秀   2017款 Crosstown Edition
#
#   Versionsp_1              Versions_2 Versionsp_2  \
# 0         未上市   2018款 1.0L 52千瓦巧克力特别版    13.0888万
# 1          停售    2017款 0.9T 66千瓦挚爱特别版          停售
#
#                                     URL
# 0    https://price.pcauto.com.cn/sg903/
# 1  https://price.pcauto.com.cn/sg11251/

# %%
d_dict = {}
for i in range(1043):
    try:
        d_dict[i] = df.iloc[i].Officialprice.split('-')[1].replace('万','')
    except:
        d_dict[i] = df.iloc[i].Officialprice.split('-')[0].replace('万','')
d_series = pd.Series(d_dict)

# %%
df.Officialprice = d_series

# %%
df.head(2)
# Out:
#          Carname Officialprice           Carfuelc  Brand         MIITfuelc  \
# 0   smart fortwo         30.89  5.00-11.80L/100km  smart  4.20-5.20L/100km
# 1  smart forfour         22.08  5.10-12.00L/100km  smart               NaN
#
#   Rank Displacement Gearbox Cartype                 Ranking  Carstrength  \
# 0  微型车          0.9     双离合     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>         45.0
# 1  微型车          0.9     双离合     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>         44.7
#
#   Configuration Major Ownerevaluate Price                Versions_1  \
# 0            较弱   测试中            优秀    优秀                 2018款 基本型
# 1            较弱   测试中            优秀    优秀   2017款 Crosstown Edition
#
#   Versionsp_1              Versions_2 Versionsp_2  \
# 0         未上市   2018款 1.0L 52千瓦巧克力特别版    13.0888万
# 1          停售    2017款 0.9T 66千瓦挚爱特别版          停售
#
#                                     URL
# 0    https://price.pcauto.com.cn/sg903/
# 1  https://price.pcauto.com.cn/sg11251/

# %%
df.iloc[df.Officialprice.sort_values(ascending=False).head(1).index].Carname
# Out:
# 561    揽胜星脉
# Name: Carname, dtype: object

# %% [markdown]
# # 4. 哪些车车主评价比较高?
# DS 优秀最多

# %%
df1 = df[df.Ownerevaluate.str.contains('优秀')]

# %%
df1.groupby('Brand').max().head()
# Out:
#             Carname            Carfuelc   Rank Gearbox Cartype  \
# Brand
# DS             DS 7    8.90-9.10L/100km   紧凑型车    手自一体     两厢车
# GMC           YUKON  11.00-22.50L/100km  大型SUV    手自一体     SUV
# Jeep            牧马人  10.80-15.10L/100km  中型SUV    手自一体     SUV
# MG名爵           名爵ZS    8.20-9.60L/100km   紧凑型车      自动     掀背车
# MINI   MINI CLUBMAN   7.50-10.20L/100km    小型车    手自一体   软顶敞篷车
#
#                        Ranking  Carstrength Configuration Major Ownerevaluate  \
# Brand
# DS     该车车实力评分高于98%同级别车系查看详情>>         79.6            良好   测试中            优秀
# GMC     该车暂未被列入榜单，暂无排名信息查看详情>>         53.4            良好   测试中            优秀
# Jeep   该车车实力评分高于21%同级别车系查看详情>>         70.8            良好    良好            优秀
# MG名爵   该车车实力评分高于97%同级别车系查看详情>>         75.6            较弱    良好            优秀
# MINI    该车暂未被列入榜单，暂无排名信息查看详情>>         49.2            一般   测试中            优秀
#
#       Price                         Versions_1 Versionsp_1  \
# Brand
# ...

# %% [markdown]
# # 问题:5.车的级别（微型车）与车实力平均得分对比
# 中大型SUV 实力最高  66.678571

# %%
df.head(2)
# Out:
#          Carname Officialprice           Carfuelc  Brand         MIITfuelc  \
# 0   smart fortwo         30.89  5.00-11.80L/100km  smart  4.20-5.20L/100km
# 1  smart forfour         22.08  5.10-12.00L/100km  smart               NaN
#
#   Rank Displacement Gearbox Cartype                 Ranking  Carstrength  \
# 0  微型车          0.9     双离合     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>         45.0
# 1  微型车          0.9     双离合     两厢车  该车暂未被列入榜单，暂无排名信息查看详情>>         44.7
#
#   Configuration Major Ownerevaluate Price                Versions_1  \
# 0            较弱   测试中            优秀    优秀                 2018款 基本型
# 1            较弱   测试中            优秀    优秀   2017款 Crosstown Edition
#
#   Versionsp_1              Versions_2 Versionsp_2  \
# 0         未上市   2018款 1.0L 52千瓦巧克力特别版    13.0888万
# 1          停售    2017款 0.9T 66千瓦挚爱特别版          停售
#
#                                     URL
# 0    https://price.pcauto.com.cn/sg903/
# 1  https://price.pcauto.com.cn/sg11251/

# %%
df.groupby('Rank').mean()
# Out:
#         Carstrength
# Rank
# MPV       46.962338
# 中型SUV     60.643023
# 中型车       59.848214
# 中大型SUV    66.678571
# 中大型车      64.609524
# 大型SUV     56.050000
# 大型车       65.118182
# 小型SUV     48.768056
# 小型车       45.265854
# 微卡        33.000000
# 微型车       39.637500
# 微面        34.340000
# 皮卡        36.125000
# 紧凑型SUV    56.579339
# 紧凑型车      54.510000
# 跑车        55.050000
# 轻客        36.280000

# %% [markdown]
# # 6.车级别最多的是：
# 紧凑型SUV

# %%
df['Rank'].value_counts().head(1)
# Out:
# 紧凑型SUV    242
# Name: Rank, dtype: int64
